# %%
import sys
sys.path.insert(1, '../../Src')
from utils.preprocessing import *
import training


from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
from math import ceil
import warnings
import glob
import os
import sys




SEED = 42
seed_everything(SEED)
PATH_DATASET = '../../dataset/'
PATH_RESULTS = '../../results/Demanda/'
FILL = False
TARGET = 'Demanda'
N_FOLDS = 3
N_FEATURE_IMPORTANCE = 15



plt.rcParams['axes.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Lectura de data referencial para sacar metricas de analisis

# %%
submission_top_reference = 'Submission_73.csv'
print('reading .. ',os.path.join('../../results/',submission_top_reference))
result = pd.read_csv(os.path.join('../../results/',submission_top_reference))
descriptive_columns = ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']
reverse_mapping_file = '../../utils/reverse_dict_mapping_list.txt'

result[['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']] = result['ID'].str.split('|',expand=True)

with open(reverse_mapping_file, 'rb') as f:
    reverse_mapping = pickle.load( f)
    
descriptive_columns = ['Z_MARCA', 'Z_GAMA', 'Z_MODELO',
                       'Z_DEPARTAMENTO', 'Z_PUNTO_VENTA']
i=0
for column in descriptive_columns:
    if column in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']:
        inv_reverse_mapping = {v: k for k, v in reverse_mapping[i].items()}

        result[column] = result[column].map(inv_reverse_mapping)
    i+=1
    
result = result.rename(columns = {TARGET: TARGET+'_real'})
result.head(1)
# Out:
# reading ..  ../../results/Submission_73.csv
#                                                   ID  Demanda_real Z_MODELO  \
# 0  009e0874cc07b2180b2b2b1039321041a1f42e66693c49...           0.0  MOD_170
#
#   Z_PUNTO_VENTA Z_GAMA     Z_WEEK
# 0     PVENT_259  GAM_2  SEMANA_51

# %% [markdown]
# # Lectura de la data con las nuevas variables creadas

# %%
print('Reading dataset')
SHIFT=1
df_train  = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_train_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))
df_test   = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_test_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))

gc.collect()
print('df_train size :',df_train.shape)
print('df_test size  :',df_test.shape) 
features_names = set(df_train.columns)-set([TARGET,'date_block_num',TARGET+'_clipped','release','item_id',
                                            'Z_WEEK_DATE', 'Z_WEEK','date_block_num','year',
                                            'month', 'is_month_end', 'tm_m_end','is_month_start','tm_wm', 'tm_w_end','is_quarter_start','is_year_start',
                                             'day_of_week',
                                            'day_of_year', 'day',
                                           ]) 
print(len(features_names))
features_names = list(features_names)
df_train['week_of_month'] = df_train['week_of_month'].astype('category')
df_test['week_of_month']  = df_test['week_of_month'].astype('category')
total_features_names = features_names.copy()
# Out:
# Reading dataset
# df_train size : (2358650, 1111)
# df_test size  : (471730, 1111)
# 1093

# %% [markdown]
# # Filtro de datos por ventana de tiempo temporal [1 a 3 meses antes] y [7 a 9 meses antes]
# ### nos aseguramos que la tendencia de los meses no solo dependa del anterior inmediato

# %%
def get_feature_names_shift(shift,total_features_names):
    features_names = []

    for column in total_features_names:
        if 'shift' in column:
            number = column.split('shift_')[1]
            number = int(number.split('_')[0])
            if (number>=shift and number<=(shift+2))or(number>=(shift+6) and number<=(shift+8)):
                features_names.append(column)
        else:
            features_names.append(column)
    return features_names

# %% [markdown]
# # Definir la ventana de testing para poder evaluar que el modelo predice bien el futuro
# ### esta ventana de testing es nuestra base de analisis en el training

# %%
TRAIN_START = '2021-08-01'
TEST_START = '2022-03-01'
TEST_END   = '2022-05-01'
print(df_train.shape)
df_train = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)]
print(df_train.shape)
# Out:
# (2358650, 1111)
# (1839747, 1111)

# %% [markdown]
# # Entrenamiento con cross validation e importancia de datos

# %%
PATH_RESULTS = '../../results/Demanda_ventana_custom/'
training.PATH_RESULTS = PATH_RESULTS
training.submission_analysis.TARGET  = TARGET

metrics_dict = {}
metrics_dict_list = []
for SHIFT in range(1,5):
    print('*'*20)
    print('*'*20)
    print('WEEK = ',SHIFT)
    print('*'*20)
    print('*'*20)

    features_names = get_feature_names_shift(SHIFT,total_features_names)
    print('len base features = ',len(features_names))
    print('example base features =',features_names[:5])
    
    ################### CV MODEL RANDOM SPLIT ###############

    gc.collect()
    
    for idx,model_type in enumerate(['xgboost']):

    
        X_train      = df_train[((df_train['Z_WEEK_DATE'] >= TRAIN_START) &(df_train['Z_WEEK_DATE'] < TEST_START))&
                               (df_train['Z_WEEK_DATE'] != '2022-04-11')].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT model_type = ',model_type,'c_model_v2')
        print('*'*20)

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]
        X_train = X_train[features_names]
        X_test  = X_test[features_names]
        X_submission = df_test[features_names]        
        


        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        model_version = 'c_model_v2'
        training.TARGET = TARGET
        training.SHIFT = SHIFT

        df_submission,df_feature_importance,metrics = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                            X_test,y_test,X_submission,df_test,result,N_FOLDS)

    
        gc.collect()
        
        #'''
        if idx ==0 :
            features_names = list(df_feature_importance['feature'][:30].values)
            
        ################### CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE ###############
        important_features = list(df_feature_importance[:N_FEATURE_IMPORTANCE]['feature'])
        
        X_train      = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)&(df_train['Z_WEEK_DATE'] < TEST_START)].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]

        X_train = X_train[important_features]
        X_test  = X_test[important_features]
        X_submission = df_test[important_features]

        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type = ',model_type,'c_model_v3')
        print('*'*20)
        
        model_version = 'c_model_v3'
        training.TARGET = TARGET
        training.SHIFT = SHIFT


        df_submission,df_feature_importance,metrics = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                               X_test,y_test,X_submission,df_test,result,N_FOLDS)
        #'''
        metrics_dict[SHIFT] = metrics
        metrics_dict_list.append(metrics.append('SEMANA_'+str(SHIFT)))
        gc.collect()
# Out:
# ********************
# ********************
# WEEK =  1
# ********************
# ********************
# len base features =  444
# example base features = ['shift_3_roll_4_mean_Z_PUNTO_VENTA_Z_DEPARTAMENTO', 'shift_7_roll_4_mean_item_id', 'shift_2_roll_2_std_Z_PUNTO_VENTA_Z_GAMA', 'shift_2_roll_4_std_Z_MARCA_Z_DEPARTAMENTO', 'shift_7_roll_2_std_Z_PUNTO_VENTA_Z_DEPARTAMENTO']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 444)
# X_test           (377384, 444)
# X_submission     (471730, 444)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1
# [14:36:43] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01533	validation_1-rmse:5.93895
# [20]	validation_0-rmse:5.67463	validation_1-rmse:5.60604
# [40]	validation_0-rmse:4.80061	validation_1-rmse:4.79649
# [60]	validation_0-rmse:3.93479	validation_1-rmse:4.04251
# [80]	validation_0-rmse:3.27241	validation_1-rmse:3.50300
# [100]	validation_0-rmse:2.79883	validation_1-rmse:3.14494
# [120]	validation_0-rmse:2.47330	validation_1-rmse:2.92048
# [140]	validation_0-rmse:2.25941	validation_1-rmse:2.78820
# [160]	validation_0-rmse:2.12613	validation_1-rmse:2.70854
# [180]	validation_0-rmse:2.04493	validation_1-rmse:2.66392
# [200]	validation_0-rmse:1.99007	validation_1-rmse:2.63568
# [220]	validation_0-rmse:1.95462	validation_1-rmse:2.61797
# [240]	validation_0-rmse:1.93056	validation_1-rmse:2.60750
# [260]	validation_0-rmse:1.91288	validation_1-rmse:2.60062
# [280]	validation_0-rmse:1.89988	validation_1-rmse:2.59487
# [300]	validation_0-rmse:1.89028	validation_1-rmse:2.59131
# [320]	validation_0-rmse:1.88386	validation_1-rmse:2.58948
# [340]	validation_0-rmse:1.87640	validation_1-rmse:2.58748
# [360]	validation_0-rmse:1.86848	validation_1-rmse:2.58592
# [380]	validation_0-rmse:1.86111	validation_1-rmse:2.58322
# [400]	validation_0-rmse:1.85344	validation_1-rmse:2.57957
# [420]	validation_0-rmse:1.83864	validation_1-rmse:2.57493
# [440]	validation_0-rmse:1.82686	validation_1-rmse:2.57092
# [460]	validation_0-rmse:1.81090	validation_1-rmse:2.56754
# [480]	validation_0-rmse:1.80233	validation_1-rmse:2.56714
# [500]	validation_0-rmse:1.78643	validation_1-rmse:2.56295
# [520]	validation_0-rmse:1.77898	validation_1-rmse:2.56141
# [540]	validation_0-rmse:1.77049	validation_1-rmse:2.55855
# [560]	validation_0-rmse:1.76338	validation_1-rmse:2.55631
# [580]	validation_0-rmse:1.75546	validation_1-rmse:2.55504
# [600]	validation_0-rmse:1.73519	validation_1-rmse:2.55208
# [620]	validation_0-rmse:1.72139	validation_1-rmse:2.54925
# [640]	validation_0-rmse:1.71176	validation_1-rmse:2.54769
# [660]	validation_0-rmse:1.69965	validation_1-rmse:2.54499
# [680]	validation_0-rmse:1.68508	validation_1-rmse:2.54251
# [700]	validation_0-rmse:1.67131	validation_1-rmse:2.54407
# [720]	validation_0-rmse:1.66370	validation_1-rmse:2.54414
# [740]	validation_0-rmse:1.65157	validation_1-rmse:2.54706
# [752]	validation_0-rmse:1.64584	validation_1-rmse:2.54904
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.541894651071278
# Score test : 2.489934336535407
# Final score mean_absolute_percentage_error
# Score val  : 0.6422974268651482
# Score test : 0.6874854277146711
# Final score mean_absolute_error
# Score val  : 0.4755761451514044
# Score test : 0.4944721116928643
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5419_test_2.4899_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5419_test_2.4899_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5419_test_2.4899_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5419_test_2.4899_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0790415875655803
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1081647988753853
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0495045807309458
# Saving analysis by week ..
# Final score mean_squared_errorweek = 51
# Score week 51_rmse  : 1.7689444797420009
# Final score mean_absolute_percentage_errorweek = 51
# Score week 51_mape  : 0.6923308318730172
# Final score mean_absolute_errorweek = 51
# Score  week 51_mase  : 0.37380352343011847
# Final score mean_squared_errorweek = 52
# Score week 52_rmse  : 2.689608777342957
# Final score mean_absolute_percentage_errorweek = 52
# Score week 52_mape  : 0.6810532317415671
# Final score mean_absolute_errorweek = 52
# Score  week 52_mase  : 0.4814045618835545
# Final score mean_squared_errorweek = 53
# Score week 53_rmse  : 2.261394674828004
# Final score mean_absolute_percentage_errorweek = 53
# Score week 53_mape  : 0.7533816936908672
# Final score mean_absolute_errorweek = 53
# Score  week 53_mase  : 0.42717177717039156
# Final score mean_squared_errorweek = 54
# Score week 54_rmse  : 1.9760480403381275
# Final score mean_absolute_percentage_errorweek = 54
# Score week 54_mape  : 0.744957893482868
# Final score mean_absolute_errorweek = 54
# Score  week 54_mase  : 0.38077898078506905
# Final score mean_squared_errorweek = 55
# Score week 55_rmse  : 1.6852188034352948
# Final score mean_absolute_percentage_errorweek = 55
# Score week 55_mape  : 0.7200014908978176
# Final score mean_absolute_errorweek = 55
# Score  week 55_mase  : 0.32829592670253477
# Final score mean_squared_errorweek = 56
# Score week 56_rmse  : 2.2173987752008104
# Final score mean_absolute_percentage_errorweek = 56
# Score week 56_mape  : 0.6889333636834278
# Final score mean_absolute_errorweek = 56
# Score  week 56_mase  : 0.4107693351282486
# Final score mean_squared_errorweek = 57
# Score week 57_rmse  : 2.3147189046268806
# Final score mean_absolute_percentage_errorweek = 57
# Score week 57_mape  : 0.7201279299728199
# Final score mean_absolute_errorweek = 57
# Score  week 57_mase  : 0.43217693043836986
# Final score mean_squared_errorweek = 58
# Score week 58_rmse  : 2.285934800871995
# Final score mean_absolute_percentage_errorweek = 58
# Score week 58_mape  : 0.7149008389093794
# Final score mean_absolute_errorweek = 58
# Score  week 58_mase  : 0.42965455504569233
# Final score mean_squared_errorweek = 59
# Score week 59_rmse  : 1.7383724864138064
# Final score mean_absolute_percentage_errorweek = 59
# Score week 59_mape  : 0.6799496892905177
# Final score mean_absolute_errorweek = 59
# Score  week 59_mase  : 0.3343212734267515
# Final score mean_squared_errorweek = 60
# Score week 60_rmse  : 1.5748420178317306
# Final score mean_absolute_percentage_errorweek = 60
# Score week 60_mape  : 0.6894187926365767
# Final score mean_absolute_errorweek = 60
# Score  week 60_mase  : 0.30173510641207774
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1
# [14:38:33] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10006	validation_1-rmse:5.76349
# [20]	validation_0-rmse:5.75690	validation_1-rmse:5.43231
# [40]	validation_0-rmse:4.86718	validation_1-rmse:4.65957
# [60]	validation_0-rmse:3.98048	validation_1-rmse:3.95309
# [80]	validation_0-rmse:3.29852	validation_1-rmse:3.44762
# [100]	validation_0-rmse:2.81180	validation_1-rmse:3.10985
# [120]	validation_0-rmse:2.47962	validation_1-rmse:2.89761
# [140]	validation_0-rmse:2.26209	validation_1-rmse:2.76532
# [160]	validation_0-rmse:2.12340	validation_1-rmse:2.68617
# [180]	validation_0-rmse:2.02947	validation_1-rmse:2.63494
# [200]	validation_0-rmse:1.97374	validation_1-rmse:2.60597
# [220]	validation_0-rmse:1.93294	validation_1-rmse:2.58493
# [240]	validation_0-rmse:1.90713	validation_1-rmse:2.57274
# [260]	validation_0-rmse:1.88830	validation_1-rmse:2.56322
# [280]	validation_0-rmse:1.87471	validation_1-rmse:2.55726
# [300]	validation_0-rmse:1.86469	validation_1-rmse:2.55096
# [320]	validation_0-rmse:1.85605	validation_1-rmse:2.54689
# [340]	validation_0-rmse:1.84886	validation_1-rmse:2.54314
# [360]	validation_0-rmse:1.84258	validation_1-rmse:2.53993
# [380]	validation_0-rmse:1.83042	validation_1-rmse:2.53637
# [400]	validation_0-rmse:1.81762	validation_1-rmse:2.53399
# [420]	validation_0-rmse:1.80356	validation_1-rmse:2.52914
# [440]	validation_0-rmse:1.79215	validation_1-rmse:2.52566
# [460]	validation_0-rmse:1.78096	validation_1-rmse:2.52245
# [480]	validation_0-rmse:1.76940	validation_1-rmse:2.52048
# [500]	validation_0-rmse:1.75681	validation_1-rmse:2.51837
# [520]	validation_0-rmse:1.74682	validation_1-rmse:2.51524
# [540]	validation_0-rmse:1.73678	validation_1-rmse:2.51372
# [560]	validation_0-rmse:1.72858	validation_1-rmse:2.51356
# [580]	validation_0-rmse:1.71664	validation_1-rmse:2.51160
# [600]	validation_0-rmse:1.70758	validation_1-rmse:2.50935
# [620]	validation_0-rmse:1.69806	validation_1-rmse:2.50759
# [640]	validation_0-rmse:1.68929	validation_1-rmse:2.50535
# [660]	validation_0-rmse:1.68146	validation_1-rmse:2.50194
# [680]	validation_0-rmse:1.67298	validation_1-rmse:2.49992
# [700]	validation_0-rmse:1.66393	validation_1-rmse:2.49836
# [720]	validation_0-rmse:1.65548	validation_1-rmse:2.49832
# [740]	validation_0-rmse:1.64911	validation_1-rmse:2.49691
# [760]	validation_0-rmse:1.63973	validation_1-rmse:2.49611
# [780]	validation_0-rmse:1.63243	validation_1-rmse:2.49389
# [800]	validation_0-rmse:1.62470	validation_1-rmse:2.49244
# [820]	validation_0-rmse:1.61410	validation_1-rmse:2.49005
# [840]	validation_0-rmse:1.60418	validation_1-rmse:2.48805
# [860]	validation_0-rmse:1.59536	validation_1-rmse:2.48742
# [880]	validation_0-rmse:1.58810	validation_1-rmse:2.48641
# [900]	validation_0-rmse:1.58032	validation_1-rmse:2.48461
# [920]	validation_0-rmse:1.57053	validation_1-rmse:2.48210
# [940]	validation_0-rmse:1.56491	validation_1-rmse:2.48205
# [960]	validation_0-rmse:1.55700	validation_1-rmse:2.47768
# [980]	validation_0-rmse:1.54981	validation_1-rmse:2.47751
# [1000]	validation_0-rmse:1.54349	validation_1-rmse:2.47698
# [1020]	validation_0-rmse:1.53766	validation_1-rmse:2.47725
# [1037]	validation_0-rmse:1.53250	validation_1-rmse:2.47853
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.4764189136007833
# Score test : 2.2506719703689706
# Final score mean_absolute_percentage_error
# Score val  : 0.6427927548240214
# Score test : 0.682066187432312
# Final score mean_absolute_error
# Score val  : 0.46884503804135164
# Score test : 0.4877849979858092
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.4764_test_2.2507_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.4764_test_2.2507_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.4764_test_2.2507_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.4764_test_2.2507_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1205676918399594
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1517455190486534
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.088924578007771
# Saving analysis by week ..
# Final score mean_squared_errorweek = 51
# Score week 51_rmse  : 1.669149572488782
# Final score mean_absolute_percentage_errorweek = 51
# Score week 51_mape  : 0.7356816771980094
# Final score mean_absolute_errorweek = 51
# Score  week 51_mase  : 0.381092711408416
# Final score mean_squared_errorweek = 52
# Score week 52_rmse  : 2.8924708193710207
# Final score mean_absolute_percentage_errorweek = 52
# Score week 52_mape  : 0.7105945471716331
# Final score mean_absolute_errorweek = 52
# Score  week 52_mase  : 0.5073354901539641
# Final score mean_squared_errorweek = 53
# Score week 53_rmse  : 2.3083765903436353
# Final score mean_absolute_percentage_errorweek = 53
# Score week 53_mape  : 0.7289840438110518
# Final score mean_absolute_errorweek = 53
# Score  week 53_mase  : 0.4294555641452744
# Final score mean_squared_errorweek = 54
# Score week 54_rmse  : 1.9621229665806847
# Final score mean_absolute_percentage_errorweek = 54
# Score week 54_mape  : 0.7726622707906232
# Final score mean_absolute_errorweek = 54
# Score  week 54_mase  : 0.3768832183637432
# Final score mean_squared_errorweek = 55
# Score week 55_rmse  : 1.6790077839746738
# Final score mean_absolute_percentage_errorweek = 55
# Score week 55_mape  : 0.7726250748526606
# Final score mean_absolute_errorweek = 55
# Score  week 55_mase  : 0.32179827972339226
# Final score mean_squared_errorweek = 56
# Score week 56_rmse  : 2.209710414568537
# Final score mean_absolute_percentage_errorweek = 56
# Score week 56_mape  : 0.6978754850468105
# Final score mean_absolute_errorweek = 56
# Score  week 56_mase  : 0.4059837910456487
# Final score mean_squared_errorweek = 57
# Score week 57_rmse  : 2.3194685205804864
# Final score mean_absolute_percentage_errorweek = 57
# Score week 57_mape  : 0.6955428209093973
# Final score mean_absolute_errorweek = 57
# Score  week 57_mase  : 0.4295938272163089
# Final score mean_squared_errorweek = 58
# Score week 58_rmse  : 2.3935156164051135
# Final score mean_absolute_percentage_errorweek = 58
# Score week 58_mape  : 0.6902886420104042
# Final score mean_absolute_errorweek = 58
# Score  week 58_mase  : 0.4407093451760837
# Final score mean_squared_errorweek = 59
# Score week 59_rmse  : 1.826820739096025
# Final score mean_absolute_percentage_errorweek = 59
# Score week 59_mape  : 0.6662277702875705
# Final score mean_absolute_errorweek = 59
# Score  week 59_mase  : 0.3403285007352823
# Final score mean_squared_errorweek = 60
# Score week 60_rmse  : 1.5776831462754946
# Final score mean_absolute_percentage_errorweek = 60
# Score week 60_mape  : 0.6736797397223137
# Final score mean_absolute_errorweek = 60
# Score  week 60_mase  : 0.3007272720153649
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1
# [14:40:44] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85187	validation_1-rmse:6.25704
# [20]	validation_0-rmse:5.51565	validation_1-rmse:5.91890
# [40]	validation_0-rmse:4.67689	validation_1-rmse:5.08175
# [60]	validation_0-rmse:3.84710	validation_1-rmse:4.29029
# [80]	validation_0-rmse:3.21004	validation_1-rmse:3.69199
# [100]	validation_0-rmse:2.75300	validation_1-rmse:3.27903
# [120]	validation_0-rmse:2.44170	validation_1-rmse:3.00757
# [140]	validation_0-rmse:2.23784	validation_1-rmse:2.83518
# [160]	validation_0-rmse:2.10993	validation_1-rmse:2.72609
# [180]	validation_0-rmse:2.03100	validation_1-rmse:2.65969
# [200]	validation_0-rmse:1.98213	validation_1-rmse:2.61588
# [220]	validation_0-rmse:1.94457	validation_1-rmse:2.58183
# [240]	validation_0-rmse:1.91960	validation_1-rmse:2.55905
# [260]	validation_0-rmse:1.90147	validation_1-rmse:2.54421
# [280]	validation_0-rmse:1.88844	validation_1-rmse:2.53416
# [300]	validation_0-rmse:1.87918	validation_1-rmse:2.52703
# [320]	validation_0-rmse:1.87284	validation_1-rmse:2.52154
# [340]	validation_0-rmse:1.86654	validation_1-rmse:2.51591
# [360]	validation_0-rmse:1.86072	validation_1-rmse:2.50998
# [380]	validation_0-rmse:1.85288	validation_1-rmse:2.50509
# [400]	validation_0-rmse:1.84071	validation_1-rmse:2.49754
# [420]	validation_0-rmse:1.82705	validation_1-rmse:2.49466
# [440]	validation_0-rmse:1.81988	validation_1-rmse:2.49252
# [460]	validation_0-rmse:1.81009	validation_1-rmse:2.48817
# [480]	validation_0-rmse:1.80368	validation_1-rmse:2.48607
# [500]	validation_0-rmse:1.79510	validation_1-rmse:2.48369
# [520]	validation_0-rmse:1.78338	validation_1-rmse:2.48271
# [540]	validation_0-rmse:1.77500	validation_1-rmse:2.48193
# [560]	validation_0-rmse:1.76621	validation_1-rmse:2.48097
# [580]	validation_0-rmse:1.75514	validation_1-rmse:2.47845
# [600]	validation_0-rmse:1.73667	validation_1-rmse:2.47802
# [620]	validation_0-rmse:1.72007	validation_1-rmse:2.47824
# [640]	validation_0-rmse:1.70718	validation_1-rmse:2.47722
# [660]	validation_0-rmse:1.69831	validation_1-rmse:2.47813
# [678]	validation_0-rmse:1.68823	validation_1-rmse:2.47845
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.476498019049578
# Score test : 2.154676159405605
# Final score mean_absolute_percentage_error
# Score val  : 0.6458942505638864
# Score test : 0.6843003092257057
# Final score mean_absolute_error
# Score val  : 0.4794475996431
# Score test : 0.4880326029889498
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.4765_test_2.1547_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.4765_test_2.1547_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.4765_test_2.1547_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.4765_test_2.1547_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0841602075262067
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0742758738237703
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.093997884560535
# Saving analysis by week ..
# Final score mean_squared_errorweek = 51
# Score week 51_rmse  : 1.399980799310481
# Final score mean_absolute_percentage_errorweek = 51
# Score week 51_mape  : 0.7479403917440758
# Final score mean_absolute_errorweek = 51
# Score  week 51_mase  : 0.3742997840175143
# Final score mean_squared_errorweek = 52
# Score week 52_rmse  : 2.8548032018190876
# Final score mean_absolute_percentage_errorweek = 52
# Score week 52_mape  : 0.6925010827536604
# Final score mean_absolute_errorweek = 52
# Score  week 52_mase  : 0.49180020707724165
# Final score mean_squared_errorweek = 53
# Score week 53_rmse  : 2.2241357880500536
# Final score mean_absolute_percentage_errorweek = 53
# Score week 53_mape  : 0.7484009480801216
# Final score mean_absolute_errorweek = 53
# Score  week 53_mase  : 0.4192297808663276
# Final score mean_squared_errorweek = 54
# Score week 54_rmse  : 1.8730378022603447
# Final score mean_absolute_percentage_errorweek = 54
# Score week 54_mape  : 0.8437528176496131
# Final score mean_absolute_errorweek = 54
# Score  week 54_mase  : 0.3934004565539141
# Final score mean_squared_errorweek = 55
# Score week 55_rmse  : 1.7170334393077515
# Final score mean_absolute_percentage_errorweek = 55
# Score week 55_mape  : 0.8788415624593828
# Final score mean_absolute_errorweek = 55
# Score  week 55_mase  : 0.35429096362716894
# Final score mean_squared_errorweek = 56
# Score week 56_rmse  : 2.172534392575028
# Final score mean_absolute_percentage_errorweek = 56
# Score week 56_mape  : 0.6950636794362909
# Final score mean_absolute_errorweek = 56
# Score  week 56_mase  : 0.39917998003098015
# Final score mean_squared_errorweek = 57
# Score week 57_rmse  : 2.341078048012214
# Final score mean_absolute_percentage_errorweek = 57
# Score week 57_mape  : 0.7085622256692253
# Final score mean_absolute_errorweek = 57
# Score  week 57_mase  : 0.4330110030572311
# Final score mean_squared_errorweek = 58
# Score week 58_rmse  : 2.426539625915647
# Final score mean_absolute_percentage_errorweek = 58
# Score week 58_mape  : 0.7078631205927394
# Final score mean_absolute_errorweek = 58
# Score  week 58_mase  : 0.4462573195429194
# Final score mean_squared_errorweek = 59
# Score week 59_rmse  : 1.8232855789602618
# Final score mean_absolute_percentage_errorweek = 59
# Score week 59_mape  : 0.7651809893393235
# Final score mean_absolute_errorweek = 59
# Score  week 59_mase  : 0.3562668516638763
# Final score mean_squared_errorweek = 60
# Score week 60_rmse  : 1.5846509806044506
# Final score mean_absolute_percentage_errorweek = 60
# Score week 60_mape  : 0.679102637242288
# Final score mean_absolute_errorweek = 60
# Score  week 60_mase  : 0.3020676466394132
# Predict submission
# CV score: 2.49846
# cv_train_rmse :  2.4984609889724947
# cv_test_rmse  :  2.146124133490615
# cv_train_mape :  0.6436620292518901
# cv_test_mape  :  0.6812829907850937
# cv_train_mase :  0.47462292826378577
# cv_test_mase  :  0.48430897170522785
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_1
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_1/rmse_cv_train_2.4985_rmse_cv_test_2.1461_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_1/rmse_cv_train_2.4985_rmse_cv_test_2.1461_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_1/rmse_cv_train_2.4985_rmse_cv_test_2.1461_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0733557097655315
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.073016431296222
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0736949327252887
# Saving analysis by week ..
# Final score mean_squared_errorweek = 51
# Score week 51_rmse  : 1.4296474644351664
# Final score mean_absolute_percentage_errorweek = 51
# Score week 51_mape  : 0.7223207163180296
# Final score mean_absolute_errorweek = 51
# Score  week 51_mase  : 0.37054699310711064
# Final score mean_squared_errorweek = 52
# Score week 52_rmse  : 2.8048008664591886
# Final score mean_absolute_percentage_errorweek = 52
# Score week 52_mape  : 0.6918158830016472
# Final score mean_absolute_errorweek = 52
# Score  week 52_mase  : 0.4918788380756538
# Final score mean_squared_errorweek = 53
# Score week 53_rmse  : 2.251231212440266
# Final score mean_absolute_percentage_errorweek = 53
# Score week 53_mape  : 0.740356915941708
# Final score mean_absolute_errorweek = 53
# Score  week 53_mase  : 0.42274514625897514
# Final score mean_squared_errorweek = 54
# Score week 54_rmse  : 1.9159796046612947
# Final score mean_absolute_percentage_errorweek = 54
# Score week 54_mape  : 0.78183076855818
# Final score mean_absolute_errorweek = 54
# Score  week 54_mase  : 0.3805957109800839
# Final score mean_squared_errorweek = 55
# Score week 55_rmse  : 1.684388919377344
# Final score mean_absolute_percentage_errorweek = 55
# Score week 55_mape  : 0.7794408887919004
# Final score mean_absolute_errorweek = 55
# Score  week 55_mase  : 0.3303791274731213
# Final score mean_squared_errorweek = 56
# Score week 56_rmse  : 2.198284298993647
# Final score mean_absolute_percentage_errorweek = 56
# Score week 56_mape  : 0.6859389747529547
# Final score mean_absolute_errorweek = 56
# Score  week 56_mase  : 0.4038498098492267
# Final score mean_squared_errorweek = 57
# Score week 57_rmse  : 2.324254476132814
# Final score mean_absolute_percentage_errorweek = 57
# Score week 57_mape  : 0.7014478142782006
# Final score mean_absolute_errorweek = 57
# Score  week 57_mase  : 0.43090329002140537
# Final score mean_squared_errorweek = 58
# Score week 58_rmse  : 2.3631473583756373
# Final score mean_absolute_percentage_errorweek = 58
# Score week 58_mape  : 0.6969175217321754
# Final score mean_absolute_errorweek = 58
# Score  week 58_mase  : 0.437255254549325
# Final score mean_squared_errorweek = 59
# Score week 59_rmse  : 1.7861475061308505
# Final score mean_absolute_percentage_errorweek = 59
# Score week 59_mape  : 0.6898222064227028
# Final score mean_absolute_errorweek = 59
# Score  week 59_mase  : 0.3400816203770696
# Final score mean_squared_errorweek = 60
# Score week 60_rmse  : 1.5784968450941153
# Final score mean_absolute_percentage_errorweek = 60
# Score week 60_mape  : 0.6768148328882033
# Final score mean_absolute_errorweek = 60
# Score  week 60_mase  : 0.30115545401922644
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1
# [14:42:43] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01533	validation_1-rmse:5.93895
# [20]	validation_0-rmse:5.67555	validation_1-rmse:5.60460
# [40]	validation_0-rmse:4.82006	validation_1-rmse:4.80106
# [60]	validation_0-rmse:3.99606	validation_1-rmse:4.06031
# [80]	validation_0-rmse:3.37812	validation_1-rmse:3.53004
# [100]	validation_0-rmse:2.95124	validation_1-rmse:3.18498
# [120]	validation_0-rmse:2.67474	validation_1-rmse:2.98039
# [140]	validation_0-rmse:2.50064	validation_1-rmse:2.86461
# [160]	validation_0-rmse:2.39330	validation_1-rmse:2.79928
# [180]	validation_0-rmse:2.32761	validation_1-rmse:2.76214
# [200]	validation_0-rmse:2.28688	validation_1-rmse:2.74261
# [220]	validation_0-rmse:2.26207	validation_1-rmse:2.73126
# [240]	validation_0-rmse:2.24663	validation_1-rmse:2.72393
# [260]	validation_0-rmse:2.23467	validation_1-rmse:2.71776
# [280]	validation_0-rmse:2.22649	validation_1-rmse:2.71513
# [300]	validation_0-rmse:2.22024	validation_1-rmse:2.71176
# [320]	validation_0-rmse:2.21559	validation_1-rmse:2.70916
# [340]	validation_0-rmse:2.20984	validation_1-rmse:2.70781
# [360]	validation_0-rmse:2.20546	validation_1-rmse:2.70876
# [374]	validation_0-rmse:2.20391	validation_1-rmse:2.70814
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.7072881284890116
# Score test : 2.1753121806915914
# Final score mean_absolute_percentage_error
# Score val  : 0.6527665408679796
# Score test : 0.7116407096074358
# Final score mean_absolute_error
# Score val  : 0.49268616333278076
# Score test : 0.45606128208004165
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7073_test_2.1753_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7073_test_2.1753_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7073_test_2.1753_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7073_test_2.1753_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1272440739673106
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0780371597659832
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1753381951066393
# Saving analysis by week ..
# Final score mean_squared_errorweek = 51
# Score week 51_rmse  : 1.2424957345659886
# Final score mean_absolute_percentage_errorweek = 51
# Score week 51_mape  : 0.6091663408387387
# Final score mean_absolute_errorweek = 51
# Score  week 51_mase  : 0.30696571647050236
# Final score mean_squared_errorweek = 52
# Score week 52_rmse  : 2.7445920287551133
# Final score mean_absolute_percentage_errorweek = 52
# Score week 52_mape  : 0.6152531428742424
# Final score mean_absolute_errorweek = 52
# Score  week 52_mase  : 0.44159686526413455
# Final score mean_squared_errorweek = 53
# Score week 53_rmse  : 2.2780749359935526
# Final score mean_absolute_percentage_errorweek = 53
# Score week 53_mape  : 0.6658222451292986
# Final score mean_absolute_errorweek = 53
# Score  week 53_mase  : 0.38680643916961854
# Final score mean_squared_errorweek = 54
# Score week 54_rmse  : 1.9936829074614588
# Final score mean_absolute_percentage_errorweek = 54
# Score week 54_mape  : 0.6650133169010933
# Final score mean_absolute_errorweek = 54
# Score  week 54_mase  : 0.34022539554270526
# Final score mean_squared_errorweek = 55
# Score week 55_rmse  : 1.8303590310686548
# Final score mean_absolute_percentage_errorweek = 55
# Score week 55_mape  : 0.6935768579625327
# Final score mean_absolute_errorweek = 55
# Score  week 55_mase  : 0.32385985705774306
# Final score mean_squared_errorweek = 56
# Score week 56_rmse  : 2.252154973886827
# Final score mean_absolute_percentage_errorweek = 56
# Score week 56_mape  : 0.7391190575892818
# Final score mean_absolute_errorweek = 56
# Score  week 56_mase  : 0.40360796124710463
# Final score mean_squared_errorweek = 57
# Score week 57_rmse  : 2.3922432666039795
# Final score mean_absolute_percentage_errorweek = 57
# Score week 57_mape  : 0.7965847320210184
# Final score mean_absolute_errorweek = 57
# Score  week 57_mase  : 0.43977614839397844
# Final score mean_squared_errorweek = 58
# Score week 58_rmse  : 2.4967227747648555
# Final score mean_absolute_percentage_errorweek = 58
# Score week 58_mape  : 0.8043378286134624
# Final score mean_absolute_errorweek = 58
# Score  week 58_mase  : 0.4576580090804856
# Final score mean_squared_errorweek = 59
# Score week 59_rmse  : 1.988103563232437
# Final score mean_absolute_percentage_errorweek = 59
# Score week 59_mape  : 0.7755151124926688
# Final score mean_absolute_errorweek = 59
# Score  week 59_mase  : 0.3675867734951275
# Final score mean_squared_errorweek = 60
# Score week 60_rmse  : 1.6368479007735455
# Final score mean_absolute_percentage_errorweek = 60
# Score week 60_mape  : 0.7538538283224244
# Final score mean_absolute_errorweek = 60
# Score  week 60_mase  : 0.3060864790710547
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1
# [14:43:03] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10006	validation_1-rmse:5.76349
# [20]	validation_0-rmse:5.75762	validation_1-rmse:5.43238
# [40]	validation_0-rmse:4.87940	validation_1-rmse:4.65886
# [60]	validation_0-rmse:4.02303	validation_1-rmse:3.95188
# [80]	validation_0-rmse:3.37671	validation_1-rmse:3.44818
# [100]	validation_0-rmse:2.93023	validation_1-rmse:3.12208
# [120]	validation_0-rmse:2.63621	validation_1-rmse:2.92438
# [140]	validation_0-rmse:2.44362	validation_1-rmse:2.80623
# [160]	validation_0-rmse:2.32514	validation_1-rmse:2.74031
# [180]	validation_0-rmse:2.25361	validation_1-rmse:2.70282
# [200]	validation_0-rmse:2.21037	validation_1-rmse:2.68169
# [220]	validation_0-rmse:2.18029	validation_1-rmse:2.66793
# [240]	validation_0-rmse:2.16052	validation_1-rmse:2.66040
# [260]	validation_0-rmse:2.14643	validation_1-rmse:2.65503
# [280]	validation_0-rmse:2.13865	validation_1-rmse:2.65275
# [300]	validation_0-rmse:2.13235	validation_1-rmse:2.65098
# [320]	validation_0-rmse:2.12586	validation_1-rmse:2.64939
# [340]	validation_0-rmse:2.12087	validation_1-rmse:2.64784
# [360]	validation_0-rmse:2.11705	validation_1-rmse:2.64681
# [380]	validation_0-rmse:2.11197	validation_1-rmse:2.64610
# [400]	validation_0-rmse:2.10823	validation_1-rmse:2.64534
# [420]	validation_0-rmse:2.10401	validation_1-rmse:2.64369
# [440]	validation_0-rmse:2.10021	validation_1-rmse:2.64281
# [460]	validation_0-rmse:2.09516	validation_1-rmse:2.64176
# [480]	validation_0-rmse:2.09080	validation_1-rmse:2.64093
# [500]	validation_0-rmse:2.08520	validation_1-rmse:2.64001
# [520]	validation_0-rmse:2.07882	validation_1-rmse:2.63948
# [540]	validation_0-rmse:2.07373	validation_1-rmse:2.63966
# [560]	validation_0-rmse:2.06642	validation_1-rmse:2.64030
# [576]	validation_0-rmse:2.06202	validation_1-rmse:2.64137
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.6389455833961866
# Score test : 2.2063619334909808
# Final score mean_absolute_percentage_error
# Score val  : 0.6557948230425662
# Score test : 0.7157425541153682
# Final score mean_absolute_error
# Score val  : 0.4842601761359335
# Score test : 0.4582152544994036
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6389_test_2.2064_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6389_test_2.2064_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6389_test_2.2064_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6389_test_2.2064_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.121499717608574
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0651687000864634
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.176373208760323
# Saving analysis by week ..
# Final score mean_squared_errorweek = 51
# Score week 51_rmse  : 1.2419374053310046
# Final score mean_absolute_percentage_errorweek = 51
# Score week 51_mape  : 0.6283163833511002
# Final score mean_absolute_errorweek = 51
# Score  week 51_mase  : 0.31284210062064216
# Final score mean_squared_errorweek = 52
# Score week 52_rmse  : 2.7762107241300464
# Final score mean_absolute_percentage_errorweek = 52
# Score week 52_mape  : 0.6205828676573063
# Final score mean_absolute_errorweek = 52
# Score  week 52_mase  : 0.4457866493529971
# Final score mean_squared_errorweek = 53
# Score week 53_rmse  : 2.2165780004993882
# Final score mean_absolute_percentage_errorweek = 53
# Score week 53_mape  : 0.6637829197205963
# Final score mean_absolute_errorweek = 53
# Score  week 53_mase  : 0.38487724351198904
# Final score mean_squared_errorweek = 54
# Score week 54_rmse  : 1.9432871201072388
# Final score mean_absolute_percentage_errorweek = 54
# Score week 54_mape  : 0.6589617816311575
# Final score mean_absolute_errorweek = 54
# Score  week 54_mase  : 0.3399097859545202
# Final score mean_squared_errorweek = 55
# Score week 55_rmse  : 1.83991071307184
# Final score mean_absolute_percentage_errorweek = 55
# Score week 55_mape  : 0.6844895520940992
# Final score mean_absolute_errorweek = 55
# Score  week 55_mase  : 0.3259110500690112
# Final score mean_squared_errorweek = 56
# Score week 56_rmse  : 2.245366911277945
# Final score mean_absolute_percentage_errorweek = 56
# Score week 56_mape  : 0.7342332826553035
# Final score mean_absolute_errorweek = 56
# Score  week 56_mase  : 0.40424073316542053
# Final score mean_squared_errorweek = 57
# Score week 57_rmse  : 2.3951682202702
# Final score mean_absolute_percentage_errorweek = 57
# Score week 57_mape  : 0.7949296450951401
# Final score mean_absolute_errorweek = 57
# Score  week 57_mase  : 0.4396361209546426
# Final score mean_squared_errorweek = 58
# Score week 58_rmse  : 2.4999414795064503
# Final score mean_absolute_percentage_errorweek = 58
# Score week 58_mape  : 0.8033711093269683
# Final score mean_absolute_errorweek = 58
# Score  week 58_mase  : 0.4575703268632611
# Final score mean_squared_errorweek = 59
# Score week 59_rmse  : 1.991470083384267
# Final score mean_absolute_percentage_errorweek = 59
# Score week 59_mape  : 0.7780595765966373
# Final score mean_absolute_errorweek = 59
# Score  week 59_mase  : 0.3678785558075865
# Final score mean_squared_errorweek = 60
# Score week 60_rmse  : 1.639767622385232
# Final score mean_absolute_percentage_errorweek = 60
# Score week 60_mape  : 0.758796219186522
# Final score mean_absolute_errorweek = 60
# Score  week 60_mase  : 0.3064231546187702
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1
# [14:43:25] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85187	validation_1-rmse:6.25704
# [20]	validation_0-rmse:5.51651	validation_1-rmse:5.91918
# [40]	validation_0-rmse:4.68963	validation_1-rmse:5.07039
# [60]	validation_0-rmse:3.89217	validation_1-rmse:4.26485
# [80]	validation_0-rmse:3.29413	validation_1-rmse:3.67000
# [100]	validation_0-rmse:2.88493	validation_1-rmse:3.26807
# [120]	validation_0-rmse:2.61695	validation_1-rmse:3.00665
# [140]	validation_0-rmse:2.44619	validation_1-rmse:2.84167
# [160]	validation_0-rmse:2.33874	validation_1-rmse:2.74052
# [180]	validation_0-rmse:2.27436	validation_1-rmse:2.67866
# [200]	validation_0-rmse:2.23334	validation_1-rmse:2.63912
# [220]	validation_0-rmse:2.20789	validation_1-rmse:2.61457
# [240]	validation_0-rmse:2.19206	validation_1-rmse:2.59904
# [260]	validation_0-rmse:2.18029	validation_1-rmse:2.58612
# [280]	validation_0-rmse:2.17163	validation_1-rmse:2.57757
# [300]	validation_0-rmse:2.16588	validation_1-rmse:2.57260
# [320]	validation_0-rmse:2.16101	validation_1-rmse:2.56814
# [340]	validation_0-rmse:2.15529	validation_1-rmse:2.56332
# [360]	validation_0-rmse:2.15094	validation_1-rmse:2.55967
# [380]	validation_0-rmse:2.14817	validation_1-rmse:2.55704
# [400]	validation_0-rmse:2.14374	validation_1-rmse:2.55407
# [420]	validation_0-rmse:2.13908	validation_1-rmse:2.55199
# [440]	validation_0-rmse:2.13421	validation_1-rmse:2.54954
# [460]	validation_0-rmse:2.12757	validation_1-rmse:2.54604
# [480]	validation_0-rmse:2.11922	validation_1-rmse:2.54354
# [500]	validation_0-rmse:2.10995	validation_1-rmse:2.53929
# [520]	validation_0-rmse:2.10205	validation_1-rmse:2.53554
# [540]	validation_0-rmse:2.09549	validation_1-rmse:2.53349
# [560]	validation_0-rmse:2.08836	validation_1-rmse:2.53182
# [580]	validation_0-rmse:2.07966	validation_1-rmse:2.53148
# [600]	validation_0-rmse:2.07440	validation_1-rmse:2.53028
# [620]	validation_0-rmse:2.06944	validation_1-rmse:2.52905
# [640]	validation_0-rmse:2.06325	validation_1-rmse:2.52766
# [660]	validation_0-rmse:2.05793	validation_1-rmse:2.52490
# [680]	validation_0-rmse:2.05330	validation_1-rmse:2.52420
# [700]	validation_0-rmse:2.04501	validation_1-rmse:2.52216
# [720]	validation_0-rmse:2.03765	validation_1-rmse:2.52144
# [740]	validation_0-rmse:2.03109	validation_1-rmse:2.51985
# [760]	validation_0-rmse:2.02462	validation_1-rmse:2.52040
# [769]	validation_0-rmse:2.02254	validation_1-rmse:2.52012
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.5194830287971146
# Score test : 2.324228893344206
# Final score mean_absolute_percentage_error
# Score val  : 0.6514630197676874
# Score test : 0.7189617297521034
# Final score mean_absolute_error
# Score val  : 0.4860756027201374
# Score test : 0.46038049726031366
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.5195_test_2.3242_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.5195_test_2.3242_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.5195_test_2.3242_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.5195_test_2.3242_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1560557812987815
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.135963823755379
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.175962225718107
# Saving analysis by week ..
# Final score mean_squared_errorweek = 51
# Score week 51_rmse  : 1.4333916624380496
# Final score mean_absolute_percentage_errorweek = 51
# Score week 51_mape  : 0.6442944530407614
# Final score mean_absolute_errorweek = 51
# Score  week 51_mase  : 0.32333729215943124
# Final score mean_squared_errorweek = 52
# Score week 52_rmse  : 2.8544828286157182
# Final score mean_absolute_percentage_errorweek = 52
# Score week 52_mape  : 0.6427692585870712
# Final score mean_absolute_errorweek = 52
# Score  week 52_mase  : 0.45177517940822487
# Final score mean_squared_errorweek = 53
# Score week 53_rmse  : 2.306119150699956
# Final score mean_absolute_percentage_errorweek = 53
# Score week 53_mape  : 0.6904112573759469
# Final score mean_absolute_errorweek = 53
# Score  week 53_mase  : 0.3902477192772183
# Final score mean_squared_errorweek = 54
# Score week 54_rmse  : 1.9701913926462784
# Final score mean_absolute_percentage_errorweek = 54
# Score week 54_mape  : 0.6839554747209184
# Final score mean_absolute_errorweek = 54
# Score  week 54_mase  : 0.3392306956559622
# Final score mean_squared_errorweek = 55
# Score week 55_rmse  : 1.8463975044033771
# Final score mean_absolute_percentage_errorweek = 55
# Score week 55_mape  : 0.7030132786930483
# Final score mean_absolute_errorweek = 55
# Score  week 55_mase  : 0.32500975894481815
# Final score mean_squared_errorweek = 56
# Score week 56_rmse  : 2.2501750129527927
# Final score mean_absolute_percentage_errorweek = 56
# Score week 56_mape  : 0.7277829366606058
# Final score mean_absolute_errorweek = 56
# Score  week 56_mase  : 0.4001210938564043
# Final score mean_squared_errorweek = 57
# Score week 57_rmse  : 2.3934506636376196
# Final score mean_absolute_percentage_errorweek = 57
# Score week 57_mape  : 0.7785345862565239
# Final score mean_absolute_errorweek = 57
# Score  week 57_mase  : 0.43576430228553803
# Final score mean_squared_errorweek = 58
# Score week 58_rmse  : 2.4983806213241597
# Final score mean_absolute_percentage_errorweek = 58
# Score week 58_mape  : 0.7877421776571955
# Final score mean_absolute_errorweek = 58
# Score  week 58_mase  : 0.4534818173427991
# Final score mean_squared_errorweek = 59
# Score week 59_rmse  : 1.9901073231863313
# Final score mean_absolute_percentage_errorweek = 59
# Score week 59_mape  : 0.7662087367462613
# Final score mean_absolute_errorweek = 59
# Score  week 59_mase  : 0.3643289831814777
# Final score mean_squared_errorweek = 60
# Score week 60_rmse  : 1.6369885411230185
# Final score mean_absolute_percentage_errorweek = 60
# Score week 60_mape  : 0.7465928302388786
# Final score mean_absolute_errorweek = 60
# Score  week 60_mase  : 0.302565086878228
# Predict submission
# CV score: 2.62305
# cv_train_rmse :  2.623054101379104
# cv_test_rmse  :  2.2039956808551637
# cv_train_mape :  0.6533408097285646
# cv_test_mape  :  0.7142595622179938
# cv_train_mase :  0.48767398415707175
# cv_test_mase  :  0.45696789521430803
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1/rmse_cv_train_2.6231_rmse_cv_test_2.204_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1/rmse_cv_train_2.6231_rmse_cv_test_2.204_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1/rmse_cv_train_2.6231_rmse_cv_test_2.204_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1318726662388157
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0874043838414194
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1754321567063446
# Saving analysis by week ..
# Final score mean_squared_errorweek = 51
# Score week 51_rmse  : 1.2835839742932544
# Final score mean_absolute_percentage_errorweek = 51
# Score week 51_mape  : 0.6259247412301518
# Final score mean_absolute_errorweek = 51
# Score  week 51_mase  : 0.3134277690200742
# Final score mean_squared_errorweek = 52
# Score week 52_rmse  : 2.7876486840503722
# Final score mean_absolute_percentage_errorweek = 52
# Score week 52_mape  : 0.6237011775983791
# Final score mean_absolute_errorweek = 52
# Score  week 52_mase  : 0.4449274341440516
# Final score mean_squared_errorweek = 53
# Score week 53_rmse  : 2.2635414315549887
# Final score mean_absolute_percentage_errorweek = 53
# Score week 53_mape  : 0.6710474676370694
# Final score mean_absolute_errorweek = 53
# Score  week 53_mase  : 0.3862748054521912
# Final score mean_squared_errorweek = 54
# Score week 54_rmse  : 1.966617702418882
# Final score mean_absolute_percentage_errorweek = 54
# Score week 54_mape  : 0.666455668810468
# Final score mean_absolute_errorweek = 54
# Score  week 54_mase  : 0.33883936316603497
# Final score mean_squared_errorweek = 55
# Score week 55_rmse  : 1.8375274974318918
# Final score mean_absolute_percentage_errorweek = 55
# Score week 55_mape  : 0.6899237039645643
# Final score mean_absolute_errorweek = 55
# Score  week 55_mase  : 0.3241201901080017
# Final score mean_squared_errorweek = 56
# Score week 56_rmse  : 2.2475766231193415
# Final score mean_absolute_percentage_errorweek = 56
# Score week 56_mape  : 0.7310402461871818
# Final score mean_absolute_errorweek = 56
# Score  week 56_mase  : 0.40226197963246163
# Final score mean_squared_errorweek = 57
# Score week 57_rmse  : 2.3934969825290096
# Final score mean_absolute_percentage_errorweek = 57
# Score week 57_mape  : 0.7885699140696898
# Final score mean_absolute_errorweek = 57
# Score  week 57_mase  : 0.4382729713603124
# Final score mean_squared_errorweek = 58
# Score week 58_rmse  : 2.49823069477622
# Final score mean_absolute_percentage_errorweek = 58
# Score week 58_mape  : 0.7971945658096968
# Final score mean_absolute_errorweek = 58
# Score  week 58_mase  : 0.4561295619042835
# Final score mean_squared_errorweek = 59
# Score week 59_rmse  : 1.9897527197280094
# Final score mean_absolute_percentage_errorweek = 59
# Score week 59_mape  : 0.7715208279318723
# Final score mean_absolute_errorweek = 59
# Score  week 59_mase  : 0.3664788911782071
# Final score mean_squared_errorweek = 60
# Score week 60_rmse  : 1.637627665253916
# Final score mean_absolute_percentage_errorweek = 60
# Score week 60_mape  : 0.7510485384092652
# Final score mean_absolute_errorweek = 60
# Score  week 60_mase  : 0.3049034978253164
# ********************
# ********************
# WEEK =  2
# ********************
# ********************
# len base features =  444
# example base features = ['shift_3_roll_4_mean_Z_PUNTO_VENTA_Z_DEPARTAMENTO', 'Demanda_lag_shift_10', 'shift_2_roll_2_std_Z_PUNTO_VENTA_Z_GAMA', 'shift_10_roll_2_mean_Z_MODELO_Z_PUNTO_VENTA', 'shift_2_roll_4_std_Z_MARCA_Z_DEPARTAMENTO']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 444)
# X_test           (377384, 444)
# X_submission     (471730, 444)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2
# [14:44:38] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01545	validation_1-rmse:5.93908
# [20]	validation_0-rmse:5.69312	validation_1-rmse:5.62586
# [40]	validation_0-rmse:4.88754	validation_1-rmse:4.87837
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4631/1760486024.py in <module>
#      49         training.SHIFT = SHIFT
#      50
# ---> 51         df_submission,df_feature_importance,metrics = training.training_model_cv(model_type,model_version,X_train,y_train,
#      52                                                             X_test,y_test,X_submission,df_test,result,N_FOLDS)
#      53
#
# /notebooks/entel-2022/DATATHON-ENTEL-2022---Reto2/notebooks/Forecasting_por_semanas/../../Src/training.py in training_model_cv(model_type, model_version, X_train, y_train, X_test, y_test, X_submission, df_test, result, N_FOLDS)
#     324         model_version_fold = model_version+'/fold_'+str(fold_+1)
#     325
# --> 326         X_validation_pred,X_test_pred,df_submission,df_feature_importance = training_model(model_type,model_version_fold,X_train_cv,y_train_cv,
#     327                                                                       X_validation_cv,y_validation_cv,X_test,y_test,X_submission,df_test,result)
#     328
#
# /notebooks/entel-2022/DATATHON-ENTEL-2022---Reto2/notebooks/Forecasting_por_semanas/../../Src/training.py in training_model(model_type, model_version, X_train, y_train, X_validation, y_validation, X_test, y_test, X_submission, df_test, result)
#     195         model = XGBOOST.my_xgboost(model_name)
#     196
# --> 197     _ = model.train(X_train,y_train,X_validation,y_validation)
#     198
#     199     ###### analisis training #############
#
# /notebooks/entel-2022/DATATHON-ENTEL-2022---Reto2/notebooks/Forecasting_por_semanas/../../Src/utils/XGBOOST.py in train(self, X_train, y_train, X_validation, y_validation)
#      80
#      81
# ---> 82         self.model_result = self.model.fit(X_train._get_numeric_data().values,y_train,
#      83                 verbose=20,
#      84                 early_stopping_rounds=40,
#
# /opt/conda/lib/python3.8/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     530         for k, arg in zip(sig.parameters, args):
#     531             kwargs[k] = arg
# --> 532         return f(**kwargs)
#     533
#     534     return inner_f
#
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     959             xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#     960         )
# --> 961         self._Booster = train(
#     962             params,
#     963             train_dmatrix,
#
# /opt/conda/lib/python3.8/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     530         for k, arg in zip(sig.parameters, args):
#     531             kwargs[k] = arg
# --> 532         return f(**kwargs)
#     533
#     534     return inner_f
#
# /opt/conda/lib/python3.8/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179         if cb_container.before_iteration(bst, i, dtrain, evals):
#     180             break
# --> 181         bst.update(dtrain, i, obj)
#     182         if cb_container.after_iteration(bst, i, dtrain, evals):
#     183             break
#
# /opt/conda/lib/python3.8/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1731
#    1732         if fobj is None:
# -> 1733             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1734                                                     ctypes.c_int(iteration),
#    1735                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
import pandas as pd

df = pd.DataFrame(metrics_dict_list,columns =['train rmse','val rmse','train mape','val mape','train mase','val mase'])

# %%
df.head(10)
