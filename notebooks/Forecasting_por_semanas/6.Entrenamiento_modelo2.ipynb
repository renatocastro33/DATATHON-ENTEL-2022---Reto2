# %%
import sys
sys.path.insert(1, '../../Src')
from utils.preprocessing import *
import training


from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
from math import ceil
import warnings
import glob
import os
import sys




SEED = 42
seed_everything(SEED)
PATH_DATASET = '../../dataset/'
PATH_RESULTS = '../../results/Demanda/'
FILL = False
TARGET = 'Demanda'
N_FOLDS = 3
N_FEATURE_IMPORTANCE = 15



plt.rcParams['axes.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Lectura de data referencial para sacar metricas de analisis

# %%
submission_top_reference = 'Submission_73.csv'
print('reading .. ',os.path.join('../../results/',submission_top_reference))
result = pd.read_csv(os.path.join('../../results/',submission_top_reference))
descriptive_columns = ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']
reverse_mapping_file = '../../utils/reverse_dict_mapping_list.txt'

result[['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']] = result['ID'].str.split('|',expand=True)

with open(reverse_mapping_file, 'rb') as f:
    reverse_mapping = pickle.load( f)
    
descriptive_columns = ['Z_MARCA', 'Z_GAMA', 'Z_MODELO',
                       'Z_DEPARTAMENTO', 'Z_PUNTO_VENTA']
i=0
for column in descriptive_columns:
    if column in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']:
        inv_reverse_mapping = {v: k for k, v in reverse_mapping[i].items()}

        result[column] = result[column].map(inv_reverse_mapping)
    i+=1
    
result = result.rename(columns = {TARGET: TARGET+'_real'})
result.head(1)
# Out:
# reading ..  ../../results/Submission_73.csv
#                                                   ID  Demanda_real Z_MODELO  \
# 0  009e0874cc07b2180b2b2b1039321041a1f42e66693c49...           0.0  MOD_170
#
#   Z_PUNTO_VENTA Z_GAMA     Z_WEEK
# 0     PVENT_259  GAM_2  SEMANA_51

# %% [markdown]
# # Lectura de la data con las nuevas variables creadas

# %%
print('Reading dataset')
SHIFT=1
df_train  = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_train_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))
df_test   = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_test_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))

gc.collect()
print('df_train size :',df_train.shape)
print('df_test size  :',df_test.shape) 
features_names = set(df_train.columns)-set([TARGET,'date_block_num',TARGET+'_clipped','release','item_id',
                                            'Z_WEEK_DATE', 'Z_WEEK','date_block_num','year',
                                            'month', 'is_month_end', 'tm_m_end','is_month_start','tm_wm', 'tm_w_end','is_quarter_start','is_year_start',
                                             'day_of_week',
                                            'day_of_year', 'day',
                                           ]) 
print(len(features_names))
features_names = list(features_names)
df_train['week_of_month'] = df_train['week_of_month'].astype('category')
df_test['week_of_month']  = df_test['week_of_month'].astype('category')
total_features_names = features_names.copy()
# Out:
# Reading dataset
# df_train size : (2358650, 1111)
# df_test size  : (471730, 1111)
# 1093

# %% [markdown]
# # Filtro de datos por ventana de tiempo temporal [1 a 3 meses antes] y [7 a 9 meses antes]
# ### nos aseguramos que la tendencia de los meses no solo dependa del anterior inmediato

# %%
def get_feature_names_shift(shift,total_features_names):
    features_names = []

    for column in total_features_names:
        if 'shift' in column:
            number = column.split('shift_')[1]
            number = int(number.split('_')[0])
            if (number>=shift and number<=(shift+2))or(number>=(shift+6) and number<=(shift+8)):
                features_names.append(column)
        else:
            features_names.append(column)
    return features_names

# %% [markdown]
# # Definir la ventana de testing para poder evaluar que el modelo predice bien el futuro
# ### esta ventana de testing es nuestra base de analisis en el training

# %%
TRAIN_START = '2021-08-01'
TEST_START = '2022-03-01'
TEST_END   = '2022-05-01'
print(df_train.shape)
df_train = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)]
print(df_train.shape)
# Out:
# (2358650, 1111)
# (1839747, 1111)

# %% [markdown]
# # Entrenamiento con cross validation e importancia de datos

# %%
PATH_RESULTS = '../../results/Demanda_ventana_custom/'
training.PATH_RESULTS = PATH_RESULTS
training.submission_analysis.TARGET  = TARGET


for SHIFT in range(1,4):
    print('*'*20)
    print('*'*20)
    print('WEEK = ',SHIFT)
    print('*'*20)
    print('*'*20)

    features_names = get_feature_names_shift(SHIFT,total_features_names)
    print('len base features = ',len(features_names))
    print('example base features =',features_names[:5])
    
    ################### CV MODEL RANDOM SPLIT ###############

    gc.collect()
    
    for idx,model_type in enumerate(['xgboost']):

    
        X_train      = df_train[((df_train['Z_WEEK_DATE'] >= TRAIN_START) &(df_train['Z_WEEK_DATE'] < TEST_START))&
                               (df_train['Z_WEEK_DATE'] != '2022-04-11')].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT model_type = ',model_type,'c_model_v2')
        print('*'*20)

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]
        X_train = X_train[features_names]
        X_test  = X_test[features_names]
        X_submission = df_test[features_names]        
        


        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        model_version = 'c_model_v2'
        training.TARGET = TARGET
        training.SHIFT = SHIFT

        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                            X_test,y_test,X_submission,df_test,result,N_FOLDS)

    
        gc.collect()
        
        #'''
        if idx ==0 :
            features_names = list(df_feature_importance['feature'][:30].values)
            
        ################### CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE ###############
        important_features = list(df_feature_importance[:N_FEATURE_IMPORTANCE]['feature'])
        
        X_train      = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)&(df_train['Z_WEEK_DATE'] < TEST_START)].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]

        X_train = X_train[important_features]
        X_test  = X_test[important_features]
        X_submission = df_test[important_features]

        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type = ',model_type,'c_model_v3')
        print('*'*20)
        
        model_version = 'c_model_v3'
        training.TARGET = TARGET
        training.SHIFT = SHIFT


        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                               X_test,y_test,X_submission,df_test,result,N_FOLDS)
        #'''
        gc.collect()
# Out:
# ********************
# ********************
# WEEK =  1
# ********************
# ********************
# len base features =  444
# example base features = ['shift_3_roll_2_mean_Z_MODELO_Z_PUNTO_VENTA', 'shift_7_roll_4_mean_Z_MODELO_Z_MARCA', 'shift_2_roll_2_std_Z_PUNTO_VENTA', 'shift_2_roll_2_std_Z_GAMA', 'shift_7_roll_2_std_Z_PUNTO_VENTA_Z_DEPARTAMENTO']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 444)
# X_test           (377384, 444)
# X_submission     (471730, 444)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1
# [22:46:49] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01533	validation_1-rmse:5.93895
# [20]	validation_0-rmse:5.67463	validation_1-rmse:5.60601
# [40]	validation_0-rmse:4.80061	validation_1-rmse:4.79672
# [60]	validation_0-rmse:3.93528	validation_1-rmse:4.04420
# [80]	validation_0-rmse:3.27156	validation_1-rmse:3.50218
# [100]	validation_0-rmse:2.79633	validation_1-rmse:3.14425
# [120]	validation_0-rmse:2.47059	validation_1-rmse:2.92477
# [140]	validation_0-rmse:2.25727	validation_1-rmse:2.79192
# [160]	validation_0-rmse:2.12065	validation_1-rmse:2.71185
# [180]	validation_0-rmse:2.03800	validation_1-rmse:2.66552
# [200]	validation_0-rmse:1.98432	validation_1-rmse:2.63663
# [220]	validation_0-rmse:1.94727	validation_1-rmse:2.61977
# [240]	validation_0-rmse:1.92406	validation_1-rmse:2.61048
# [260]	validation_0-rmse:1.90415	validation_1-rmse:2.60342
# [280]	validation_0-rmse:1.89122	validation_1-rmse:2.59776
# [300]	validation_0-rmse:1.88142	validation_1-rmse:2.59431
# [320]	validation_0-rmse:1.87453	validation_1-rmse:2.59194
# [340]	validation_0-rmse:1.86729	validation_1-rmse:2.59062
# [360]	validation_0-rmse:1.85929	validation_1-rmse:2.58946
# [380]	validation_0-rmse:1.85186	validation_1-rmse:2.58861
# [400]	validation_0-rmse:1.84584	validation_1-rmse:2.58685
# [420]	validation_0-rmse:1.82747	validation_1-rmse:2.58822
# [440]	validation_0-rmse:1.81745	validation_1-rmse:2.58511
# [460]	validation_0-rmse:1.80476	validation_1-rmse:2.58374
# [480]	validation_0-rmse:1.79559	validation_1-rmse:2.58218
# [500]	validation_0-rmse:1.78514	validation_1-rmse:2.58042
# [520]	validation_0-rmse:1.77495	validation_1-rmse:2.57784
# [540]	validation_0-rmse:1.76591	validation_1-rmse:2.57703
# [560]	validation_0-rmse:1.75859	validation_1-rmse:2.57581
# [580]	validation_0-rmse:1.74414	validation_1-rmse:2.57149
# [600]	validation_0-rmse:1.73000	validation_1-rmse:2.56878
# [620]	validation_0-rmse:1.71280	validation_1-rmse:2.56477
# [640]	validation_0-rmse:1.69984	validation_1-rmse:2.56238
# [660]	validation_0-rmse:1.69074	validation_1-rmse:2.56140
# [680]	validation_0-rmse:1.68094	validation_1-rmse:2.55916
# [700]	validation_0-rmse:1.66881	validation_1-rmse:2.55789
# [720]	validation_0-rmse:1.65745	validation_1-rmse:2.55932
# [740]	validation_0-rmse:1.65141	validation_1-rmse:2.55880
# [749]	validation_0-rmse:1.64788	validation_1-rmse:2.55994
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.555443656343765
# Score test : 2.5339920339468405
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5554_test_2.534_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5554_test_2.534_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5554_test_2.534_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5554_test_2.534_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.101873959285586
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1402543332895774
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0627795980862604
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1
# [22:48:40] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10006	validation_1-rmse:5.76349
# [20]	validation_0-rmse:5.75690	validation_1-rmse:5.43237
# [40]	validation_0-rmse:4.86718	validation_1-rmse:4.65966
# [60]	validation_0-rmse:3.98048	validation_1-rmse:3.95270
# [80]	validation_0-rmse:3.29852	validation_1-rmse:3.44660
# [100]	validation_0-rmse:2.81180	validation_1-rmse:3.10867
# [120]	validation_0-rmse:2.47962	validation_1-rmse:2.89655
# [140]	validation_0-rmse:2.26209	validation_1-rmse:2.76440
# [160]	validation_0-rmse:2.12340	validation_1-rmse:2.68597
# [180]	validation_0-rmse:2.02947	validation_1-rmse:2.63503
# [200]	validation_0-rmse:1.97374	validation_1-rmse:2.60628
# [220]	validation_0-rmse:1.93317	validation_1-rmse:2.58599
# [240]	validation_0-rmse:1.90576	validation_1-rmse:2.57315
# [260]	validation_0-rmse:1.88873	validation_1-rmse:2.56550
# [280]	validation_0-rmse:1.87548	validation_1-rmse:2.55995
# [300]	validation_0-rmse:1.86558	validation_1-rmse:2.55433
# [320]	validation_0-rmse:1.85781	validation_1-rmse:2.55108
# [340]	validation_0-rmse:1.85273	validation_1-rmse:2.54829
# [360]	validation_0-rmse:1.84205	validation_1-rmse:2.54330
# [380]	validation_0-rmse:1.83412	validation_1-rmse:2.53934
# [400]	validation_0-rmse:1.82310	validation_1-rmse:2.53404
# [420]	validation_0-rmse:1.80596	validation_1-rmse:2.52733
# [440]	validation_0-rmse:1.79134	validation_1-rmse:2.52219
# [460]	validation_0-rmse:1.78053	validation_1-rmse:2.51725
# [480]	validation_0-rmse:1.77135	validation_1-rmse:2.51379
# [500]	validation_0-rmse:1.76091	validation_1-rmse:2.51041
# [520]	validation_0-rmse:1.74961	validation_1-rmse:2.50832
# [540]	validation_0-rmse:1.74120	validation_1-rmse:2.50615
# [560]	validation_0-rmse:1.73243	validation_1-rmse:2.50359
# [580]	validation_0-rmse:1.72229	validation_1-rmse:2.50147
# [600]	validation_0-rmse:1.70976	validation_1-rmse:2.49958
# [620]	validation_0-rmse:1.70105	validation_1-rmse:2.49708
# [640]	validation_0-rmse:1.69292	validation_1-rmse:2.49511
# [660]	validation_0-rmse:1.68590	validation_1-rmse:2.49292
# [680]	validation_0-rmse:1.67502	validation_1-rmse:2.49151
# [700]	validation_0-rmse:1.66759	validation_1-rmse:2.49099
# [720]	validation_0-rmse:1.66003	validation_1-rmse:2.49076
# [740]	validation_0-rmse:1.65161	validation_1-rmse:2.48875
# [760]	validation_0-rmse:1.64121	validation_1-rmse:2.48668
# [780]	validation_0-rmse:1.63401	validation_1-rmse:2.48555
# [800]	validation_0-rmse:1.62519	validation_1-rmse:2.48509
# [820]	validation_0-rmse:1.61929	validation_1-rmse:2.48344
# [840]	validation_0-rmse:1.61199	validation_1-rmse:2.48426
# [860]	validation_0-rmse:1.60456	validation_1-rmse:2.48291
# [880]	validation_0-rmse:1.59679	validation_1-rmse:2.48216
# [900]	validation_0-rmse:1.58919	validation_1-rmse:2.48079
# [920]	validation_0-rmse:1.58394	validation_1-rmse:2.48047
# [940]	validation_0-rmse:1.57380	validation_1-rmse:2.48809
# [956]	validation_0-rmse:1.56819	validation_1-rmse:2.48694
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.4801703747871473
# Score test : 2.235262567968253
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.4802_test_2.2353_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.4802_test_2.2353_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.4802_test_2.2353_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.4802_test_2.2353_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.129428248974568
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.147805019017329
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.110891502504513
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1
# [22:50:47] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85187	validation_1-rmse:6.25704
# [20]	validation_0-rmse:5.51565	validation_1-rmse:5.91905
# [40]	validation_0-rmse:4.67689	validation_1-rmse:5.08426
# [60]	validation_0-rmse:3.84710	validation_1-rmse:4.29929
# [80]	validation_0-rmse:3.21004	validation_1-rmse:3.70787
# [100]	validation_0-rmse:2.75300	validation_1-rmse:3.30148
# [120]	validation_0-rmse:2.44170	validation_1-rmse:3.03272
# [140]	validation_0-rmse:2.23784	validation_1-rmse:2.86173
# [160]	validation_0-rmse:2.10993	validation_1-rmse:2.75401
# [180]	validation_0-rmse:2.03100	validation_1-rmse:2.68819
# [200]	validation_0-rmse:1.98213	validation_1-rmse:2.64569
# [220]	validation_0-rmse:1.94457	validation_1-rmse:2.61236
# [240]	validation_0-rmse:1.91960	validation_1-rmse:2.59004
# [260]	validation_0-rmse:1.90147	validation_1-rmse:2.57525
# [280]	validation_0-rmse:1.88844	validation_1-rmse:2.56530
# [300]	validation_0-rmse:1.87918	validation_1-rmse:2.55815
# [320]	validation_0-rmse:1.87284	validation_1-rmse:2.55263
# [340]	validation_0-rmse:1.86654	validation_1-rmse:2.54740
# [360]	validation_0-rmse:1.86072	validation_1-rmse:2.54155
# [380]	validation_0-rmse:1.85288	validation_1-rmse:2.53651
# [400]	validation_0-rmse:1.84071	validation_1-rmse:2.52889
# [420]	validation_0-rmse:1.82705	validation_1-rmse:2.52592
# [440]	validation_0-rmse:1.81988	validation_1-rmse:2.52360
# [460]	validation_0-rmse:1.81009	validation_1-rmse:2.51907
# [480]	validation_0-rmse:1.80368	validation_1-rmse:2.51687
# [500]	validation_0-rmse:1.79510	validation_1-rmse:2.51430
# [520]	validation_0-rmse:1.78338	validation_1-rmse:2.51321
# [540]	validation_0-rmse:1.77500	validation_1-rmse:2.51087
# [560]	validation_0-rmse:1.76621	validation_1-rmse:2.50800
# [580]	validation_0-rmse:1.75514	validation_1-rmse:2.50405
# [600]	validation_0-rmse:1.73667	validation_1-rmse:2.50308
# [620]	validation_0-rmse:1.72007	validation_1-rmse:2.50289
# [640]	validation_0-rmse:1.70718	validation_1-rmse:2.50145
# [660]	validation_0-rmse:1.69831	validation_1-rmse:2.50139
# [670]	validation_0-rmse:1.69134	validation_1-rmse:2.50253
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.500744546079832
# Score test : 2.1565120584004247
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.5007_test_2.1565_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.5007_test_2.1565_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.5007_test_2.1565_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.5007_test_2.1565_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0836226271461884
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.070583658385387
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0965805060475375
# Saving analysis by week ..
# Predict submission
# CV score: 2.51232
# cv_train_rmse :  2.512320381758266
# cv_test_rmse  :  2.1068006754897253
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_1
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_1/rmse_cv_train_2.5123_rmse_cv_test_2.1068_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_1/rmse_cv_train_2.5123_rmse_cv_test_2.1068_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_1/rmse_cv_train_2.5123_rmse_cv_test_2.1068_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0776229601436267
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0672062633844632
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.087987690015431
# Saving analysis by week ..
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1
# [22:52:48] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01533	validation_1-rmse:5.93895
# [20]	validation_0-rmse:5.67558	validation_1-rmse:5.60466
# [40]	validation_0-rmse:4.82070	validation_1-rmse:4.80137
# [60]	validation_0-rmse:3.99680	validation_1-rmse:4.05806
# [80]	validation_0-rmse:3.38095	validation_1-rmse:3.52891
# [100]	validation_0-rmse:2.95205	validation_1-rmse:3.18793
# [120]	validation_0-rmse:2.67414	validation_1-rmse:2.98687
# [140]	validation_0-rmse:2.49800	validation_1-rmse:2.87292
# [160]	validation_0-rmse:2.39079	validation_1-rmse:2.80511
# [180]	validation_0-rmse:2.32443	validation_1-rmse:2.76945
# [200]	validation_0-rmse:2.28066	validation_1-rmse:2.75424
# [220]	validation_0-rmse:2.25613	validation_1-rmse:2.74133
# [240]	validation_0-rmse:2.24003	validation_1-rmse:2.73683
# [260]	validation_0-rmse:2.22633	validation_1-rmse:2.73571
# [280]	validation_0-rmse:2.21819	validation_1-rmse:2.73396
# [300]	validation_0-rmse:2.21286	validation_1-rmse:2.73232
# [320]	validation_0-rmse:2.20882	validation_1-rmse:2.73172
# [340]	validation_0-rmse:2.20490	validation_1-rmse:2.73055
# [360]	validation_0-rmse:2.20074	validation_1-rmse:2.72856
# [380]	validation_0-rmse:2.19736	validation_1-rmse:2.72751
# [400]	validation_0-rmse:2.18894	validation_1-rmse:2.73560
# [420]	validation_0-rmse:2.18428	validation_1-rmse:2.73809
# [421]	validation_0-rmse:2.18408	validation_1-rmse:2.73799
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.7274810815712334
# Score test : 2.191415866486637
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7275_test_2.1914_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7275_test_2.1914_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7275_test_2.1914_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7275_test_2.1914_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.127113219375154
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0761482861853082
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.176885295519926
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1
# [22:53:08] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10006	validation_1-rmse:5.76349
# [20]	validation_0-rmse:5.75767	validation_1-rmse:5.43252
# [40]	validation_0-rmse:4.88128	validation_1-rmse:4.66019
# [60]	validation_0-rmse:4.02725	validation_1-rmse:3.95187
# [80]	validation_0-rmse:3.38151	validation_1-rmse:3.44742
# [100]	validation_0-rmse:2.93648	validation_1-rmse:3.12109
# [120]	validation_0-rmse:2.64350	validation_1-rmse:2.91979
# [140]	validation_0-rmse:2.45022	validation_1-rmse:2.79952
# [160]	validation_0-rmse:2.33155	validation_1-rmse:2.73238
# [180]	validation_0-rmse:2.26032	validation_1-rmse:2.69384
# [200]	validation_0-rmse:2.21867	validation_1-rmse:2.67260
# [220]	validation_0-rmse:2.18980	validation_1-rmse:2.65993
# [240]	validation_0-rmse:2.16927	validation_1-rmse:2.65169
# [260]	validation_0-rmse:2.15481	validation_1-rmse:2.64565
# [280]	validation_0-rmse:2.14717	validation_1-rmse:2.64227
# [300]	validation_0-rmse:2.14139	validation_1-rmse:2.64016
# [320]	validation_0-rmse:2.13624	validation_1-rmse:2.63818
# [340]	validation_0-rmse:2.13076	validation_1-rmse:2.63604
# [360]	validation_0-rmse:2.12617	validation_1-rmse:2.63412
# [380]	validation_0-rmse:2.12210	validation_1-rmse:2.63267
# [400]	validation_0-rmse:2.11829	validation_1-rmse:2.63127
# [420]	validation_0-rmse:2.11284	validation_1-rmse:2.62882
# [440]	validation_0-rmse:2.10916	validation_1-rmse:2.62720
# [460]	validation_0-rmse:2.10386	validation_1-rmse:2.62669
# [480]	validation_0-rmse:2.09978	validation_1-rmse:2.62585
# [500]	validation_0-rmse:2.09548	validation_1-rmse:2.62533
# [520]	validation_0-rmse:2.09246	validation_1-rmse:2.62428
# [540]	validation_0-rmse:2.08926	validation_1-rmse:2.62332
# [560]	validation_0-rmse:2.08435	validation_1-rmse:2.62361
# [580]	validation_0-rmse:2.07829	validation_1-rmse:2.62210
# [600]	validation_0-rmse:2.07289	validation_1-rmse:2.62136
# [620]	validation_0-rmse:2.06461	validation_1-rmse:2.62001
# [640]	validation_0-rmse:2.05503	validation_1-rmse:2.62015
# [660]	validation_0-rmse:2.04960	validation_1-rmse:2.61904
# [680]	validation_0-rmse:2.04358	validation_1-rmse:2.61822
# [700]	validation_0-rmse:2.03514	validation_1-rmse:2.61809
# [720]	validation_0-rmse:2.02788	validation_1-rmse:2.61699
# [740]	validation_0-rmse:2.01925	validation_1-rmse:2.61641
# [760]	validation_0-rmse:2.01435	validation_1-rmse:2.61391
# [780]	validation_0-rmse:2.00579	validation_1-rmse:2.61429
# [800]	validation_0-rmse:1.99840	validation_1-rmse:2.61542
# [816]	validation_0-rmse:1.99410	validation_1-rmse:2.61489
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.6134224745556005
# Score test : 2.2228186068006193
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6134_test_2.2228_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6134_test_2.2228_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6134_test_2.2228_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6134_test_2.2228_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.126816471019004
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0835351011993644
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.169234446726683
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1
# [22:53:33] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85187	validation_1-rmse:6.25704
# [20]	validation_0-rmse:5.51652	validation_1-rmse:5.91930
# [40]	validation_0-rmse:4.69001	validation_1-rmse:5.07144
# [60]	validation_0-rmse:3.89051	validation_1-rmse:4.26536
# [80]	validation_0-rmse:3.29307	validation_1-rmse:3.66745
# [100]	validation_0-rmse:2.88501	validation_1-rmse:3.26602
# [120]	validation_0-rmse:2.61698	validation_1-rmse:3.00587
# [140]	validation_0-rmse:2.44802	validation_1-rmse:2.84048
# [160]	validation_0-rmse:2.33885	validation_1-rmse:2.73623
# [180]	validation_0-rmse:2.27406	validation_1-rmse:2.67277
# [200]	validation_0-rmse:2.23463	validation_1-rmse:2.63428
# [220]	validation_0-rmse:2.20933	validation_1-rmse:2.60986
# [240]	validation_0-rmse:2.19271	validation_1-rmse:2.59391
# [260]	validation_0-rmse:2.18023	validation_1-rmse:2.58007
# [280]	validation_0-rmse:2.17251	validation_1-rmse:2.57213
# [300]	validation_0-rmse:2.16767	validation_1-rmse:2.56742
# [320]	validation_0-rmse:2.16327	validation_1-rmse:2.56298
# [340]	validation_0-rmse:2.15856	validation_1-rmse:2.55877
# [360]	validation_0-rmse:2.15535	validation_1-rmse:2.55633
# [380]	validation_0-rmse:2.15237	validation_1-rmse:2.55437
# [400]	validation_0-rmse:2.14900	validation_1-rmse:2.55237
# [420]	validation_0-rmse:2.14574	validation_1-rmse:2.54985
# [440]	validation_0-rmse:2.14144	validation_1-rmse:2.54687
# [460]	validation_0-rmse:2.13728	validation_1-rmse:2.54508
# [480]	validation_0-rmse:2.13146	validation_1-rmse:2.54434
# [500]	validation_0-rmse:2.12159	validation_1-rmse:2.54558
# [520]	validation_0-rmse:2.11576	validation_1-rmse:2.54382
# [540]	validation_0-rmse:2.11240	validation_1-rmse:2.54194
# [560]	validation_0-rmse:2.10769	validation_1-rmse:2.54104
# [580]	validation_0-rmse:2.10086	validation_1-rmse:2.54129
# [600]	validation_0-rmse:2.09596	validation_1-rmse:2.54169
# [620]	validation_0-rmse:2.08612	validation_1-rmse:2.54033
# [640]	validation_0-rmse:2.07723	validation_1-rmse:2.53940
# [660]	validation_0-rmse:2.06997	validation_1-rmse:2.54067
# [680]	validation_0-rmse:2.06296	validation_1-rmse:2.53928
# [700]	validation_0-rmse:2.05597	validation_1-rmse:2.53825
# [720]	validation_0-rmse:2.05098	validation_1-rmse:2.53517
# [740]	validation_0-rmse:2.04129	validation_1-rmse:2.53317
# [760]	validation_0-rmse:2.02920	validation_1-rmse:2.52977
# [780]	validation_0-rmse:2.02316	validation_1-rmse:2.52779
# [800]	validation_0-rmse:2.01465	validation_1-rmse:2.52533
# [820]	validation_0-rmse:2.00751	validation_1-rmse:2.52398
# [840]	validation_0-rmse:1.99931	validation_1-rmse:2.52175
# [860]	validation_0-rmse:1.99334	validation_1-rmse:2.52076
# [880]	validation_0-rmse:1.98706	validation_1-rmse:2.51962
# [900]	validation_0-rmse:1.98062	validation_1-rmse:2.51840
# [920]	validation_0-rmse:1.97208	validation_1-rmse:2.51696
# [940]	validation_0-rmse:1.96734	validation_1-rmse:2.51492
# [960]	validation_0-rmse:1.96233	validation_1-rmse:2.51349
# [980]	validation_0-rmse:1.95640	validation_1-rmse:2.51224
# [1000]	validation_0-rmse:1.94937	validation_1-rmse:2.51268
# [1020]	validation_0-rmse:1.94495	validation_1-rmse:2.51068
# [1040]	validation_0-rmse:1.93986	validation_1-rmse:2.50968
# [1060]	validation_0-rmse:1.93419	validation_1-rmse:2.50788
# [1080]	validation_0-rmse:1.92961	validation_1-rmse:2.50759
# [1100]	validation_0-rmse:1.92506	validation_1-rmse:2.50666
# [1120]	validation_0-rmse:1.92014	validation_1-rmse:2.50479
# [1140]	validation_0-rmse:1.91504	validation_1-rmse:2.50323
# [1160]	validation_0-rmse:1.91041	validation_1-rmse:2.50183
# [1180]	validation_0-rmse:1.90624	validation_1-rmse:2.50163
# [1200]	validation_0-rmse:1.90348	validation_1-rmse:2.50130
# [1220]	validation_0-rmse:1.89985	validation_1-rmse:2.50059
# [1240]	validation_0-rmse:1.89747	validation_1-rmse:2.50000
# [1260]	validation_0-rmse:1.89111	validation_1-rmse:2.50127
# [1278]	validation_0-rmse:1.88833	validation_1-rmse:2.50199
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.499760053931753
# Score test : 2.3968247613527476
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.4998_test_2.3968_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.4998_test_2.3968_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.4998_test_2.3968_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.4998_test_2.3968_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1617549746090323
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1528672414303927
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1706063165092107
# Saving analysis by week ..
# Predict submission
# CV score: 2.61521
# cv_train_rmse :  2.6152075531804644
# cv_test_rmse  :  2.234032163849912
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1/rmse_cv_train_2.6152_rmse_cv_test_2.234_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1/rmse_cv_train_2.6152_rmse_cv_test_2.234_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1/rmse_cv_train_2.6152_rmse_cv_test_2.234_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.134770884882705
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0975120860653282
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.171390455605727
# Saving analysis by week ..
# ********************
# ********************
# WEEK =  2
# ********************
# ********************
# len base features =  444
# example base features = ['shift_10_roll_4_mean_item_id', 'shift_4_roll_2_std_Z_PUNTO_VENTA_Z_MARCA', 'shift_3_roll_2_mean_Z_MODELO_Z_PUNTO_VENTA', 'shift_2_roll_2_std_Z_PUNTO_VENTA', 'shift_10_roll_2_mean_Z_GAMA_Z_DEPARTAMENTO']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 444)
# X_test           (377384, 444)
# X_submission     (471730, 444)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2
# [22:54:51] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01545	validation_1-rmse:5.93908
# [20]	validation_0-rmse:5.69312	validation_1-rmse:5.62577
# [40]	validation_0-rmse:4.88754	validation_1-rmse:4.87758
# [60]	validation_0-rmse:4.10303	validation_1-rmse:4.19777
# [80]	validation_0-rmse:3.50219	validation_1-rmse:3.70784
# [100]	validation_0-rmse:3.07405	validation_1-rmse:3.38580
# [120]	validation_0-rmse:2.78711	validation_1-rmse:3.18583
# [140]	validation_0-rmse:2.60197	validation_1-rmse:3.06397
# [160]	validation_0-rmse:2.48219	validation_1-rmse:2.99170
# [180]	validation_0-rmse:2.40153	validation_1-rmse:2.94701
# [200]	validation_0-rmse:2.34672	validation_1-rmse:2.92042
# [220]	validation_0-rmse:2.30763	validation_1-rmse:2.90399
# [240]	validation_0-rmse:2.27788	validation_1-rmse:2.89086
# [260]	validation_0-rmse:2.25870	validation_1-rmse:2.88346
# [280]	validation_0-rmse:2.24572	validation_1-rmse:2.88000
# [300]	validation_0-rmse:2.23450	validation_1-rmse:2.87694
# [320]	validation_0-rmse:2.22207	validation_1-rmse:2.87396
# [340]	validation_0-rmse:2.20734	validation_1-rmse:2.87008
# [360]	validation_0-rmse:2.19550	validation_1-rmse:2.86687
# [380]	validation_0-rmse:2.17393	validation_1-rmse:2.85807
# [400]	validation_0-rmse:2.15360	validation_1-rmse:2.85309
# [420]	validation_0-rmse:2.14105	validation_1-rmse:2.85203
# [440]	validation_0-rmse:2.12464	validation_1-rmse:2.84848
# [460]	validation_0-rmse:2.10732	validation_1-rmse:2.84422
# [480]	validation_0-rmse:2.09036	validation_1-rmse:2.83751
# [500]	validation_0-rmse:2.07990	validation_1-rmse:2.83435
# [520]	validation_0-rmse:2.06482	validation_1-rmse:2.83246
# [540]	validation_0-rmse:2.05038	validation_1-rmse:2.82929
# [560]	validation_0-rmse:2.02901	validation_1-rmse:2.82745
# [580]	validation_0-rmse:2.01499	validation_1-rmse:2.82622
# [600]	validation_0-rmse:2.00434	validation_1-rmse:2.82446
# [620]	validation_0-rmse:1.99090	validation_1-rmse:2.82303
# [640]	validation_0-rmse:1.98112	validation_1-rmse:2.82077
# [660]	validation_0-rmse:1.96575	validation_1-rmse:2.81610
# [680]	validation_0-rmse:1.95228	validation_1-rmse:2.81168
# [700]	validation_0-rmse:1.93635	validation_1-rmse:2.80897
# [720]	validation_0-rmse:1.91914	validation_1-rmse:2.80417
# [740]	validation_0-rmse:1.90565	validation_1-rmse:2.80235
# [760]	validation_0-rmse:1.89185	validation_1-rmse:2.80103
# [780]	validation_0-rmse:1.87962	validation_1-rmse:2.79932
# [800]	validation_0-rmse:1.86670	validation_1-rmse:2.79733
# [820]	validation_0-rmse:1.85382	validation_1-rmse:2.79467
# [840]	validation_0-rmse:1.84103	validation_1-rmse:2.79280
# [860]	validation_0-rmse:1.83054	validation_1-rmse:2.79084
# [880]	validation_0-rmse:1.82010	validation_1-rmse:2.78799
# [900]	validation_0-rmse:1.81059	validation_1-rmse:2.78651
# [920]	validation_0-rmse:1.80082	validation_1-rmse:2.78472
# [940]	validation_0-rmse:1.79365	validation_1-rmse:2.78206
# [960]	validation_0-rmse:1.78379	validation_1-rmse:2.78076
# [980]	validation_0-rmse:1.77601	validation_1-rmse:2.77951
# [1000]	validation_0-rmse:1.76674	validation_1-rmse:2.77812
# [1020]	validation_0-rmse:1.75908	validation_1-rmse:2.77887
# [1040]	validation_0-rmse:1.75251	validation_1-rmse:2.77780
# [1060]	validation_0-rmse:1.74491	validation_1-rmse:2.77781
# [1080]	validation_0-rmse:1.73620	validation_1-rmse:2.77621
# [1100]	validation_0-rmse:1.72890	validation_1-rmse:2.77601
# [1120]	validation_0-rmse:1.72046	validation_1-rmse:2.77549
# [1140]	validation_0-rmse:1.71366	validation_1-rmse:2.77398
# [1160]	validation_0-rmse:1.70361	validation_1-rmse:2.77333
# [1180]	validation_0-rmse:1.69557	validation_1-rmse:2.77335
# [1200]	validation_0-rmse:1.68787	validation_1-rmse:2.77251
# [1220]	validation_0-rmse:1.67637	validation_1-rmse:2.77080
# [1240]	validation_0-rmse:1.67110	validation_1-rmse:2.76978
# [1260]	validation_0-rmse:1.66429	validation_1-rmse:2.77172
# [1279]	validation_0-rmse:1.65948	validation_1-rmse:2.77151
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.7697655669327452
# Score test : 2.787028514390623
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2/rmse_val_2.7698_test_2.787_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2/rmse_val_2.7698_test_2.787_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2/rmse_val_2.7698_test_2.787_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2/rmse_val_2.7698_test_2.787_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.032756451625922
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.049221136441298
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0161573146001914
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2
# [22:57:22] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10018	validation_1-rmse:5.76363
# [20]	validation_0-rmse:5.77549	validation_1-rmse:5.45455
# [40]	validation_0-rmse:4.95033	validation_1-rmse:4.76165
# [60]	validation_0-rmse:4.13905	validation_1-rmse:4.12075
# [80]	validation_0-rmse:3.51737	validation_1-rmse:3.65653
# [100]	validation_0-rmse:3.08218	validation_1-rmse:3.34666
# [120]	validation_0-rmse:2.78759	validation_1-rmse:3.14974
# [140]	validation_0-rmse:2.59812	validation_1-rmse:3.02845
# [160]	validation_0-rmse:2.46502	validation_1-rmse:2.95158
# [180]	validation_0-rmse:2.37090	validation_1-rmse:2.90264
# [200]	validation_0-rmse:2.30893	validation_1-rmse:2.86781
# [220]	validation_0-rmse:2.27162	validation_1-rmse:2.84706
# [240]	validation_0-rmse:2.24460	validation_1-rmse:2.83191
# [260]	validation_0-rmse:2.22546	validation_1-rmse:2.82026
# [280]	validation_0-rmse:2.20967	validation_1-rmse:2.81158
# [300]	validation_0-rmse:2.19549	validation_1-rmse:2.80265
# [320]	validation_0-rmse:2.18530	validation_1-rmse:2.79650
# [340]	validation_0-rmse:2.17198	validation_1-rmse:2.78939
# [360]	validation_0-rmse:2.15698	validation_1-rmse:2.78467
# [380]	validation_0-rmse:2.14122	validation_1-rmse:2.77999
# [400]	validation_0-rmse:2.11875	validation_1-rmse:2.78058
# [420]	validation_0-rmse:2.09893	validation_1-rmse:2.78041
# [440]	validation_0-rmse:2.07847	validation_1-rmse:2.77888
# [460]	validation_0-rmse:2.06533	validation_1-rmse:2.77120
# [480]	validation_0-rmse:2.05131	validation_1-rmse:2.76421
# [500]	validation_0-rmse:2.03496	validation_1-rmse:2.75996
# [520]	validation_0-rmse:2.02530	validation_1-rmse:2.75640
# [540]	validation_0-rmse:2.00945	validation_1-rmse:2.75451
# [560]	validation_0-rmse:1.98796	validation_1-rmse:2.75057
# [580]	validation_0-rmse:1.97203	validation_1-rmse:2.75078
# [600]	validation_0-rmse:1.95042	validation_1-rmse:2.74825
# [620]	validation_0-rmse:1.92959	validation_1-rmse:2.74627
# [640]	validation_0-rmse:1.91620	validation_1-rmse:2.74384
# [660]	validation_0-rmse:1.89925	validation_1-rmse:2.74510
# [680]	validation_0-rmse:1.88275	validation_1-rmse:2.74159
# [700]	validation_0-rmse:1.87139	validation_1-rmse:2.74174
# [720]	validation_0-rmse:1.86000	validation_1-rmse:2.73911
# [740]	validation_0-rmse:1.85128	validation_1-rmse:2.73879
# [760]	validation_0-rmse:1.84305	validation_1-rmse:2.73712
# [780]	validation_0-rmse:1.83085	validation_1-rmse:2.73680
# [800]	validation_0-rmse:1.82155	validation_1-rmse:2.73566
# [820]	validation_0-rmse:1.81368	validation_1-rmse:2.73445
# [840]	validation_0-rmse:1.80349	validation_1-rmse:2.73446
# [860]	validation_0-rmse:1.79540	validation_1-rmse:2.73681
# [875]	validation_0-rmse:1.78761	validation_1-rmse:2.73670
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.7335405175202565
# Score test : 2.6931174908927975
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.7335_test_2.6931_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.7335_test_2.6931_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.7335_test_2.6931_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.7335_test_2.6931_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9998441421510578
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.970099697943202
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0291526226373167
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2
# [22:59:21] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85200	validation_1-rmse:6.25717
# [20]	validation_0-rmse:5.53409	validation_1-rmse:5.94081
# [40]	validation_0-rmse:4.75198	validation_1-rmse:5.18368
# [60]	validation_0-rmse:3.99057	validation_1-rmse:4.48754
# [80]	validation_0-rmse:3.40662	validation_1-rmse:3.98015
# [100]	validation_0-rmse:3.00462	validation_1-rmse:3.64002
# [120]	validation_0-rmse:2.72762	validation_1-rmse:3.42024
# [140]	validation_0-rmse:2.55350	validation_1-rmse:3.28509
# [160]	validation_0-rmse:2.43816	validation_1-rmse:3.19463
# [180]	validation_0-rmse:2.36137	validation_1-rmse:3.13518
# [200]	validation_0-rmse:2.31034	validation_1-rmse:3.09577
# [220]	validation_0-rmse:2.27187	validation_1-rmse:3.06578
# [240]	validation_0-rmse:2.24651	validation_1-rmse:3.04606
# [260]	validation_0-rmse:2.22619	validation_1-rmse:3.02976
# [280]	validation_0-rmse:2.21328	validation_1-rmse:3.01926
# [300]	validation_0-rmse:2.20400	validation_1-rmse:3.01198
# [320]	validation_0-rmse:2.19272	validation_1-rmse:3.00375
# [340]	validation_0-rmse:2.18396	validation_1-rmse:2.99716
# [360]	validation_0-rmse:2.17395	validation_1-rmse:2.98819
# [380]	validation_0-rmse:2.15497	validation_1-rmse:2.98076
# [400]	validation_0-rmse:2.13401	validation_1-rmse:2.97113
# [420]	validation_0-rmse:2.12078	validation_1-rmse:2.96563
# [440]	validation_0-rmse:2.10841	validation_1-rmse:2.96111
# [460]	validation_0-rmse:2.09586	validation_1-rmse:2.95579
# [480]	validation_0-rmse:2.08677	validation_1-rmse:2.95052
# [500]	validation_0-rmse:2.06931	validation_1-rmse:2.94357
# [520]	validation_0-rmse:2.05855	validation_1-rmse:2.93970
# [540]	validation_0-rmse:2.04543	validation_1-rmse:2.93916
# [560]	validation_0-rmse:2.03001	validation_1-rmse:2.93803
# [580]	validation_0-rmse:2.01655	validation_1-rmse:2.93875
# [600]	validation_0-rmse:1.99877	validation_1-rmse:2.93945
# [620]	validation_0-rmse:1.98767	validation_1-rmse:2.93841
# [640]	validation_0-rmse:1.97118	validation_1-rmse:2.93610
# [660]	validation_0-rmse:1.95853	validation_1-rmse:2.93539
# [680]	validation_0-rmse:1.94345	validation_1-rmse:2.93373
# [700]	validation_0-rmse:1.92697	validation_1-rmse:2.93453
# [720]	validation_0-rmse:1.90611	validation_1-rmse:2.93639
# [721]	validation_0-rmse:1.90595	validation_1-rmse:2.93637
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.9335542312066583
# Score test : 2.515677340245629
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2/rmse_val_2.9336_test_2.5157_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2/rmse_val_2.9336_test_2.5157_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2/rmse_val_2.9336_test_2.5157_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2/rmse_val_2.9336_test_2.5157_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9740672308338414
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.947287635488014
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.000488372467954
# Saving analysis by week ..
# Predict submission
# CV score: 2.81363
# cv_train_rmse :  2.8136325856834876
# cv_test_rmse  :  2.593863556534376
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_2
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_2/rmse_cv_train_2.8136_rmse_cv_test_2.5939_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_2/rmse_cv_train_2.8136_rmse_cv_test_2.5939_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_2/rmse_cv_train_2.8136_rmse_cv_test_2.5939_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.96238800402676
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.919078089675092
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0047624902779044
# Saving analysis by week ..
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2
# [23:01:25] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01546	validation_1-rmse:5.93908
# [20]	validation_0-rmse:5.69501	validation_1-rmse:5.62359
# [40]	validation_0-rmse:4.91068	validation_1-rmse:4.87257
# [60]	validation_0-rmse:4.16411	validation_1-rmse:4.18073
# [80]	validation_0-rmse:3.61092	validation_1-rmse:3.70042
# [100]	validation_0-rmse:3.23041	validation_1-rmse:3.39259
# [120]	validation_0-rmse:2.98198	validation_1-rmse:3.20821
# [140]	validation_0-rmse:2.82450	validation_1-rmse:3.10415
# [160]	validation_0-rmse:2.72773	validation_1-rmse:3.04521
# [180]	validation_0-rmse:2.66470	validation_1-rmse:3.01307
# [200]	validation_0-rmse:2.62258	validation_1-rmse:2.99464
# [220]	validation_0-rmse:2.59536	validation_1-rmse:2.98380
# [240]	validation_0-rmse:2.57601	validation_1-rmse:2.97641
# [260]	validation_0-rmse:2.56298	validation_1-rmse:2.97186
# [280]	validation_0-rmse:2.55201	validation_1-rmse:2.96874
# [300]	validation_0-rmse:2.54424	validation_1-rmse:2.96678
# [320]	validation_0-rmse:2.53626	validation_1-rmse:2.96522
# [340]	validation_0-rmse:2.52953	validation_1-rmse:2.96482
# [360]	validation_0-rmse:2.52353	validation_1-rmse:2.96417
# [380]	validation_0-rmse:2.51657	validation_1-rmse:2.96451
# [394]	validation_0-rmse:2.51040	validation_1-rmse:2.96445
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.964123482742587
# Score test : 2.8328400059734054
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2/rmse_val_2.9641_test_2.8328_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2/rmse_val_2.9641_test_2.8328_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2/rmse_val_2.9641_test_2.8328_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2/rmse_val_2.9641_test_2.8328_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9392918269867556
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.7182523002523173
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1375955214008284
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_2
# [23:01:44] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
# ...
# [140]	validation_0-rmse:2.72882	validation_1-rmse:3.48924
# [160]	validation_0-rmse:2.62282	validation_1-rmse:3.40341
# [180]	validation_0-rmse:2.54934	validation_1-rmse:3.34366
# [200]	validation_0-rmse:2.50291	validation_1-rmse:3.30515
# [220]	validation_0-rmse:2.46963	validation_1-rmse:3.27728
# [240]	validation_0-rmse:2.44304	validation_1-rmse:3.25743
# [260]	validation_0-rmse:2.41978	validation_1-rmse:3.24130
# [280]	validation_0-rmse:2.40312	validation_1-rmse:3.22907
# [300]	validation_0-rmse:2.38761	validation_1-rmse:3.21662
# [320]	validation_0-rmse:2.37489	validation_1-rmse:3.20674
# [340]	validation_0-rmse:2.36336	validation_1-rmse:3.19931
# [360]	validation_0-rmse:2.34844	validation_1-rmse:3.18923
# [380]	validation_0-rmse:2.31682	validation_1-rmse:3.18394
# [400]	validation_0-rmse:2.28871	validation_1-rmse:3.18098
# [420]	validation_0-rmse:2.27242	validation_1-rmse:3.17445
# [440]	validation_0-rmse:2.25486	validation_1-rmse:3.16832
# [460]	validation_0-rmse:2.23786	validation_1-rmse:3.16616
# [480]	validation_0-rmse:2.22532	validation_1-rmse:3.16416
# [500]	validation_0-rmse:2.20206	validation_1-rmse:3.16301
# [520]	validation_0-rmse:2.18959	validation_1-rmse:3.15961
# [540]	validation_0-rmse:2.16933	validation_1-rmse:3.15871
# [560]	validation_0-rmse:2.15071	validation_1-rmse:3.15510
# [580]	validation_0-rmse:2.13616	validation_1-rmse:3.15501
# [600]	validation_0-rmse:2.12067	validation_1-rmse:3.15598
# [609]	validation_0-rmse:2.11497	validation_1-rmse:3.15581
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.1534505644246615
# Score test : 2.756899863424062
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_3/rmse_val_3.1535_test_2.7569_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_3/rmse_val_3.1535_test_2.7569_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_3/rmse_val_3.1535_test_2.7569_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_3/rmse_val_3.1535_test_2.7569_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9039557187938612
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9270103039601363
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8806185276890048
# Saving analysis by week ..
# Predict submission
# CV score: 2.94634
# cv_train_rmse :  2.946338059451372
# cv_test_rmse  :  2.941924920984112
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_3
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_3/rmse_cv_train_2.9463_rmse_cv_test_2.9419_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_3/rmse_cv_train_2.9463_rmse_cv_test_2.9419_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_3/rmse_cv_train_2.9463_rmse_cv_test_2.9419_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0166971107154685
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0988072652772094
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9310987897971053
# Saving analysis by week ..
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_3
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_3
# [23:09:52] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01555	validation_1-rmse:5.93918
# [20]	validation_0-rmse:5.70939	validation_1-rmse:5.64234
# [40]	validation_0-rmse:4.97495	validation_1-rmse:4.98476
# [60]	validation_0-rmse:4.28085	validation_1-rmse:4.40477
# [80]	validation_0-rmse:3.77057	validation_1-rmse:4.00339
# [100]	validation_0-rmse:3.42477	validation_1-rmse:3.75147
# [120]	validation_0-rmse:3.20224	validation_1-rmse:3.59802
# [140]	validation_0-rmse:3.05336	validation_1-rmse:3.50999
# [160]	validation_0-rmse:2.96204	validation_1-rmse:3.45979
# [180]	validation_0-rmse:2.89401	validation_1-rmse:3.42873
# [200]	validation_0-rmse:2.84994	validation_1-rmse:3.41222
# [220]	validation_0-rmse:2.82138	validation_1-rmse:3.40024
# [240]	validation_0-rmse:2.80060	validation_1-rmse:3.39380
# [260]	validation_0-rmse:2.78310	validation_1-rmse:3.39203
# [280]	validation_0-rmse:2.76998	validation_1-rmse:3.39079
# [300]	validation_0-rmse:2.75966	validation_1-rmse:3.38927
# [320]	validation_0-rmse:2.75369	validation_1-rmse:3.38751
# [340]	validation_0-rmse:2.73756	validation_1-rmse:3.38774
# [360]	validation_0-rmse:2.72587	validation_1-rmse:3.38707
# [380]	validation_0-rmse:2.71520	validation_1-rmse:3.38784
# [395]	validation_0-rmse:2.70959	validation_1-rmse:3.38718
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.386653560409742
# Score test : 3.113680178110834
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_3/rmse_val_3.3867_test_3.1137_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_3/rmse_val_3.3867_test_3.1137_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_3/rmse_val_3.3867_test_3.1137_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_3/rmse_val_3.3867_test_3.1137_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8366584107140935
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.6413187097361175
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0131321686277346
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_3
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_3
# [23:10:11] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10028	validation_1-rmse:5.76374
# [20]	validation_0-rmse:5.79186	validation_1-rmse:5.46795
# [40]	validation_0-rmse:5.05157	validation_1-rmse:4.81326
# [60]	validation_0-rmse:4.35360	validation_1-rmse:4.23413
# [80]	validation_0-rmse:3.83981	validation_1-rmse:3.82365
# [100]	validation_0-rmse:3.49257	validation_1-rmse:3.55354
# [120]	validation_0-rmse:3.26628	validation_1-rmse:3.38388
# [140]	validation_0-rmse:3.12317	validation_1-rmse:3.27975
# [160]	validation_0-rmse:3.03046	validation_1-rmse:3.21900
# [180]	validation_0-rmse:2.97149	validation_1-rmse:3.18170
# [200]	validation_0-rmse:2.92741	validation_1-rmse:3.15695
# [220]	validation_0-rmse:2.89772	validation_1-rmse:3.13934
# [240]	validation_0-rmse:2.87324	validation_1-rmse:3.12796
# [260]	validation_0-rmse:2.85920	validation_1-rmse:3.12076
# [280]	validation_0-rmse:2.85048	validation_1-rmse:3.11650
# [300]	validation_0-rmse:2.83851	validation_1-rmse:3.11127
# [320]	validation_0-rmse:2.83178	validation_1-rmse:3.10938
# [340]	validation_0-rmse:2.80537	validation_1-rmse:3.10618
# [360]	validation_0-rmse:2.79021	validation_1-rmse:3.10621
# [380]	validation_0-rmse:2.77492	validation_1-rmse:3.10376
# [400]	validation_0-rmse:2.76137	validation_1-rmse:3.09614
# [420]	validation_0-rmse:2.75357	validation_1-rmse:3.09435
# [440]	validation_0-rmse:2.73841	validation_1-rmse:3.09150
# [460]	validation_0-rmse:2.71758	validation_1-rmse:3.09198
# [480]	validation_0-rmse:2.69875	validation_1-rmse:3.09122
# [500]	validation_0-rmse:2.68264	validation_1-rmse:3.09242
# [511]	validation_0-rmse:2.66969	validation_1-rmse:3.09296
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.090215643106823
# Score test : 3.0293405459305784
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_3/rmse_val_3.0902_test_3.0293_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_3/rmse_val_3.0902_test_3.0293_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_3/rmse_val_3.0902_test_3.0293_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_3/rmse_val_3.0902_test_3.0293_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9141041875013372
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.7705170162473405
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0476472294804404
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_3
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_3
# [23:10:32] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85211	validation_1-rmse:6.25728
# [20]	validation_0-rmse:5.54908	validation_1-rmse:5.95581
# [40]	validation_0-rmse:4.82521	validation_1-rmse:5.24856
# [60]	validation_0-rmse:4.14511	validation_1-rmse:4.61083
# [80]	validation_0-rmse:3.64218	validation_1-rmse:4.16019
# [100]	validation_0-rmse:3.29619	validation_1-rmse:3.86751
# [120]	validation_0-rmse:3.07333	validation_1-rmse:3.69180
# [140]	validation_0-rmse:2.93173	validation_1-rmse:3.58646
# [160]	validation_0-rmse:2.84342	validation_1-rmse:3.52423
# [180]	validation_0-rmse:2.78517	validation_1-rmse:3.48677
# [200]	validation_0-rmse:2.74477	validation_1-rmse:3.46402
# [220]	validation_0-rmse:2.71207	validation_1-rmse:3.44617
# [240]	validation_0-rmse:2.69316	validation_1-rmse:3.43735
# [260]	validation_0-rmse:2.68029	validation_1-rmse:3.42933
# [280]	validation_0-rmse:2.67145	validation_1-rmse:3.42482
# [300]	validation_0-rmse:2.66458	validation_1-rmse:3.42260
# [320]	validation_0-rmse:2.65801	validation_1-rmse:3.42122
# [340]	validation_0-rmse:2.65328	validation_1-rmse:3.41956
# [360]	validation_0-rmse:2.64603	validation_1-rmse:3.41622
# [380]	validation_0-rmse:2.63976	validation_1-rmse:3.41315
# [400]	validation_0-rmse:2.63340	validation_1-rmse:3.41112
# [420]	validation_0-rmse:2.62553	validation_1-rmse:3.41004
# [440]	validation_0-rmse:2.60954	validation_1-rmse:3.40830
# [460]	validation_0-rmse:2.59708	validation_1-rmse:3.40631
# [480]	validation_0-rmse:2.58498	validation_1-rmse:3.40490
# [500]	validation_0-rmse:2.57593	validation_1-rmse:3.40385
# [520]	validation_0-rmse:2.56441	validation_1-rmse:3.40305
# [540]	validation_0-rmse:2.55490	validation_1-rmse:3.40285
# [560]	validation_0-rmse:2.54179	validation_1-rmse:3.40300
# [580]	validation_0-rmse:2.53317	validation_1-rmse:3.40238
# [600]	validation_0-rmse:2.52250	validation_1-rmse:3.40008
# [620]	validation_0-rmse:2.50020	validation_1-rmse:3.39730
# [640]	validation_0-rmse:2.47971	validation_1-rmse:3.39638
# [660]	validation_0-rmse:2.46431	validation_1-rmse:3.39486
# [680]	validation_0-rmse:2.45139	validation_1-rmse:3.39543
# [700]	validation_0-rmse:2.43464	validation_1-rmse:3.39357
# [720]	validation_0-rmse:2.41586	validation_1-rmse:3.39085
# [740]	validation_0-rmse:2.39933	validation_1-rmse:3.39026
# [760]	validation_0-rmse:2.38621	validation_1-rmse:3.39021
# [780]	validation_0-rmse:2.37511	validation_1-rmse:3.38928
# [800]	validation_0-rmse:2.36826	validation_1-rmse:3.38894
# [820]	validation_0-rmse:2.35765	validation_1-rmse:3.38648
# [840]	validation_0-rmse:2.34899	validation_1-rmse:3.38526
# [860]	validation_0-rmse:2.34209	validation_1-rmse:3.38573
# [880]	validation_0-rmse:2.32836	validation_1-rmse:3.38576
# [889]	validation_0-rmse:2.32281	validation_1-rmse:3.38504
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.3848787066090886
# Score test : 2.907200995949498
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_3/rmse_val_3.3849_test_2.9072_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_3/rmse_val_3.3849_test_2.9072_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_3/rmse_val_3.3849_test_2.9072_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_3/rmse_val_3.3849_test_2.9072_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0683105803175668
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.01223721045984
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.122903370892792
# Saving analysis by week ..
# Predict submission
# CV score: 3.29020
# cv_train_rmse :  3.2902006138809963
# cv_test_rmse  :  2.9659404129087337
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_3
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_3/rmse_cv_train_3.2902_rmse_cv_test_2.9659_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_3/rmse_cv_train_3.2902_rmse_cv_test_2.9659_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_3/rmse_cv_train_3.2902_rmse_cv_test_2.9659_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8969022446420103
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.7370816483166698
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.044266029296881
# Saving analysis by week ..
