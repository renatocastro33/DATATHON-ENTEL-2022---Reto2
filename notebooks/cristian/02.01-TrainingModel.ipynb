# %%
import sys
sys.path.insert(1, '../../Src')
from utils.preprocessing import *
import training


import numpy as np
import pandas as pd
from math import ceil
import warnings
import os

SEED = 42
seed_everything(SEED)
PATH_DATASET = '../../dataset/'
PATH_RESULTS = '../../results/Demanda/'
FILL = False
TARGET = 'Demanda'
N_FOLDS = 3
N_FEATURE_IMPORTANCE = 15



plt.rcParams['axes.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)
# %load_ext autoreload
# %autoreload 2

# %%
submission_top_reference = 'submission_weeks2_repz12_rmse_kaggle_0.686.csv'
print('reading .. ',os.path.join('../../results/',submission_top_reference))
result = pd.read_csv(os.path.join('../../results/',submission_top_reference))
# Out:
# reading ..  ../../results/submission_weeks2_repz12_rmse_kaggle_0.686.csv

# %%
descriptive_columns = ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']
reverse_mapping_file = '../../utils/reverse_dict_mapping_list.txt'

result[['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']] = result['ID'].str.split('|',expand=True)

with open(reverse_mapping_file, 'rb') as f:
    reverse_mapping = pickle.load( f)
    
descriptive_columns = ['Z_MARCA', 'Z_GAMA', 'Z_MODELO',
                       'Z_DEPARTAMENTO', 'Z_PUNTO_VENTA']
i=0
for column in descriptive_columns:
    if column in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']:
        inv_reverse_mapping = {v: k for k, v in reverse_mapping[i].items()}

        result[column] = result[column].map(inv_reverse_mapping)
    i+=1
    
result = result.rename(columns = {TARGET: TARGET+'_real'})

# %%
result.head(1)
# Out:
#                                                   ID  Demanda_real Z_MODELO  \
# 0  009e0874cc07b2180b2b2b1039321041a1f42e66693c49...      0.010752  MOD_170
#
#   Z_PUNTO_VENTA Z_GAMA     Z_WEEK
# 0     PVENT_259  GAM_2  SEMANA_51

# %%
print('Reading dataset')
SHIFT=1
df_train  = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_train_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))
df_test   = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_test_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))

gc.collect()
print('df_train size :',df_train.shape)
print('df_test size  :',df_test.shape)
# Out:
# Reading dataset
# df_train size : (2358650, 1111)
# df_test size  : (471730, 1111)

# %%
features_names = set(df_train.columns)-set([TARGET,'date_block_num',TARGET+'_clipped','release','item_id',
                                            'Z_WEEK_DATE', 'Z_WEEK','date_block_num','year',
                                            'month', 'is_month_end', 'tm_m_end','is_month_start','tm_wm', 'tm_w_end','is_quarter_start','is_year_start',
                                             'day_of_week',
                                            'day_of_year', 'day',
                                            #'Z_MODELO','Z_PUNTO_VENTA','Z_DEPARTAMENTO',
                                            #'Z_GAMA','Z_MARCA', 
                                           ]) 
print(len(features_names))
features_names = list(features_names)
# Out:
# 1093

# %%
print(len(features_names))
features_names = [e for e in features_names if not any(prefix in e for prefix in ['enc_'])]
print(len(features_names))
# Out:
# 1093
# 1045

# %%
for columns in features_names:
    if columns in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA']:
        print(columns)
# Out:
# Z_MODELO
# Z_PUNTO_VENTA
# Z_GAMA

# %%
df_train['week_of_month'] = df_train['week_of_month'].astype('category')
df_test['week_of_month']  = df_test['week_of_month'].astype('category')

# %%
total_features_names = features_names.copy()

# %%
def get_feature_names_shift(shift,total_features_names):
    features_names = []

    for column in total_features_names:
        if 'shift' in column:
            number = column.split('shift_')[1]
            number = int(number.split('_')[0])
            if number>=shift and number<=(shift+3):
                features_names.append(column)
        else:
            features_names.append(column)
    return features_names

# %%
TRAIN_START = '2021-08-01'
TEST_START = '2022-03-01'
TEST_END   = '2022-05-01'
print(df_train.shape)
df_train = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)]
print(df_train.shape)
# Out:
# (2358650, 1111)
# (1839747, 1111)

# %%
PATH_RESULTS = '../../results/Demanda_ventana3_no_enc/'
training.PATH_RESULTS = PATH_RESULTS
training.submission_analysis.TARGET  = TARGET


for SHIFT in range(1,11):
    print('*'*20)
    print('*'*20)
    print('WEEK = ',SHIFT)
    print('*'*20)
    print('*'*20)

    features_names = get_feature_names_shift(SHIFT,total_features_names)
    print('len base features = ',len(features_names))
    print('example base features =',features_names[:5])
    
    ################### CV MODEL RANDOM SPLIT ###############


    
    for idx,model_type in enumerate(['xgboost']):

    
        X_train      = df_train[((df_train['Z_WEEK_DATE'] >= TRAIN_START) &(df_train['Z_WEEK_DATE'] < TEST_START))&
                               (df_train['Z_WEEK_DATE'] != '2022-04-11')].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT model_type = ',model_type,'c_model_v2')
        print('*'*20)

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]
        X_train = X_train[features_names]
        X_test  = X_test[features_names]
        X_submission = df_test[features_names]        
        


        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        model_version = 'c_model_v2'
        training.TARGET = TARGET
        training.SHIFT = SHIFT

        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                            X_test,y_test,X_submission,df_test,result,N_FOLDS)

    
        
        
        #'''
        if idx ==0 :
            features_names = list(df_feature_importance['feature'][:30].values)
            
        ################### CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE ###############
        important_features = list(df_feature_importance[:N_FEATURE_IMPORTANCE]['feature'])
        
        X_train      = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)&(df_train['Z_WEEK_DATE'] < TEST_START)].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]

        X_train = X_train[important_features]
        X_test  = X_test[important_features]
        X_submission = df_test[important_features]

        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type = ',model_type,'c_model_v3')
        print('*'*20)
        
        model_version = 'c_model_v3'
        training.TARGET = TARGET
        training.SHIFT = SHIFT


        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                               X_test,y_test,X_submission,df_test,result,N_FOLDS)
        #'''
# Out:
# ********************
# ********************
# WEEK =  1
# ********************
# ********************
# len base features =  266
# example base features = ['shift_1_roll_4_std_Z_MODELO_Z_DEPARTAMENTO', 'shift_1_roll_2_std_Z_GAMA_Z_MARCA', 'shift_2_roll_4_mean_Z_MODELO_Z_GAMA', 'shift_1_roll_2_mean_Z_PUNTO_VENTA', 'Demanda_lag_shift_3']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 266)
# X_test           (377384, 266)
# X_submission     (471730, 266)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_1
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_1
# [14:42:19] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01540	validation_1-rmse:5.93902
# [20]	validation_0-rmse:5.68031	validation_1-rmse:5.61363
# [40]	validation_0-rmse:4.82347	validation_1-rmse:4.84176
# [60]	validation_0-rmse:3.98261	validation_1-rmse:4.13875
# [80]	validation_0-rmse:3.34443	validation_1-rmse:3.63601
# [100]	validation_0-rmse:2.89454	validation_1-rmse:3.31052
# [120]	validation_0-rmse:2.58646	validation_1-rmse:3.10558
# [140]	validation_0-rmse:2.37878	validation_1-rmse:2.98029
# [160]	validation_0-rmse:2.24239	validation_1-rmse:2.91157
# [180]	validation_0-rmse:2.15572	validation_1-rmse:2.87072
# [200]	validation_0-rmse:2.10031	validation_1-rmse:2.84603
# [220]	validation_0-rmse:2.06118	validation_1-rmse:2.82959
# [240]	validation_0-rmse:2.03289	validation_1-rmse:2.82261
# [140]	validation_0-rmse:2.40541	validation_1-rmse:2.97214
# [160]	validation_0-rmse:2.28092	validation_1-rmse:2.86331
# [180]	validation_0-rmse:2.19985	validation_1-rmse:2.79381
# [200]	validation_0-rmse:2.14295	validation_1-rmse:2.74850
# [220]	validation_0-rmse:2.10015	validation_1-rmse:2.71119
# [240]	validation_0-rmse:2.06851	validation_1-rmse:2.69272
# [260]	validation_0-rmse:2.03497	validation_1-rmse:2.68123
# [280]	validation_0-rmse:2.00117	validation_1-rmse:2.67137
# [300]	validation_0-rmse:1.98610	validation_1-rmse:2.66446
# [320]	validation_0-rmse:1.97399	validation_1-rmse:2.65771
# [340]	validation_0-rmse:1.96564	validation_1-rmse:2.65132
# [360]	validation_0-rmse:1.94773	validation_1-rmse:2.64955
# [380]	validation_0-rmse:1.92803	validation_1-rmse:2.64571
# [400]	validation_0-rmse:1.90705	validation_1-rmse:2.64275
# [420]	validation_0-rmse:1.89483	validation_1-rmse:2.63731
# [440]	validation_0-rmse:1.88338	validation_1-rmse:2.63563
# [460]	validation_0-rmse:1.87271	validation_1-rmse:2.63562
# [480]	validation_0-rmse:1.86251	validation_1-rmse:2.63454
# [500]	validation_0-rmse:1.84847	validation_1-rmse:2.63349
# [520]	validation_0-rmse:1.83121	validation_1-rmse:2.63379
# [534]	validation_0-rmse:1.81939	validation_1-rmse:2.63645
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.6327880694916135
# Score test : 2.8703630308168617
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.6328_test_2.8704_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.6328_test_2.8704_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.6328_test_2.8704_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.6328_test_2.8704_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1474579811155476
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.118686744946334
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.175848808649726
# Saving analysis by week ..
# Predict submission
# CV score: 2.73792
# cv_train_rmse :  2.7379249543697863
# cv_test_rmse  :  2.787375850851392
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/shift_1
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/shift_1/rmse_cv_train_2.7379_rmse_cv_test_2.7874_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/shift_1/rmse_cv_train_2.7379_rmse_cv_test_2.7874_prediction_test.png
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/shift_1/rmse_cv_train_2.7379_rmse_cv_test_2.7874_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.10844526212694
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0531517104557913
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.16232534569235
# Saving analysis by week ..
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift_1
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift_1
# [14:52:35] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01540	validation_1-rmse:5.93902
# [20]	validation_0-rmse:5.68197	validation_1-rmse:5.61057
# [40]	validation_0-rmse:4.85254	validation_1-rmse:4.81822
# [60]	validation_0-rmse:4.06503	validation_1-rmse:4.09626
# [80]	validation_0-rmse:3.48368	validation_1-rmse:3.58936
# [100]	validation_0-rmse:3.08943	validation_1-rmse:3.26267
# [120]	validation_0-rmse:2.83630	validation_1-rmse:3.06916
# [140]	validation_0-rmse:2.67811	validation_1-rmse:2.95798
# [160]	validation_0-rmse:2.58136	validation_1-rmse:2.89401
# [180]	validation_0-rmse:2.52181	validation_1-rmse:2.86244
# [200]	validation_0-rmse:2.48312	validation_1-rmse:2.84515
# [220]	validation_0-rmse:2.45700	validation_1-rmse:2.83824
# [240]	validation_0-rmse:2.44090	validation_1-rmse:2.83358
# [260]	validation_0-rmse:2.42833	validation_1-rmse:2.83206
# [280]	validation_0-rmse:2.41949	validation_1-rmse:2.83265
# [299]	validation_0-rmse:2.41127	validation_1-rmse:2.83196
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.8317000411748605
# Score test : 2.237020949042373
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.8317_test_2.237_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.8317_test_2.237_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.8317_test_2.237_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.8317_test_2.237_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0671019139732976
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9301681157765385
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.195511714918367
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_2/shift_1
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_2/shift_1
# [14:53:08] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10013	validation_1-rmse:5.76357
# [20]	validation_0-rmse:5.76331	validation_1-rmse:5.43727
# [40]	validation_0-rmse:4.90674	validation_1-rmse:4.67472
# [60]	validation_0-rmse:4.08405	validation_1-rmse:3.98509
# [80]	validation_0-rmse:3.47076	validation_1-rmse:3.51012
# [100]	validation_0-rmse:3.04478	validation_1-rmse:3.21224
# [120]	validation_0-rmse:2.77175	validation_1-rmse:3.04048
# [140]	validation_0-rmse:2.59914	validation_1-rmse:2.94790
# [160]	validation_0-rmse:2.49527	validation_1-rmse:2.90057
# [180]	validation_0-rmse:2.42995	validation_1-rmse:2.87669
# [200]	validation_0-rmse:2.38775	validation_1-rmse:2.86508
# [220]	validation_0-rmse:2.36184	validation_1-rmse:2.86118
# [240]	validation_0-rmse:2.34012	validation_1-rmse:2.86297
# [260]	validation_0-rmse:2.32641	validation_1-rmse:2.86584
# [264]	validation_0-rmse:2.32432	validation_1-rmse:2.86592
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.8605823750978536
# Score test : 2.19549215676436
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.8606_test_2.1955_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.8606_test_2.1955_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.8606_test_2.1955_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.8606_test_2.1955_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0672862762112234
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.92955704939419
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1963958406343154
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_1
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_1
# [14:53:39] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85195	validation_1-rmse:6.25711
# [20]	validation_0-rmse:5.52275	validation_1-rmse:5.92508
# [40]	validation_0-rmse:4.72438	validation_1-rmse:5.11850
# [60]	validation_0-rmse:3.97126	validation_1-rmse:4.36943
# [80]	validation_0-rmse:3.41458	validation_1-rmse:3.82659
# [100]	validation_0-rmse:3.04082	validation_1-rmse:3.45991
# [120]	validation_0-rmse:2.79947	validation_1-rmse:3.22358
# [140]	validation_0-rmse:2.64569	validation_1-rmse:3.07468
# [160]	validation_0-rmse:2.54918	validation_1-rmse:2.98254
# [180]	validation_0-rmse:2.49027	validation_1-rmse:2.92425
# [200]	validation_0-rmse:2.45230	validation_1-rmse:2.88745
# [220]	validation_0-rmse:2.42784	validation_1-rmse:2.86335
# [240]	validation_0-rmse:2.40829	validation_1-rmse:2.84702
# [260]	validation_0-rmse:2.39775	validation_1-rmse:2.83670
# [280]	validation_0-rmse:2.39044	validation_1-rmse:2.82991
# [300]	validation_0-rmse:2.38215	validation_1-rmse:2.82735
# [320]	validation_0-rmse:2.37561	validation_1-rmse:2.82542
# [340]	validation_0-rmse:2.37059	validation_1-rmse:2.82401
# [360]	validation_0-rmse:2.36455	validation_1-rmse:2.82419
# [380]	validation_0-rmse:2.35925	validation_1-rmse:2.82496
# [392]	validation_0-rmse:2.35743	validation_1-rmse:2.82553
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.8236962896809343
# Score test : 2.3594030093955856
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.8237_test_2.3594_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.8237_test_2.3594_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.8237_test_2.3594_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.8237_test_2.3594_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1056735729168565
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.013379090615315
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.194089111415926
# Saving analysis by week ..
# Predict submission
# CV score: 2.83870
# cv_train_rmse :  2.8387037712540457
# cv_test_rmse  :  2.225507999106475
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_1
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_1/rmse_cv_train_2.8387_rmse_cv_test_2.2255_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_1/rmse_cv_train_2.8387_rmse_cv_test_2.2255_prediction_test.png
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_1/rmse_cv_train_2.8387_rmse_cv_test_2.2255_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.075648619377379
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9486809997586072
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1952851166593907
# Saving analysis by week ..
# ********************
# ********************
# WEEK =  2
# ********************
# ********************
# len base features =  266
# example base features = ['shift_2_roll_4_mean_Z_MODELO_Z_GAMA', 'shift_5_roll_2_mean_Z_PUNTO_VENTA_Z_DEPARTAMENTO', 'Demanda_lag_shift_3', 'shift_3_roll_4_std_Z_GAMA', 'shift_2_roll_4_std_Z_PUNTO_VENTA_Z_DEPARTAMENTO']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 266)
# X_test           (377384, 266)
# X_submission     (471730, 266)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_2
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_2
# [14:54:55] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01558	validation_1-rmse:5.93922
# [20]	validation_0-rmse:5.70608	validation_1-rmse:5.64340
# [40]	validation_0-rmse:4.94748	validation_1-rmse:4.96850
# [60]	validation_0-rmse:4.21610	validation_1-rmse:4.37027
# [80]	validation_0-rmse:3.66914	validation_1-rmse:3.95645
# [100]	validation_0-rmse:3.27638	validation_1-rmse:3.69499
# [120]	validation_0-rmse:3.01859	validation_1-rmse:3.53768
# [140]	validation_0-rmse:2.84033	validation_1-rmse:3.43639
# [160]	validation_0-rmse:2.71267	validation_1-rmse:3.37288
# [180]	validation_0-rmse:2.63108	validation_1-rmse:3.33975
# [200]	validation_0-rmse:2.56955	validation_1-rmse:3.31764
# [220]	validation_0-rmse:2.52477	validation_1-rmse:3.30186
# [240]	validation_0-rmse:2.49285	validation_1-rmse:3.29142
# [260]	validation_0-rmse:2.46700	validation_1-rmse:3.28350
# [280]	validation_0-rmse:2.45067	validation_1-rmse:3.27834
# [300]	validation_0-rmse:2.43627	validation_1-rmse:3.27136
# [320]	validation_0-rmse:2.42469	validation_1-rmse:3.26663
# [340]	validation_0-rmse:2.41412	validation_1-rmse:3.26181
# [360]	validation_0-rmse:2.39710	validation_1-rmse:3.25703
# [380]	validation_0-rmse:2.36842	validation_1-rmse:3.25350
# [400]	validation_0-rmse:2.34696	validation_1-rmse:3.25137
# [420]	validation_0-rmse:2.32444	validation_1-rmse:3.24691
# [440]	validation_0-rmse:2.30389	validation_1-rmse:3.24330
# [460]	validation_0-rmse:2.28084	validation_1-rmse:3.24107
# [480]	validation_0-rmse:2.26377	validation_1-rmse:3.24014
# [500]	validation_0-rmse:2.24159	validation_1-rmse:3.23910
# [520]	validation_0-rmse:2.21933	validation_1-rmse:3.24052
# [540]	validation_0-rmse:2.19355	validation_1-rmse:3.23834
# [560]	validation_0-rmse:2.16943	validation_1-rmse:3.23600
# [580]	validation_0-rmse:2.14562	validation_1-rmse:3.23726
# [600]	validation_0-rmse:2.13010	validation_1-rmse:3.23454
# [620]	validation_0-rmse:2.11708	validation_1-rmse:3.23307
# [640]	validation_0-rmse:2.10784	validation_1-rmse:3.23367
# [660]	validation_0-rmse:2.09532	validation_1-rmse:3.23405
# [677]	validation_0-rmse:2.08140	validation_1-rmse:3.23539
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.2316098675986504
# Score test : 3.814474830989219
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_2/rmse_val_3.2316_test_3.8145_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_2/rmse_val_3.2316_test_3.8145_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_2/rmse_val_3.2316_test_3.8145_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_2/rmse_val_3.2316_test_3.8145_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.2135453829188814
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.2824806987147905
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.142393097561098
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_2/shift_2
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_2/shift_2
# [14:59:19] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.
# [200]	validation_0-rmse:2.59169	validation_1-rmse:3.32643
# [220]	validation_0-rmse:2.54789	validation_1-rmse:3.30079
# [240]	validation_0-rmse:2.51875	validation_1-rmse:3.27756
# [260]	validation_0-rmse:2.49226	validation_1-rmse:3.25932
# [280]	validation_0-rmse:2.47242	validation_1-rmse:3.24860
# [300]	validation_0-rmse:2.45572	validation_1-rmse:3.23897
# [320]	validation_0-rmse:2.43428	validation_1-rmse:3.23163
# [340]	validation_0-rmse:2.41166	validation_1-rmse:3.22457
# [360]	validation_0-rmse:2.39521	validation_1-rmse:3.22038
# [380]	validation_0-rmse:2.37635	validation_1-rmse:3.21535
# [400]	validation_0-rmse:2.34903	validation_1-rmse:3.21059
# [420]	validation_0-rmse:2.32492	validation_1-rmse:3.20828
# [440]	validation_0-rmse:2.30193	validation_1-rmse:3.21014
# [453]	validation_0-rmse:2.28193	validation_1-rmse:3.21026
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.206069989789706
# Score test : 3.088384139377797
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_2/rmse_val_3.2061_test_3.0884_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_2/rmse_val_3.2061_test_3.0884_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_2/rmse_val_3.2061_test_3.0884_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_2/rmse_val_3.2061_test_3.0884_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0307741024818675
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9049814224718256
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1492167621390097
# Saving analysis by week ..
# Predict submission
# CV score: 3.15697
# cv_train_rmse :  3.1569708811462527
# cv_test_rmse  :  3.477923386313542
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/shift_2
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/shift_2/rmse_cv_train_3.157_rmse_cv_test_3.4779_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/shift_2/rmse_cv_train_3.157_rmse_cv_test_3.4779_prediction_test.png
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/shift_2/rmse_cv_train_3.157_rmse_cv_test_3.4779_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.105909181547655
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.099892921054055
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1119083033977812
# Saving analysis by week ..
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift_2
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift_2
# [15:07:06] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01559	validation_1-rmse:5.93922
# [20]	validation_0-rmse:5.70936	validation_1-rmse:5.63801
# [40]	validation_0-rmse:4.97730	validation_1-rmse:4.93833
# [60]	validation_0-rmse:4.29376	validation_1-rmse:4.30501
# [80]	validation_0-rmse:3.80169	validation_1-rmse:3.87125
# [100]	validation_0-rmse:3.47425	validation_1-rmse:3.60261
# [120]	validation_0-rmse:3.26416	validation_1-rmse:3.44277
# [140]	validation_0-rmse:3.12643	validation_1-rmse:3.34681
# [160]	validation_0-rmse:3.04106	validation_1-rmse:3.29595
# [180]	validation_0-rmse:2.98659	validation_1-rmse:3.26589
# [200]	validation_0-rmse:2.95035	validation_1-rmse:3.24799
# [220]	validation_0-rmse:2.92595	validation_1-rmse:3.24001
# [240]	validation_0-rmse:2.90910	validation_1-rmse:3.23446
# [260]	validation_0-rmse:2.89926	validation_1-rmse:3.23197
# [280]	validation_0-rmse:2.89074	validation_1-rmse:3.23119
# [300]	validation_0-rmse:2.88256	validation_1-rmse:3.22644
# [320]	validation_0-rmse:2.87359	validation_1-rmse:3.22055
# [340]	validation_0-rmse:2.86595	validation_1-rmse:3.21807
# [360]	validation_0-rmse:2.85995	validation_1-rmse:3.21810
# [380]	validation_0-rmse:2.85394	validation_1-rmse:3.21849
# [400]	validation_0-rmse:2.84775	validation_1-rmse:3.21946
# [408]	validation_0-rmse:2.84284	validation_1-rmse:3.21925
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.2179101584273138
# Score test : 2.854799070207773
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift_2/rmse_val_3.2179_test_2.8548_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_1/shift
# [260]	validation_0-rmse:2.86340	validation_1-rmse:3.43959
# [280]	validation_0-rmse:2.85345	validation_1-rmse:3.43425
# [300]	validation_0-rmse:2.84698	validation_1-rmse:3.43070
# [320]	validation_0-rmse:2.84028	validation_1-rmse:3.42855
# [340]	validation_0-rmse:2.83431	validation_1-rmse:3.42782
# [360]	validation_0-rmse:2.83003	validation_1-rmse:3.42658
# [380]	validation_0-rmse:2.82502	validation_1-rmse:3.42640
# [400]	validation_0-rmse:2.81750	validation_1-rmse:3.42675
# [420]	validation_0-rmse:2.80835	validation_1-rmse:3.42603
# [440]	validation_0-rmse:2.80138	validation_1-rmse:3.42687
# [460]	validation_0-rmse:2.79263	validation_1-rmse:3.42691
# [462]	validation_0-rmse:2.79160	validation_1-rmse:3.42650
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.4257847953426985
# Score test : 2.632562747741149
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_2/rmse_val_3.4258_test_2.6326_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_2/rmse_val_3.4258_test_2.6326_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_2/rmse_val_3.4258_test_2.6326_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_2/rmse_val_3.4258_test_2.6326_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8881722325789203
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.5653196326089012
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.163368486304001
# Saving analysis by week ..
# Predict submission
# CV score: 3.26051
# cv_train_rmse :  3.260509488427158
# cv_test_rmse  :  2.6417991394596294
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_2
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_2/rmse_cv_train_3.2605_rmse_cv_test_2.6418_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_2/rmse_cv_train_3.2605_rmse_cv_test_2.6418_prediction_test.png
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_2/rmse_cv_train_3.2605_rmse_cv_test_2.6418_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9677880247273216
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.706819388344821
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1979870327394377
# Saving analysis by week ..
# ********************
# ********************
# WEEK =  3
# ********************
# ********************
# len base features =  266
# example base features = ['shift_6_roll_4_mean_Z_MODELO_Z_MARCA', 'shift_6_roll_2_mean_Z_MARCA', 'shift_5_roll_2_mean_Z_PUNTO_VENTA_Z_DEPARTAMENTO', 'shift_6_roll_4_std_Z_MODELO_Z_PUNTO_VENTA', 'shift_6_roll_4_mean_Z_MODELO_Z_PUNTO_VENTA']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 266)
# X_test           (377384, 266)
# X_submission     (471730, 266)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_3
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_3
# [15:09:50] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01577	validation_1-rmse:5.93941
# [20]	validation_0-rmse:5.72789	validation_1-rmse:5.66787
# [40]	validation_0-rmse:5.03268	validation_1-rmse:5.08360
# [60]	validation_0-rmse:4.35842	validation_1-rmse:4.56277
# [80]	validation_0-rmse:3.85168	validation_1-rmse:4.21319
# [100]	validation_0-rmse:3.49109	validation_1-rmse:3.98898
# [120]	validation_0-rmse:3.25317	validation_1-rmse:3.85333
# [140]	validation_0-rmse:3.07815	validation_1-rmse:3.76743
# [160]	validation_0-rmse:2.96835	validation_1-rmse:3.71566
# [180]	validation_0-rmse:2.89327	validation_1-rmse:3.68650
# [200]	validation_0-rmse:2.83310	validation_1-rmse:3.66487
# [220]	validation_0-rmse:2.78470	validation_1-rmse:3.65308
# [240]	validation_0-rmse:2.74921	validation_1-rmse:3.64605
# [260]	validation_0-rmse:2.72365	validation_1-rmse:3.64149
# [280]	validation_0-rmse:2.70217	validation_1-rmse:3.63504
# [300]	validation_0-rmse:2.68082	validation_1-rmse:3.62929
# [320]	validation_0-rmse:2.65403	validation_1-rmse:3.62480
# [340]	validation_0-rmse:2.63381	validation_1-rmse:3.61883
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 4.536824571939191
# Score test : 4.057383923913871
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_8/rmse_val_4.5368_test_4.0574_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_8/rmse_val_4.5368_test_4.0574_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_8/rmse_val_4.5368_test_4.0574_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/fold_3/shift_8/rmse_val_4.5368_test_4.0574_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.091499712662508
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.3143911983070242
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8418293833397503
# Saving analysis by week ..
# Predict submission
# CV score: 4.39252
# cv_train_rmse :  4.3925179168957165
# cv_test_rmse  :  4.091422268663073
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_8
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_8/rmse_cv_train_4.3925_rmse_cv_test_4.0914_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_8/rmse_cv_train_4.3925_rmse_cv_test_4.0914_prediction_test.png
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v3/shift_8/rmse_cv_train_4.3925_rmse_cv_test_4.0914_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1803394216996894
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.197463199750604
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1630800894505295
# Saving analysis by week ..
# ********************
# ********************
# WEEK =  9
# ********************
# ********************
# len base features =  266
# example base features = ['shift_11_roll_2_mean_Z_MODELO_Z_PUNTO_VENTA', 'shift_12_roll_2_std_Z_DEPARTAMENTO', 'shift_9_roll_4_mean_Z_GAMA_Z_DEPARTAMENTO', 'shift_10_roll_4_std_Z_PUNTO_VENTA_Z_GAMA', 'shift_9_roll_2_std_Z_GAMA']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 266)
# X_test           (377384, 266)
# X_submission     (471730, 266)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_9
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_9
# [17:08:13] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01654	validation_1-rmse:5.94023
# [20]	validation_0-rmse:5.80560	validation_1-rmse:5.74940
# [40]	validation_0-rmse:5.29486	validation_1-rmse:5.36816
# [60]	validation_0-rmse:4.77846	validation_1-rmse:5.02888
# [80]	validation_0-rmse:4.37889	validation_1-rmse:4.78857
# [100]	validation_0-rmse:4.09926	validation_1-rmse:4.63044
# [120]	validation_0-rmse:3.89852	validation_1-rmse:4.52368
# [140]	validation_0-rmse:3.75177	validation_1-rmse:4.45008
# [160]	validation_0-rmse:3.63979	validation_1-rmse:4.39732
# [180]	validation_0-rmse:3.54282	validation_1-rmse:4.35724
# [200]	validation_0-rmse:3.47714	validation_1-rmse:4.32893
# [220]	validation_0-rmse:3.42529	validation_1-rmse:4.30885
# [240]	validation_0-rmse:3.37026	validation_1-rmse:4.28838
# [260]	validation_0-rmse:3.32638	validation_1-rmse:4.26861
# [280]	validation_0-rmse:3.28933	validation_1-rmse:4.25567
# [300]	validation_0-rmse:3.25402	validation_1-rmse:4.24192
# [320]	validation_0-rmse:3.23481	validation_1-rmse:4.23201
# [340]	validation_0-rmse:3.21456	validation_1-rmse:4.22311
# [360]	validation_0-rmse:3.19660	validation_1-rmse:4.21582
# [380]	validation_0-rmse:3.17425	validation_1-rmse:4.21094
# [400]	validation_0-rmse:3.15325	validation_1-rmse:4.20738
# [420]	validation_0-rmse:3.13215	validation_1-rmse:4.20211
# [440]	validation_0-rmse:3.10603	validation_1-rmse:4.19683
# [460]	validation_0-rmse:3.08046	validation_1-rmse:4.19124
# [480]	validation_0-rmse:3.05382	validation_1-rmse:4.18768
# [500]	validation_0-rmse:3.02950	validation_1-rmse:4.18063
# [520]	validation_0-rmse:3.00154	validation_1-rmse:4.17432
# [540]	validation_0-rmse:2.97601	validation_1-rmse:4.16972
# [560]	validation_0-rmse:2.95948	validation_1-rmse:4.16432
# [580]	validation_0-rmse:2.94412	validation_1-rmse:4.15987
# [600]	validation_0-rmse:2.92560	validation_1-rmse:4.15629
# [620]	validation_0-rmse:2.91200	validation_1-rmse:4.15317
# [640]	validation_0-rmse:2.89800	validation_1-rmse:4.14880
# [660]	validation_0-rmse:2.87959	validation_1-rmse:4.14521
# [680]	validation_0-rmse:2.86640	validation_1-rmse:4.14253
# [700]	validation_0-rmse:2.85230	validation_1-rmse:4.14209
# [720]	validation_0-rmse:2.83796	validation_1-rmse:4.14025
# [740]	validation_0-rmse:2.82413	validation_1-rmse:4.13906
# [760]	validation_0-rmse:2.80762	validation_1-rmse:4.13803
# [780]	validation_0-rmse:2.79532	validation_1-rmse:4.13486
# [800]	validation_0-rmse:2.78449	validation_1-rmse:4.13308
# [820]	validation_0-rmse:2.77079	validation_1-rmse:4.13095
# [840]	validation_0-rmse:2.75466	validation_1-rmse:4.12973
# [860]	validation_0-rmse:2.74187	validation_1-rmse:4.12692
# [880]	validation_0-rmse:2.72638	validation_1-rmse:4.12528
# [900]	validation_0-rmse:2.71447	validation_1-rmse:4.12258
# [920]	validation_0-rmse:2.70314	validation_1-rmse:4.11899
# [940]	validation_0-rmse:2.69013	validation_1-rmse:4.11581
# [960]	validation_0-rmse:2.68054	validation_1-rmse:4.11541
# [980]	validation_0-rmse:2.66940	validation_1-rmse:4.11347
# [1000]	validation_0-rmse:2.65736	validation_1-rmse:4.11505
# [1020]	validation_0-rmse:2.64897	validation_1-rmse:4.11356
# [1040]	validation_0-rmse:2.63710	validation_1-rmse:4.11198
# [1060]	validation_0-rmse:2.62686	validation_1-rmse:4.11086
# [1080]	validation_0-rmse:2.61751	validation_1-rmse:4.11157
# [1100]	validation_0-rmse:2.60588	validation_1-rmse:4.11273
# [1102]	validation_0-rmse:2.60534	validation_1-rmse:4.11247
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 4.110642661293673
# Score test : 4.122089848779226
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_9/rmse_val_4.1106_test_4.1221_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_9/rmse_val_4.1106_test_4.1221_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_9/rmse_val_4.1106_test_4.1221_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_1/shift_9/rmse_val_4.1106_test_4.1221_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.293596193238126
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.4585760279497033
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1157908474288987
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_2/shift_9
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_2/shift_9
# [17:14:24] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10125	validation_1-rmse:5.76479
# [20]	validation_0-rmse:5.88675	validation_1-rmse:5.58267
# [40]	validation_0-rmse:5.35572	validation_1-rmse:5.23917
# [60]	validation_0-rmse:4.83313	validation_1-rmse:4.94002
# [80]	validation_0-rmse:4.42579	validation_1-rmse:4.72010
# [100]	validation_0-rmse:4.12807	validation_1-rmse:4.57076
# [120]	validation_0-rmse:3.90474	validation_1-rmse:4.46608
# [140]	validation_0-rmse:3.74432	validation_1-rmse:4.38874
# [160]	validation_0-rmse:3.61307	validation_1-rmse:4.33035
# [180]	validation_0-rmse:3.51569	validation_1-rmse:4.28415
# [200]	validation_0-rmse:3.45669	validation_1-rmse:4.25458
# [220]	validation_0-rmse:3.40321	validation_1-rmse:4.22898
# [240]	validation_0-rmse:3.35246	validation_1-rmse:4.21051
# [260]	validation_0-rmse:3.31448	validation_1-rmse:4.19723
# [280]	validation_0-rmse:3.27870	validation_1-rmse:4.18161
# [300]	validation_0-rmse:3.24311	validation_1-rmse:4.16832
# [320]	validation_0-rmse:3.20939	validation_1-rmse:4.15986
# [340]	validation_0-rmse:3.17871	validation_1-rmse:4.15107
# [360]	validation_0-rmse:3.15843	validation_1-rmse:4.14513
# [380]	validation_0-rmse:3.13565	validation_1-rmse:4.13878
# [400]	validation_0-rmse:3.11472	validation_1-rmse:4.13340
# [420]	validation_0-rmse:3.09429	validation_1-rmse:4.12956
# [440]	validation_0-rmse:3.07283	validation_1-rmse:4.12277
# [460]	validation_0-rmse:3.04927	validation_1-rmse:4.11566
# [480]	validation_0-rmse:3.02461	validation_1-rmse:4.10849
# [500]	validation_0-rmse:3.00569	validation_1-rmse:4.09899
# [520]	validation_0-rmse:2.98461	validation_1-rmse:4.08903
# [540]	validation_0-rmse:2.96322	validation_1-rmse:4.08187
# [560]	validation_0-rmse:2.94074	validation_1-rmse:4.07619
# [580]	validation_0-rmse:2.91769	validation_1-rmse:4.06926
# [600]	validation_0-rmse:2.90332	validation_1-rmse:4.06487
# [620]	validation_0-rmse:2.89000	validation_1-rmse:4.06067
# [640]	validation_0-rmse:2.87277	validation_1-rmse:4.05617
# [660]	validation_0-rmse:2.85330	validation_1-rmse:4.04973
# [680]	validation_0-rmse:2.83252	validation_1-rmse:4.04499
# [700]	validation_0-rmse:2.81989	validation_1-rmse:4.04205
# [720]	validation_0-rmse:2.80234	validation_1-rmse:4.03473
# [740]	validation_0-rmse:2.78636	validation_1-rmse:4.03065
# [760]	validation_0-rmse:2.76790	validation_1-rmse:4.02584
# [780]	validation_0-rmse:2.74877	validation_1-rmse:4.02356
# [800]	validation_0-rmse:2.73502	validation_1-rmse:4.02090
# [820]	validation_0-rmse:2.72210	validation_1-rmse:4.01761
# [840]	validation_0-rmse:2.70891	validation_1-rmse:4.01553
# [860]	validation_0-rmse:2.69682	validation_1-rmse:4.01307
# [880]	validation_0-rmse:2.68244	validation_1-rmse:4.01077
# [900]	validation_0-rmse:2.66948	validation_1-rmse:4.00763
# [920]	validation_0-rmse:2.65530	validation_1-rmse:4.00516
# [940]	validation_0-rmse:2.64394	validation_1-rmse:4.00208
# [960]	validation_0-rmse:2.63210	validation_1-rmse:4.00032
# [980]	validation_0-rmse:2.62153	validation_1-rmse:3.99787
# [1000]	validation_0-rmse:2.60996	validation_1-rmse:3.99447
# [1020]	validation_0-rmse:2.59634	validation_1-rmse:3.99158
# [1040]	validation_0-rmse:2.58478	validation_1-rmse:3.98836
# [1060]	validation_0-rmse:2.57375	validation_1-rmse:3.98849
# [1080]	validation_0-rmse:2.56192	validation_1-rmse:3.98670
# [1100]	validation_0-rmse:2.55211	validation_1-rmse:3.98759
# [1117]	validation_0-rmse:2.54532	validation_1-rmse:3.98711
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.9862981403285564
# Score test : 4.0836455707449
# end !
# saving feature importance .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_2/shift_9/rmse_val_3.9863_test_4.0836_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_2/shift_9/rmse_val_3.9863_test_4.0836_prediction_test.png
# saving model.. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_2/shift_9/rmse_val_3.9863_test_4.0836_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_2/shift_9/rmse_val_3.9863_test_4.0836_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.235411995482505
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.403080480388137
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0541026712099053
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_9
# create folder ../../results/Demanda_ventana3_no_enc/xgboost/c_model_v2/fold_3/shift_9
