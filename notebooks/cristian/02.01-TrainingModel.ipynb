# %%
import sys
sys.path.insert(1, '../../Src')
from utils.preprocessing import *
import training


import numpy as np
import pandas as pd
from math import ceil
import warnings
import os

SEED = 42
seed_everything(SEED)
PATH_DATASET = '../../dataset/'
PATH_RESULTS = '../../results/Demanda/'
FILL = False
TARGET = 'Demanda'
N_FOLDS = 3
N_FEATURE_IMPORTANCE = 15



plt.rcParams['axes.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)
# %load_ext autoreload
# %autoreload 2

# %%
submission_top_reference = 'Submission_52.csv'
print('reading .. ',os.path.join('../../results/',submission_top_reference))
result = pd.read_csv(os.path.join('../../results/',submission_top_reference))
# Out:
# reading ..  ../../results/Submission_52.csv

# %%
descriptive_columns = ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']
reverse_mapping_file = '../../utils/reverse_dict_mapping_list.txt'

result[['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']] = result['ID'].str.split('|',expand=True)

with open(reverse_mapping_file, 'rb') as f:
    reverse_mapping = pickle.load( f)
    
descriptive_columns = ['Z_MARCA', 'Z_GAMA', 'Z_MODELO',
                       'Z_DEPARTAMENTO', 'Z_PUNTO_VENTA']
i=0
for column in descriptive_columns:
    if column in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']:
        inv_reverse_mapping = {v: k for k, v in reverse_mapping[i].items()}

        result[column] = result[column].map(inv_reverse_mapping)
    i+=1
    
result = result.rename(columns = {TARGET: TARGET+'_real'})

# %%
result.head(1)
# Out:
#                                                   ID  Demanda_real Z_MODELO  \
# 0  009e0874cc07b2180b2b2b1039321041a1f42e66693c49...           0.0  MOD_170
#
#   Z_PUNTO_VENTA Z_GAMA     Z_WEEK
# 0     PVENT_259  GAM_2  SEMANA_51

# %%
print('Reading dataset')
SHIFT=1
df_train  = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_train_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))
df_test   = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_test_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))

gc.collect()
print('df_train size :',df_train.shape)
print('df_test size  :',df_test.shape)

# %%
features_names = set(df_train.columns)-set([TARGET,'date_block_num',TARGET+'_clipped','release','item_id',
                                            'Z_WEEK_DATE', 'Z_WEEK','date_block_num','year',
                                            'month', 'is_month_end', 'tm_m_end','is_month_start','tm_wm', 'tm_w_end','is_quarter_start','is_year_start',
                                             'day_of_week',
                                            'day_of_year', 'day',
                                            #'Z_MODELO','Z_PUNTO_VENTA','Z_DEPARTAMENTO',
                                            #'Z_GAMA','Z_MARCA', 
                                           ]) 
print(len(features_names))
features_names = list(features_names)
# Out:
# 1093

# %%
for columns in features_names:
    if columns in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA']:
        print(columns)
# Out:
# Z_PUNTO_VENTA
# Z_MODELO
# Z_GAMA

# %%
df_train['week_of_month'] = df_train['week_of_month'].astype('category')
df_test['week_of_month']  = df_test['week_of_month'].astype('category')

# %%
total_features_names = features_names.copy()

# %%
def get_feature_names_shift(shift,total_features_names):
    features_names = []

    for column in total_features_names:
        if 'shift' in column:
            number = column.split('shift_')[1]
            number = int(number.split('_')[0])
            if number>=shift and number<=(shift+2):
                features_names.append(column)
        else:
            features_names.append(column)
    return features_names

# %%
TRAIN_START = '2021-08-01'
TEST_START = '2022-03-01'
TEST_END   = '2022-05-01'
print(df_train.shape)
df_train = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)]
print(df_train.shape)
# Out:
# (2358650, 1111)
# (1839747, 1111)

# %%
PATH_RESULTS = '../Results/Demanda/'
training.PATH_RESULTS = PATH_RESULTS
training.submission_analysis.TARGET  = TARGET


for SHIFT in range(10,11):
    print('*'*20)
    print('*'*20)
    print('WEEK = ',SHIFT)
    print('*'*20)
    print('*'*20)

    features_names = get_feature_names_shift(SHIFT,total_features_names)
    print('len base features = ',len(features_names))
    print('example base features =',features_names[:5])
    
    ################### CV MODEL RANDOM SPLIT ###############


    
    for idx,model_type in enumerate(['xgboost']):

    
        X_train      = df_train[((df_train['Z_WEEK_DATE'] >= TRAIN_START) &(df_train['Z_WEEK_DATE'] < TEST_START))&
                               (df_train['Z_WEEK_DATE'] != '2022-04-11')].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT model_type = ',model_type,'c_model_v2')
        print('*'*20)

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]
        X_train = X_train[features_names]
        X_test  = X_test[features_names]
        X_submission = df_test[features_names]        
        


        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        model_version = 'c_model_v2'
        training.TARGET = TARGET
        training.SHIFT = SHIFT

        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                            X_test,y_test,X_submission,df_test,result,N_FOLDS)

    
        
        
        #'''
        if idx ==0 :
            features_names = list(df_feature_importance['feature'][:15].values)
            
        ################### CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE ###############
        important_features = list(df_feature_importance[:N_FEATURE_IMPORTANCE]['feature'])
        
        X_train      = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)&(df_train['Z_WEEK_DATE'] < TEST_START)].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]

        X_train = X_train[important_features]
        X_test  = X_test[important_features]
        X_submission = df_test[important_features]

        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type = ',model_type,'c_model_v3')
        print('*'*20)
        
        model_version = 'c_model_v3'
        training.TARGET = TARGET
        training.SHIFT = SHIFT


        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                               X_test,y_test,X_submission,df_test,result,N_FOLDS)
        #'''
# Out:
# ********************
# ********************
# WEEK =  10
# ********************
# ********************
# len base features =  249
# example base features = ['shift_10_roll_4_std_Z_MODELO_Z_DEPARTAMENTO', 'shift_11_roll_2_std_Z_MODELO_Z_GAMA', 'shift_10_roll_4_mean_Z_MODELO_Z_GAMA', 'enc_Z_GAMA_Z_MARCA_std', 'shift_12_roll_2_mean_Z_GAMA_Z_MARCA']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 249)
# X_test           (377384, 249)
# X_submission     (471730, 249)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../Results/Demanda/xgboost/c_model_v2/fold_1/shift_10
# create folder ../Results/Demanda/xgboost/c_model_v2/fold_1/shift_10
# [23:18:25] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01583	validation_1-rmse:5.93947
# [20]	validation_0-rmse:5.74413	validation_1-rmse:5.67528
# [40]	validation_0-rmse:5.09465	validation_1-rmse:5.06874
# [60]	validation_0-rmse:4.47794	validation_1-rmse:4.52179
# [80]	validation_0-rmse:4.01669	validation_1-rmse:4.13150
# [100]	validation_0-rmse:3.71319	validation_1-rmse:3.88342
# [120]	validation_0-rmse:3.51325	validation_1-rmse:3.72277
# [140]	validation_0-rmse:3.37025	validation_1-rmse:3.61782
# [160]	validation_0-rmse:3.26982	validation_1-rmse:3.54733
# [180]	validation_0-rmse:3.20365	validation_1-rmse:3.50601
# [200]	validation_0-rmse:3.15736	validation_1-rmse:3.47896
# [220]	validation_0-rmse:3.12160	validation_1-rmse:3.46219
# [240]	validation_0-rmse:3.08982	validation_1-rmse:3.44840
# [260]	validation_0-rmse:3.06093	validation_1-rmse:3.43585
# [280]	validation_0-rmse:3.03549	validation_1-rmse:3.42688
# [300]	validation_0-rmse:3.00843	validation_1-rmse:3.41791
# [320]	validation_0-rmse:2.98800	validation_1-rmse:3.41202
# [340]	validation_0-rmse:2.96697	validation_1-rmse:3.40547
# [360]	validation_0-rmse:2.95254	validation_1-rmse:3.40258
# [380]	validation_0-rmse:2.93630	validation_1-rmse:3.39924
# [400]	validation_0-rmse:2.91470	validation_1-rmse:3.39430
# [420]	validation_0-rmse:2.89766	validation_1-rmse:3.38777
# [440]	validation_0-rmse:2.87683	validation_1-rmse:3.38551
# [460]	validation_0-rmse:2.86505	validation_1-rmse:3.38452
# [480]	validation_0-rmse:2.84913	validation_1-rmse:3.37916
# [500]	validation_0-rmse:2.83291	validation_1-rmse:3.37557
# [520]	validation_0-rmse:2.81976	validation_1-rmse:3.37097
# [540]	validation_0-rmse:2.80482	validation_1-rmse:3.36751
# [560]	validation_0-rmse:2.78114	validation_1-rmse:3.36702
# [580]	validation_0-rmse:2.76432	validation_1-rmse:3.36512
# [600]	validation_0-rmse:2.74602	validation_1-rmse:3.36619
# [620]	validation_0-rmse:2.72424	validation_1-rmse:3.36255
# [640]	validation_0-rmse:2.70789	validation_1-rmse:3.36090
# [660]	validation_0-rmse:2.68761	validation_1-rmse:3.35550
# [680]	validation_0-rmse:2.66907	validation_1-rmse:3.35434
# [700]	validation_0-rmse:2.65030	validation_1-rmse:3.35489
# [720]	validation_0-rmse:2.63857	validation_1-rmse:3.35165
# [740]	validation_0-rmse:2.61985	validation_1-rmse:3.35026
# [760]	validation_0-rmse:2.60543	validation_1-rmse:3.35000
# [780]	validation_0-rmse:2.59648	validation_1-rmse:3.34919
# [800]	validation_0-rmse:2.57949	validation_1-rmse:3.35130
# [820]	validation_0-rmse:2.56658	validation_1-rmse:3.35250
# [826]	validation_0-rmse:2.56370	validation_1-rmse:3.35238
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.348689521661391
# Score test : 4.0063353920077285
# end !
# saving feature importance .. ../Results/Demanda/xgboost/c_model_v2/fold_1/shift_10/rmse_val_3.3487_test_4.0063_feature_importance.png
# saving test prediction .. ../Results/Demanda/xgboost/c_model_v2/fold_1/shift_10/rmse_val_3.3487_test_4.0063_prediction_test.png
# saving model.. ../Results/Demanda/xgboost/c_model_v2/fold_1/shift_10/rmse_val_3.3487_test_4.0063_model.pkl
# (471730, 1111)
# saving submission .. ../Results/Demanda/xgboost/c_model_v2/fold_1/shift_10/rmse_val_3.3487_test_4.0063_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 3
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.245104632759899
# Score test : 3.6621752651621824
# end !
# saving feature importance .. ../Results/Demanda/xgboost/c_model_v2/fold_2/shift_10/rmse_val_3.2451_test_3.6622_feature_importance.png
# saving test prediction .. ../Results/Demanda/xgboost/c_model_v2/fold_2/shift_10/rmse_val_3.2451_test_3.6622_prediction_test.png
# saving model.. ../Results/Demanda/xgboost/c_model_v2/fold_2/shift_10/rmse_val_3.2451_test_3.6622_model.pkl
# (471730, 1111)
# saving submission .. ../Results/Demanda/xgboost/c_model_v2/fold_2/shift_10/rmse_val_3.2451_test_3.6622_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.910995863348191
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.997381666015947
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.821966863925235
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../Results/Demanda/xgboost/c_model_v2/fold_3/shift_10
# create folder ../Results/Demanda/xgboost/c_model_v2/fold_3/shift_10
# [23:21:09] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85239	validation_1-rmse:6.25754
# [20]	validation_0-rmse:5.58592	validation_1-rmse:5.98961
# [40]	validation_0-rmse:4.96700	validation_1-rmse:5.38516
# [60]	validation_0-rmse:4.37550	validation_1-rmse:4.82604
# [80]	validation_0-rmse:3.93420	validation_1-rmse:4.41857
# [100]	validation_0-rmse:3.64308	validation_1-rmse:4.15491
# [120]	validation_0-rmse:3.44316	validation_1-rmse:3.97518
# [140]	validation_0-rmse:3.31034	validation_1-rmse:3.85644
# [160]	validation_0-rmse:3.21522	validation_1-rmse:3.77277
# [180]	validation_0-rmse:3.15071	validation_1-rmse:3.71547
# [200]	validation_0-rmse:3.09836	validation_1-rmse:3.67590
# [220]	validation_0-rmse:3.05610	validation_1-rmse:3.64616
# [240]	validation_0-rmse:3.02392	validation_1-rmse:3.62386
# [260]	validation_0-rmse:2.99622	validation_1-rmse:3.60886
# [280]	validation_0-rmse:2.97548	validation_1-rmse:3.59277
# [300]	validation_0-rmse:2.95563	validation_1-rmse:3.58053
# [320]	validation_0-rmse:2.94104	validation_1-rmse:3.57092
# [340]	validation_0-rmse:2.92658	validation_1-rmse:3.56164
# [360]	validation_0-rmse:2.91295	validation_1-rmse:3.55470
# [380]	validation_0-rmse:2.89614	validation_1-rmse:3.54760
# [400]	validation_0-rmse:2.87587	validation_1-rmse:3.54491
# [420]	validation_0-rmse:2.86187	validation_1-rmse:3.53853
# [440]	validation_0-rmse:2.84891	validation_1-rmse:3.53226
# [460]	validation_0-rmse:2.83702	validation_1-rmse:3.52639
# [480]	validation_0-rmse:2.82162	validation_1-rmse:3.51993
# [500]	validation_0-rmse:2.79847	validation_1-rmse:3.51389
# [520]	validation_0-rmse:2.77090	validation_1-rmse:3.50477
# [540]	validation_0-rmse:2.75362	validation_1-rmse:3.49540
# [560]	validation_0-rmse:2.73023	validation_1-rmse:3.49290
# [580]	validation_0-rmse:2.70230	validation_1-rmse:3.49148
# [600]	validation_0-rmse:2.67840	validation_1-rmse:3.48998
# [620]	validation_0-rmse:2.66364	validation_1-rmse:3.49022
# [640]	validation_0-rmse:2.64342	validation_1-rmse:3.48767
# [660]	validation_0-rmse:2.62408	validation_1-rmse:3.48669
# [680]	validation_0-rmse:2.60751	validation_1-rmse:3.48617
# [700]	validation_0-rmse:2.59068	validation_1-rmse:3.48207
# [720]	validation_0-rmse:2.57564	validation_1-rmse:3.48009
# [740]	validation_0-rmse:2.55955	validation_1-rmse:3.47687
# [760]	validation_0-rmse:2.54415	validation_1-rmse:3.47561
# [780]	validation_0-rmse:2.53135	validation_1-rmse:3.47388
# [800]	validation_0-rmse:2.51972	validation_1-rmse:3.47295
# [820]	validation_0-rmse:2.50614	validation_1-rmse:3.47363
# [835]	validation_0-rmse:2.49891	validation_1-rmse:3.47348
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.4718584056484105
# Score test : 3.8464169997385302
# end !
# saving feature importance .. ../Results/Demanda/xgboost/c_model_v2/fold_3/shift_10/rmse_val_3.4719_test_3.8464_feature_importance.png
# saving test prediction .. ../Results/Demanda/xgboost/c_model_v2/fold_3/shift_10/rmse_val_3.4719_test_3.8464_prediction_test.png
# saving model.. ../Results/Demanda/xgboost/c_model_v2/fold_3/shift_10/rmse_val_3.4719_test_3.8464_model.pkl
# (471730, 1111)
# saving submission .. ../Results/Demanda/xgboost/c_model_v2/fold_3/shift_10/rmse_val_3.4719_test_3.8464_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 3.301192298510603
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 3.503092875361978
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 3.086111062499142
# Saving analysis by week ..
# Predict submission
# CV score: 3.35650
# cv_train_rmse :  3.3564974934949316
# cv_test_rmse  :  3.7633376846043274
# create folder ../Results/Demanda/xgboost/c_model_v2/shift_10
# (471730, 1111)
# saving feature importance .. ../Results/Demanda/xgboost/c_model_v2/shift_10/rmse_cv_train_3.3565_rmse_cv_test_3.7633_feature_importance.png
# saving test prediction .. ../Results/Demanda/xgboost/c_model_v2/shift_10/rmse_cv_train_3.3565_rmse_cv_test_3.7633_prediction_test.png
# saving submission .. ../Results/Demanda/xgboost/c_model_v2/shift_10/rmse_cv_train_3.3565_rmse_cv_test_3.7633_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 3.197556356095488
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 3.3683725789762824
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 3.0170845977555842
# Saving analysis by week ..
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../Results/Demanda/xgboost/c_model_v3/fold_1/shift_10
# create folder ../Results/Demanda/xgboost/c_model_v3/fold_1/shift_10
# [23:22:44] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01583	validation_1-rmse:5.93947
# [20]	validation_0-rmse:5.74604	validation_1-rmse:5.67710
# [40]	validation_0-rmse:5.11984	validation_1-rmse:5.08881
# [60]	validation_0-rmse:4.53536	validation_1-rmse:4.56711
# [80]	validation_0-rmse:4.10733	validation_1-rmse:4.20595
# [100]	validation_0-rmse:3.81814	validation_1-rmse:3.97823
# [120]	validation_0-rmse:3.62330	validation_1-rmse:3.83269
# [140]	validation_0-rmse:3.50164	validation_1-rmse:3.74945
# [1120]	validation_0-rmse:2.64096	validation_1-rmse:3.43313
# [1140]	validation_0-rmse:2.62679	validation_1-rmse:3.42733
# [1160]	validation_0-rmse:2.61981	validation_1-rmse:3.42582
# [1180]	validation_0-rmse:2.61420	validation_1-rmse:3.42492
# [1200]	validation_0-rmse:2.60691	validation_1-rmse:3.42344
# [1220]	validation_0-rmse:2.60178	validation_1-rmse:3.42356
# [1240]	validation_0-rmse:2.58864	validation_1-rmse:3.42022
# [1260]	validation_0-rmse:2.57699	validation_1-rmse:3.41778
# [1280]	validation_0-rmse:2.56173	validation_1-rmse:3.41214
# [1300]	validation_0-rmse:2.55153	validation_1-rmse:3.40827
# [1320]	validation_0-rmse:2.53763	validation_1-rmse:3.40927
# [1340]	validation_0-rmse:2.53052	validation_1-rmse:3.40785
# [1360]	validation_0-rmse:2.52645	validation_1-rmse:3.40700
# [1380]	validation_0-rmse:2.52268	validation_1-rmse:3.40571
# [1400]	validation_0-rmse:2.51744	validation_1-rmse:3.40418
# [1420]	validation_0-rmse:2.51180	validation_1-rmse:3.40214
# [1440]	validation_0-rmse:2.49814	validation_1-rmse:3.40021
# [1460]	validation_0-rmse:2.49208	validation_1-rmse:3.40026
# [1471]	validation_0-rmse:2.48861	validation_1-rmse:3.40030
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.3998258395143477
# Score test : 4.576523168518009
# end !
# saving feature importance .. ../Results/Demanda/xgboost/c_model_v3/fold_1/shift_10/rmse_val_3.3998_test_4.5765_feature_importance.png
# saving test prediction .. ../Results/Demanda/xgboost/c_model_v3/fold_1/shift_10/rmse_val_3.3998_test_4.5765_prediction_test.png
# saving model.. ../Results/Demanda/xgboost/c_model_v3/fold_1/shift_10/rmse_val_3.3998_test_4.5765_model.pkl
# (471730, 1111)
# saving submission .. ../Results/Demanda/xgboost/c_model_v3/fold_1/shift_10/rmse_val_3.3998_test_4.5765_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.58033694176032
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.673577598615595
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.485158350585523
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../Results/Demanda/xgboost/c_model_v3/fold_2/shift_10
# create folder ../Results/Demanda/xgboost/c_model_v3/fold_2/shift_10
# [23:23:18] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10057	validation_1-rmse:5.76404
# [20]	validation_0-rmse:5.82862	validation_1-rmse:5.51055
# [40]	validation_0-rmse:5.18065	validation_1-rmse:4.97333
# [60]	validation_0-rmse:4.57793	validation_1-rmse:4.48749
# [80]	validation_0-rmse:4.13453	validation_1-rmse:4.13970
# [100]	validation_0-rmse:3.84199	validation_1-rmse:3.91507
# [120]	validation_0-rmse:3.65297	validation_1-rmse:3.77150
# [140]	validation_0-rmse:3.52217	validation_1-rmse:3.67483
# [160]	validation_0-rmse:3.43613	validation_1-rmse:3.61357
# [180]	validation_0-rmse:3.37569	validation_1-rmse:3.57151
# [200]	validation_0-rmse:3.33394	validation_1-rmse:3.54229
# [220]	validation_0-rmse:3.29966	validation_1-rmse:3.51879
# [240]	validation_0-rmse:3.27232	validation_1-rmse:3.50040
# [260]	validation_0-rmse:3.25042	validation_1-rmse:3.48647
# [280]	validation_0-rmse:3.23450	validation_1-rmse:3.47555
# [1240]	validation_0-rmse:2.58003	validation_1-rmse:3.24209
# [1260]	validation_0-rmse:2.56910	validation_1-rmse:3.23937
# [1280]	validation_0-rmse:2.55956	validation_1-rmse:3.23583
# [1300]	validation_0-rmse:2.55373	validation_1-rmse:3.23373
# [1320]	validation_0-rmse:2.54636	validation_1-rmse:3.23229
# [1340]	validation_0-rmse:2.53672	validation_1-rmse:3.22990
# [1360]	validation_0-rmse:2.52451	validation_1-rmse:3.22519
# [1380]	validation_0-rmse:2.51677	validation_1-rmse:3.22354
# [1400]	validation_0-rmse:2.51073	validation_1-rmse:3.22170
# [1420]	validation_0-rmse:2.49973	validation_1-rmse:3.21854
# [1440]	validation_0-rmse:2.48729	validation_1-rmse:3.21441
# [1460]	validation_0-rmse:2.47815	validation_1-rmse:3.21223
# [1480]	validation_0-rmse:2.47268	validation_1-rmse:3.20995
# [1500]	validation_0-rmse:2.46200	validation_1-rmse:3.20854
# [1520]	validation_0-rmse:2.45442	validation_1-rmse:3.20707
# [1540]	validation_0-rmse:2.44430	validation_1-rmse:3.20463
# [1560]	validation_0-rmse:2.43354	validation_1-rmse:3.20299
# [1580]	validation_0-rmse:2.42712	validation_1-rmse:3.20342
# [1600]	validation_0-rmse:2.42182	validation_1-rmse:3.20188
# [1620]	validation_0-rmse:2.41835	validation_1-rmse:3.20131
# [1640]	validation_0-rmse:2.41377	validation_1-rmse:3.20158
# [1660]	validation_0-rmse:2.40819	validation_1-rmse:3.20032
# [1680]	validation_0-rmse:2.40526	validation_1-rmse:3.19849
# [1700]	validation_0-rmse:2.39962	validation_1-rmse:3.19648
# [1720]	validation_0-rmse:2.39363	validation_1-rmse:3.19314
# [1740]	validation_0-rmse:2.38906	validation_1-rmse:3.19438
# [1760]	validation_0-rmse:2.38541	validation_1-rmse:3.19682
# [1762]	validation_0-rmse:2.38494	validation_1-rmse:3.19660
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.1928910040857725
# Score test : 4.610010984515453
# end !
# saving feature importance .. ../Results/Demanda/xgboost/c_model_v3/fold_2/shift_10/rmse_val_3.1929_test_4.61_feature_importance.png
# saving test prediction .. ../Results/Demanda/xgboost/c_model_v3/fold_2/shift_10/rmse_val_3.1929_test_4.61_prediction_test.png
# saving model.. ../Results/Demanda/xgboost/c_model_v3/fold_2/shift_10/rmse_val_3.1929_test_4.61_model.pkl
# (471730, 1111)
# saving submission .. ../Results/Demanda/xgboost/c_model_v3/fold_2/shift_10/rmse_val_3.1929_test_4.61_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.46556965845896
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.718305262214741
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.197644601637356
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../Results/Demanda/xgboost/c_model_v3/fold_3/shift_10
# create folder ../Results/Demanda/xgboost/c_model_v3/fold_3/shift_10
# [23:23:55] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85239	validation_1-rmse:6.25754
# [20]	validation_0-rmse:5.58891	validation_1-rmse:5.99013
# [40]	validation_0-rmse:4.99937	validation_1-rmse:5.38540
# [60]	validation_0-rmse:4.44141	validation_1-rmse:4.84418
# [80]	validation_0-rmse:4.02764	validation_1-rmse:4.45930
# [100]	validation_0-rmse:3.75414	validation_1-rmse:4.19866
# [120]	validation_0-rmse:3.57739	validation_1-rmse:4.02726
# [140]	validation_0-rmse:3.46376	validation_1-rmse:3.91540
# [160]	validation_0-rmse:3.39141	validation_1-rmse:3.84427
# [180]	validation_0-rmse:3.33527	validation_1-rmse:3.78838
# [200]	validation_0-rmse:3.29697	validation_1-rmse:3.75157
# [220]	validation_0-rmse:3.27022	validation_1-rmse:3.72482
# [240]	validation_0-rmse:3.24872	validation_1-rmse:3.70412
# [260]	validation_0-rmse:3.23537	validation_1-rmse:3.69122
# [280]	validation_0-rmse:3.21929	validation_1-rmse:3.67484
# [300]	validation_0-rmse:3.20083	validation_1-rmse:3.66203
# [320]	validation_0-rmse:3.18533	validation_1-rmse:3.65159
# [340]	validation_0-rmse:3.16538	validation_1-rmse:3.64330
# [360]	validation_0-rmse:3.14871	validation_1-rmse:3.63809
# [380]	validation_0-rmse:3.12830	validation_1-rmse:3.62872
# [400]	validation_0-rmse:3.10646	validation_1-rmse:3.62243
# [420]	validation_0-rmse:3.08578	validation_1-rmse:3.61906
# [440]	validation_0-rmse:3.07005	validation_1-rmse:3.61499
# [460]	validation_0-rmse:3.05420	validation_1-rmse:3.61206
# [480]	validation_0-rmse:3.02991	validation_1-rmse:3.60898
# [500]	validation_0-rmse:3.01272	validation_1-rmse:3.60447
# [520]	validation_0-rmse:2.99367	validation_1-rmse:3.60826
# [540]	validation_0-rmse:2.97126	validation_1-rmse:3.61230
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.6044654759925985
# Score test : 4.420281080345359
# end !
# saving feature importance .. ../Results/Demanda/xgboost/c_model_v3/fold_3/shift_10/rmse_val_3.6045_test_4.4203_feature_importance.png
# saving test prediction .. ../Results/Demanda/xgboost/c_model_v3/fold_3/shift_10/rmse_val_3.6045_test_4.4203_prediction_test.png
# saving model.. ../Results/Demanda/xgboost/c_model_v3/fold_3/shift_10/rmse_val_3.6045_test_4.4203_model.pkl
# (471730, 1111)
# saving submission .. ../Results/Demanda/xgboost/c_model_v3/fold_3/shift_10/rmse_val_3.6045_test_4.4203_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.167951155371805
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.374350098286078
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 3.950784084805811
# Saving analysis by week ..
# Predict submission
# CV score: 3.40321
# cv_train_rmse :  3.4032112297738455
# cv_test_rmse  :  4.48484696738635
# create folder ../Results/Demanda/xgboost/c_model_v3/shift_10
# (471730, 1111)
# saving feature importance .. ../Results/Demanda/xgboost/c_model_v3/shift_10/rmse_cv_train_3.4032_rmse_cv_test_4.4848_feature_importance.png
# saving test prediction .. ../Results/Demanda/xgboost/c_model_v3/shift_10/rmse_cv_train_3.4032_rmse_cv_test_4.4848_prediction_test.png
# saving submission .. ../Results/Demanda/xgboost/c_model_v3/shift_10/rmse_cv_train_3.4032_rmse_cv_test_4.4848_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.329413283544445
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.537340342354964
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 4.110983018342492
# Saving analysis by week ..
