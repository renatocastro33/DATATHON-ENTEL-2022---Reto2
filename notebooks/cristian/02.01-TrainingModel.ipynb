# %%
import sys
sys.path.insert(1, '../../Src')
from utils.preprocessing import *
import training


import numpy as np
import pandas as pd
from math import ceil
import warnings
import os

SEED = 42
seed_everything(SEED)
PATH_DATASET = '../../dataset/'
PATH_RESULTS = '../../results/Demanda/'
FILL = False
TARGET = 'Demanda'
N_FOLDS = 3
N_FEATURE_IMPORTANCE = 15



plt.rcParams['axes.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)
# %load_ext autoreload
# %autoreload 2

# %%
submission_top_reference = 'submission_weeks2_repz12_rmse_kaggle_0.686.csv'
print('reading .. ',os.path.join('../../results/',submission_top_reference))
result = pd.read_csv(os.path.join('../../results/',submission_top_reference))
# Out:
# reading ..  ../../results/submission_weeks2_repz12_rmse_kaggle_0.686.csv

# %%
descriptive_columns = ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']
reverse_mapping_file = '../../utils/reverse_dict_mapping_list.txt'

result[['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']] = result['ID'].str.split('|',expand=True)

with open(reverse_mapping_file, 'rb') as f:
    reverse_mapping = pickle.load( f)
    
descriptive_columns = ['Z_MARCA', 'Z_GAMA', 'Z_MODELO',
                       'Z_DEPARTAMENTO', 'Z_PUNTO_VENTA']
i=0
for column in descriptive_columns:
    if column in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']:
        inv_reverse_mapping = {v: k for k, v in reverse_mapping[i].items()}

        result[column] = result[column].map(inv_reverse_mapping)
    i+=1
    
result = result.rename(columns = {TARGET: TARGET+'_real'})

# %%
result.head(1)
# Out:
#                                                   ID  Demanda_real Z_MODELO  \
# 0  009e0874cc07b2180b2b2b1039321041a1f42e66693c49...      0.010752  MOD_170
#
#   Z_PUNTO_VENTA Z_GAMA     Z_WEEK
# 0     PVENT_259  GAM_2  SEMANA_51

# %%
print('Reading dataset')
SHIFT=1
df_train  = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_train_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))
df_test   = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_test_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))

gc.collect()
print('df_train size :',df_train.shape)
print('df_test size  :',df_test.shape)
# Out:
# Reading dataset
# df_train size : (2358650, 1111)
# df_test size  : (471730, 1111)

# %%
features_names = set(df_train.columns)-set([TARGET,'date_block_num',TARGET+'_clipped','release','item_id',
                                            'Z_WEEK_DATE', 'Z_WEEK','date_block_num','year',
                                            'month', 'is_month_end', 'tm_m_end','is_month_start','tm_wm', 'tm_w_end','is_quarter_start','is_year_start',
                                             'day_of_week',
                                            'day_of_year', 'day',
                                            #'Z_MODELO','Z_PUNTO_VENTA','Z_DEPARTAMENTO',
                                            #'Z_GAMA','Z_MARCA', 
                                           ]) 
print(len(features_names))
features_names = list(features_names)
# Out:
# 1093

# %%
for columns in features_names:
    if columns in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA']:
        print(columns)
# Out:
# Z_MODELO
# Z_PUNTO_VENTA
# Z_GAMA

# %%
df_train['week_of_month'] = df_train['week_of_month'].astype('category')
df_test['week_of_month']  = df_test['week_of_month'].astype('category')

# %%
total_features_names = features_names.copy()

# %%
def get_feature_names_shift(shift,total_features_names):
    features_names = []

    for column in total_features_names:
        if 'shift' in column:
            number = column.split('shift_')[1]
            number = int(number.split('_')[0])
            if number>=shift and number<=(shift+3):
                features_names.append(column)
        else:
            features_names.append(column)
    return features_names

# %%
TRAIN_START = '2021-08-01'
TEST_START = '2022-03-01'
TEST_END   = '2022-05-01'
print(df_train.shape)
df_train = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)]
print(df_train.shape)
# Out:
# (2358650, 1111)
# (1839747, 1111)

# %%
PATH_RESULTS = '../../results/Demanda/'
training.PATH_RESULTS = PATH_RESULTS
training.submission_analysis.TARGET  = TARGET


for SHIFT in range(1,11):
    print('*'*20)
    print('*'*20)
    print('WEEK = ',SHIFT)
    print('*'*20)
    print('*'*20)

    features_names = get_feature_names_shift(SHIFT,total_features_names)
    print('len base features = ',len(features_names))
    print('example base features =',features_names[:5])
    
    ################### CV MODEL RANDOM SPLIT ###############


    
    for idx,model_type in enumerate(['xgboost']):

    
        X_train      = df_train[((df_train['Z_WEEK_DATE'] >= TRAIN_START) &(df_train['Z_WEEK_DATE'] < TEST_START))&
                               (df_train['Z_WEEK_DATE'] != '2022-04-11')].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT model_type = ',model_type,'c_model_v2')
        print('*'*20)

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]
        X_train = X_train[features_names]
        X_test  = X_test[features_names]
        X_submission = df_test[features_names]        
        


        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        model_version = 'c_model_v2'
        training.TARGET = TARGET
        training.SHIFT = SHIFT

        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                            X_test,y_test,X_submission,df_test,result,N_FOLDS)

    
        
        
        #'''
        if idx ==0 :
            features_names = list(df_feature_importance['feature'][:30].values)
            
        ################### CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE ###############
        important_features = list(df_feature_importance[:N_FEATURE_IMPORTANCE]['feature'])
        
        X_train      = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)&(df_train['Z_WEEK_DATE'] < TEST_START)].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]

        X_train = X_train[important_features]
        X_test  = X_test[important_features]
        X_submission = df_test[important_features]

        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type = ',model_type,'c_model_v3')
        print('*'*20)
        
        model_version = 'c_model_v3'
        training.TARGET = TARGET
        training.SHIFT = SHIFT


        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                               X_test,y_test,X_submission,df_test,result,N_FOLDS)
        #'''
# Out:
# ********************
# ********************
# WEEK =  1
# ********************
# ********************
# len base features =  314
# example base features = ['Demanda_lag_shift_4', 'enc_Z_MODELO_Z_GAMA_max', 'shift_2_roll_4_std_Z_MARCA_Z_DEPARTAMENTO', 'enc_Z_MODELO_max', 'shift_3_roll_4_mean_Z_MODELO_Z_PUNTO_VENTA']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 314)
# X_test           (377384, 314)
# X_submission     (471730, 314)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_1
# create folder ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_1
# [02:37:47] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01533	validation_1-rmse:5.93895
# [20]	validation_0-rmse:5.67476	validation_1-rmse:5.60604
# [40]	validation_0-rmse:4.80300	validation_1-rmse:4.79579
# [60]	validation_0-rmse:3.94329	validation_1-rmse:4.04526
# [80]	validation_0-rmse:3.28855	validation_1-rmse:3.50159
# [100]	validation_0-rmse:2.82686	validation_1-rmse:3.14404
# [120]	validation_0-rmse:2.51602	validation_1-rmse:2.92972
# [140]	validation_0-rmse:2.31069	validation_1-rmse:2.80413
# [160]	validation_0-rmse:2.18254	validation_1-rmse:2.72948
# [180]	validation_0-rmse:2.10289	validation_1-rmse:2.68549
# [200]	validation_0-rmse:2.04980	validation_1-rmse:2.65885
# [220]	validation_0-rmse:2.01287	validation_1-rmse:2.64080
# [240]	validation_0-rmse:1.99043	validation_1-rmse:2.63024
# [260]	validation_0-rmse:1.97463	validation_1-rmse:2.62380
# [280]	validation_0-rmse:1.96261	validation_1-rmse:2.62046
# [300]	validation_0-rmse:1.95397	validation_1-rmse:2.61712
# [320]	validation_0-rmse:1.94616	validation_1-rmse:2.61514
# [340]	validation_0-rmse:1.93967	validation_1-rmse:2.61391
# [360]	validation_0-rmse:1.93415	validation_1-rmse:2.61354
# [380]	validation_0-rmse:1.92847	validation_1-rmse:2.61296
# [400]	validation_0-rmse:1.92032	validation_1-rmse:2.61277
# [420]	validation_0-rmse:1.91394	validation_1-rmse:2.61170
# [440]	validation_0-rmse:1.90714	validation_1-rmse:2.61073
# [460]	validation_0-rmse:1.89908	validation_1-rmse:2.60768
# [480]	validation_0-rmse:1.89107	validation_1-rmse:2.60558
# [500]	validation_0-rmse:1.87671	validation_1-rmse:2.60401
# [520]	validation_0-rmse:1.86355	validation_1-rmse:2.60229
# [540]	validation_0-rmse:1.85093	validation_1-rmse:2.60377
# [560]	validation_0-rmse:1.84265	validation_1-rmse:2.60496
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.602283359017401
# Score test : 2.245421134550627
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.6023_test_2.2454_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.6023_test_2.2454_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.6023_test_2.2454_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.6023_test_2.2454_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.964892977910124
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8059742660563598
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1118867819140354
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_1
# create folder ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_1
# [02:39:01] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10006	validation_1-rmse:5.76349
# [20]	validation_0-rmse:5.75704	validation_1-rmse:5.43222
# [40]	validation_0-rmse:4.87219	validation_1-rmse:4.65802
# [60]	validation_0-rmse:4.00078	validation_1-rmse:3.95044
# [80]	validation_0-rmse:3.33547	validation_1-rmse:3.44806
# [100]	validation_0-rmse:2.86462	validation_1-rmse:3.12182
# [120]	validation_0-rmse:2.54569	validation_1-rmse:2.92175
# [140]	validation_0-rmse:2.33738	validation_1-rmse:2.80132
# [160]	validation_0-rmse:2.20505	validation_1-rmse:2.73161
# [180]	validation_0-rmse:2.12220	validation_1-rmse:2.69084
# [200]	validation_0-rmse:2.07048	validation_1-rmse:2.66989
# [220]	validation_0-rmse:2.03366	validation_1-rmse:2.65756
# [240]	validation_0-rmse:2.00891	validation_1-rmse:2.64861
# [260]	validation_0-rmse:1.99146	validation_1-rmse:2.64328
# [280]	validation_0-rmse:1.97840	validation_1-rmse:2.64033
# [300]	validation_0-rmse:1.96893	validation_1-rmse:2.63836
# [320]	validation_0-rmse:1.96043	validation_1-rmse:2.63683
# [340]	validation_0-rmse:1.95344	validation_1-rmse:2.63615
# [360]	validation_0-rmse:1.94385	validation_1-rmse:2.63564
# [380]	validation_0-rmse:1.93347	validation_1-rmse:2.63676
# [398]	validation_0-rmse:1.92691	validation_1-rmse:2.63794
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.634684269016561
# Score test : 2.2146645294409115
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.6347_test_2.2147_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.6347_test_2.2147_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.6347_test_2.2147_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_1/rmse_val_2.6347_test_2.2147_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9597520992496218
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.7942732566683257
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1123068104400557
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_1
# create folder ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_1
# [02:40:06] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85187	validation_1-rmse:6.25705
# [20]	validation_0-rmse:5.51564	validation_1-rmse:5.91783
# [40]	validation_0-rmse:4.67682	validation_1-rmse:5.07478
# [60]	validation_0-rmse:3.85133	validation_1-rmse:4.28084
# [80]	validation_0-rmse:3.22116	validation_1-rmse:3.69171
# [100]	validation_0-rmse:2.77814	validation_1-rmse:3.29196
# [120]	validation_0-rmse:2.47723	validation_1-rmse:3.03730
# [140]	validation_0-rmse:2.28472	validation_1-rmse:2.88059
# [160]	validation_0-rmse:2.16061	validation_1-rmse:2.78198
# [180]	validation_0-rmse:2.07909	validation_1-rmse:2.72024
# [200]	validation_0-rmse:2.02794	validation_1-rmse:2.68244
# [220]	validation_0-rmse:1.99401	validation_1-rmse:2.65929
# [240]	validation_0-rmse:1.97100	validation_1-rmse:2.64386
# [260]	validation_0-rmse:1.95350	validation_1-rmse:2.63090
# [280]	validation_0-rmse:1.94196	validation_1-rmse:2.62328
# [300]	validation_0-rmse:1.93392	validation_1-rmse:2.61769
# [320]	validation_0-rmse:1.92743	validation_1-rmse:2.61363
# [340]	validation_0-rmse:1.92246	validation_1-rmse:2.61105
# [360]	validation_0-rmse:1.91617	validation_1-rmse:2.60737
# [380]	validation_0-rmse:1.90698	validation_1-rmse:2.60449
# [400]	validation_0-rmse:1.90146	validation_1-rmse:2.60212
# [420]	validation_0-rmse:1.89475	validation_1-rmse:2.60181
# [440]	validation_0-rmse:1.88505	validation_1-rmse:2.60225
# [460]	validation_0-rmse:1.87327	validation_1-rmse:2.60321
# [465]	validation_0-rmse:1.87014	validation_1-rmse:2.60439
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.6008755363637057
# Score test : 2.253315997354772
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.6009_test_2.2533_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.6009_test_2.2533_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.6009_test_2.2533_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_1/rmse_val_2.6009_test_2.2533_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.988064397190073
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8626230217873765
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.106047381579323
# Saving analysis by week ..
# Predict submission
# CV score: 2.61266
# cv_train_rmse :  2.6126610523023848
# cv_test_rmse  :  2.1817154319956105
# create folder ../../results/Demanda/xgboost/c_model_v2/shift_1
# (471730, 1111)
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v2/shift_1/rmse_cv_train_2.6127_rmse_cv_test_2.1817_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v2/shift_1/rmse_cv_train_2.6127_rmse_cv_test_2.1817_prediction_test.png
# saving submission .. ../../results/Demanda/xgboost/c_model_v2/shift_1/rmse_cv_train_2.6127_rmse_cv_test_2.1817_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9612726400864362
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.804341505920007
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.106545149650859
# Saving analysis by week ..
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v3/fold_1/shift_1
# create folder ../../results/Demanda/xgboost/c_model_v3/fold_1/shift_1
# [02:41:32] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01533	validation_1-rmse:5.93895
# [20]	validation_0-rmse:5.67562	validation_1-rmse:5.60474
# [40]	validation_0-rmse:4.82068	validation_1-rmse:4.79544
# [60]	validation_0-rmse:3.99760	validation_1-rmse:4.04745
# [80]	validation_0-rmse:3.37758	validation_1-rmse:3.50884
# [100]	validation_0-rmse:2.95102	validation_1-rmse:3.16592
# [120]	validation_0-rmse:2.67254	validation_1-rmse:2.96470
# [140]	validation_0-rmse:2.49461	validation_1-rmse:2.85289
# [160]	validation_0-rmse:2.38689	validation_1-rmse:2.79230
# [180]	validation_0-rmse:2.31661	validation_1-rmse:2.76022
# [200]	validation_0-rmse:2.27311	validation_1-rmse:2.74068
# [220]	validation_0-rmse:2.24617	validation_1-rmse:2.73191
# [240]	validation_0-rmse:2.22929	validation_1-rmse:2.72456
WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85187	validation_1-rmse:6.25705
# [20]	validation_0-rmse:5.51654	validation_1-rmse:5.91883
# [40]	validation_0-rmse:4.69147	validation_1-rmse:5.06763
# [60]	validation_0-rmse:3.89777	validation_1-rmse:4.26273
# [80]	validation_0-rmse:3.30782	validation_1-rmse:3.67155
# [100]	validation_0-rmse:2.90186	validation_1-rmse:3.27595
# [120]	validation_0-rmse:2.63781	validation_1-rmse:3.02524
# [140]	validation_0-rmse:2.46974	validation_1-rmse:2.87064
# [160]	validation_0-rmse:2.36674	validation_1-rmse:2.77877
# [180]	validation_0-rmse:2.30422	validation_1-rmse:2.72596
# [200]	validation_0-rmse:2.26469	validation_1-rmse:2.69487
# [220]	validation_0-rmse:2.23780	validation_1-rmse:2.67529
# [240]	validation_0-rmse:2.22165	validation_1-rmse:2.66361
# [260]	validation_0-rmse:2.21020	validation_1-rmse:2.65519
# [280]	validation_0-rmse:2.20255	validation_1-rmse:2.64970
# [300]	validation_0-rmse:2.19613	validation_1-rmse:2.64529
# [320]	validation_0-rmse:2.19102	validation_1-rmse:2.64299
# [340]	validation_0-rmse:2.18749	validation_1-rmse:2.64080
# [360]	validation_0-rmse:2.18458	validation_1-rmse:2.63919
# [380]	validation_0-rmse:2.18099	validation_1-rmse:2.63851
# [400]	validation_0-rmse:2.17691	validation_1-rmse:2.63749
# [420]	validation_0-rmse:2.17445	validation_1-rmse:2.63696
# [440]	validation_0-rmse:2.16388	validation_1-rmse:2.63634
# [460]	validation_0-rmse:2.15690	validation_1-rmse:2.63661
# [480]	validation_0-rmse:2.14825	validation_1-rmse:2.63696
# [490]	validation_0-rmse:2.14543	validation_1-rmse:2.63774
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.636125358237931
# Score test : 2.3493503249572214
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.6361_test_2.3494_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.6361_test_2.3494_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.6361_test_2.3494_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.6361_test_2.3494_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0321594291939102
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8741761596870603
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.178716965047113
# Saving analysis by week ..
# Predict submission
# CV score: 2.66404
# cv_train_rmse :  2.6640415930802592
# cv_test_rmse  :  2.2413967973615683
# create folder ../../results/Demanda/xgboost/c_model_v3/shift_1
# (471730, 1111)
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v3/shift_1/rmse_cv_train_2.664_rmse_cv_test_2.2414_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v3/shift_1/rmse_cv_train_2.664_rmse_cv_test_2.2414_prediction_test.png
# saving submission .. ../../results/Demanda/xgboost/c_model_v3/shift_1/rmse_cv_train_2.664_rmse_cv_test_2.2414_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0089974386721323
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8305153639246194
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.172867902017583
# Saving analysis by week ..
# ********************
# ********************
# WEEK =  2
# ********************
# ********************
# len base features =  314
# example base features = ['Demanda_lag_shift_4', 'enc_Z_MODELO_Z_GAMA_max', 'shift_5_roll_2_mean_Z_MODELO_Z_DEPARTAMENTO', 'shift_2_roll_4_std_Z_MARCA_Z_DEPARTAMENTO', 'enc_Z_MODELO_max']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 314)
# X_test           (377384, 314)
# X_submission     (471730, 314)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_2
# create folder ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_2
# [02:43:15] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01546	validation_1-rmse:5.93908
# [20]	validation_0-rmse:5.69399	validation_1-rmse:5.62562
# [40]	validation_0-rmse:4.90147	validation_1-rmse:4.88121
# [60]	validation_0-rmse:4.13949	validation_1-rmse:4.20309
# [80]	validation_0-rmse:3.56798	validation_1-rmse:3.72712
# [100]	validation_0-rmse:3.17181	validation_1-rmse:3.41793
# [120]	validation_0-rmse:2.90751	validation_1-rmse:3.22841
# [140]	validation_0-rmse:2.73514	validation_1-rmse:3.11715
# [160]	validation_0-rmse:2.62372	validation_1-rmse:3.05196
# [180]	validation_0-rmse:2.54856	validation_1-rmse:3.01608
# [200]	validation_0-rmse:2.49417	validation_1-rmse:2.99650
# [220]	validation_0-rmse:2.45270	validation_1-rmse:2.98503
# [240]	validation_0-rmse:2.42834	validation_1-rmse:2.97767
# [260]	validation_0-rmse:2.41008	validation_1-rmse:2.97293
# [280]	validation_0-rmse:2.39799	validation_1-rmse:2.96909
# [300]	validation_0-rmse:2.37976	validation_1-rmse:2.96424
# [320]	validation_0-rmse:2.35940	validation_1-rmse:2.95983
# [340]	validation_0-rmse:2.34432	validation_1-rmse:2.95731
# [360]	validation_0-rmse:2.33133	validation_1-rmse:2.95517
# [380]	validation_0-rmse:2.31941	validation_1-rmse:2.95139
# [400]	validation_0-rmse:2.30052	validation_1-rmse:2.94523
# [420]	validation_0-rmse:2.28638	validation_1-rmse:2.94410
# [440]	validation_0-rmse:2.26872	validation_1-rmse:2.94199
# [460]	validation_0-rmse:2.25014	validation_1-rmse:2.94004
# [480]	validation_0-rmse:2.23600	validation_1-rmse:2.93968
# [500]	validation_0-rmse:2.22613	validation_1-rmse:2.93871
# [520]	validation_0-rmse:2.21616	validation_1-rmse:2.93926
# [529]	validation_0-rmse:2.21055	validation_1-rmse:2.93953
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.938315988223617
# Score test : 3.0146622195654813
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_2/rmse_val_2.9383_test_3.0147_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_2/rmse_val_2.9383_test_3.0147_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_2/rmse_val_2.9383_test_3.0147_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_2/rmse_val_2.9383_test_3.0147_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8297944879191168
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.5795793274450094
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0496889725874845
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_2
# create folder ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_2
# [02:44:26] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10019	validation_1-rmse:5.76364
# [20]	validation_0-rmse:5.77649	validation_1-rmse:5.45600
# [40]	validation_0-rmse:4.96582	validation_1-rmse:4.76502
# [60]	validation_0-rmse:4.17804	validation_1-rmse:4.14119
# [80]	validation_0-rmse:3.58128	validation_1-rmse:3.69412
# [100]	validation_0-rmse:3.16579	validation_1-rmse:3.39884
# [120]	validation_0-rmse:2.89407	validation_1-rmse:3.21481
# [140]	validation_0-rmse:2.71592	validation_1-rmse:3.10222
# [160]	validation_0-rmse:2.59666	validation_1-rmse:3.03324
# [180]	validation_0-rmse:2.51253	validation_1-rmse:2.98787
# [200]	validation_0-rmse:2.45331	validation_1-rmse:2.95773
# [220]	validation_0-rmse:2.41408	validation_1-rmse:2.93964
# [240]	validation_0-rmse:2.38414	validation_1-rmse:2.92831
# [260]	validation_0-rmse:2.36397	validation_1-rmse:2.91936
# [280]	validation_0-rmse:2.34714	validation_1-rmse:2.91149
# [300]	validation_0-rmse:2.33625	validation_1-rmse:2.90772
# [320]	validation_0-rmse:2.32233	validation_1-rmse:2.90443
# [340]	validation_0-rmse:2.30700	validation_1-rmse:2.90613
# [360]	validation_0-rmse:2.29102	validation_1-rmse:2.90572
# [361]	validation_0-rmse:2.29070	validation_1-rmse:2.90557
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.90421418655049
# Score test : 2.7350348227823873
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.9042_test_2.735_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.9042_test_2.735_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.9042_test_2.735_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.9042_test_2.735_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8361086794476116
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.5365134155152886
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.093255046435395
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_2
# create folder ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_2
# [02:45:29] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85201	validation_1-rmse:6.25718
# [20]	validation_0-rmse:5.53485	validation_1-rmse:5.94114
# [40]	validation_0-rmse:4.76460	validation_1-rmse:5.18522
# [60]	validation_0-rmse:4.02408	validation_1-rmse:4.49944
# [80]	validation_0-rmse:3.46892	validation_1-rmse:4.00603
# [100]	validation_0-rmse:3.08836	validation_1-rmse:3.67891
# [120]	validation_0-rmse:2.83255	validation_1-rmse:3.47051
# [140]	validation_0-rmse:2.66899	validation_1-rmse:3.33897
# [160]	validation_0-rmse:2.56498	validation_1-rmse:3.25683
# [180]	validation_0-rmse:2.49342	validation_1-rmse:3.20189
# [200]	validation_0-rmse:2.44157	validation_1-rmse:3.16469
# [220]	validation_0-rmse:2.40042	validation_1-rmse:3.13655
# [240]	validation_0-rmse:2.37310	validation_1-rmse:3.11735
# [260]	validation_0-rmse:2.35219	validation_1-rmse:3.10212
# [280]	validation_0-rmse:2.34118	validation_1-rmse:3.09495
# [300]	validation_0-rmse:2.33293	validation_1-rmse:3.08752
# [320]	validation_0-rmse:2.32110	validation_1-rmse:3.08423
# [340]	validation_0-rmse:2.31287	validation_1-rmse:3.08025
# [360]	validation_0-rmse:2.30000	validation_1-rmse:3.08025
# [380]	validation_0-rmse:2.28814	validation_1-rmse:3.08428
# [393]	validation_0-rmse:2.27573	validation_1-rmse:3.08436
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.0789937563504264
# Score test : 2.556839523979152
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_2/rmse_val_3.079_test_2.5568_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_2/rmse_val_3.079_test_2.5568_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_2/rmse_val_3.079_test_2.5568_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v2/fold_3/shift_2/rmse_val_3.079_test_2.5568_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8613326286759388
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.65580548257059
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0463202371663467
# Saving analysis by week ..
# Predict submission
# CV score: 2.97480
# cv_train_rmse :  2.974803242627628
# cv_test_rmse  :  2.664181878121152
# create folder ../../results/Demanda/xgboost/c_model_v2/shift_2
# (471730, 1111)
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v2/shift_2/rmse_cv_train_2.9748_rmse_cv_test_2.6642_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v2/shift_2/rmse_cv_train_2.9748_rmse_cv_test_2.6642_prediction_test.png
# saving submission .. ../../results/Demanda/xgboost/c_model_v2/shift_2/rmse_cv_train_2.9748_rmse_cv_test_2.6642_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8053809992373253
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.5088908924294864
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0596236014276195
# Saving analysis by week ..
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v3/fold_1/shift_2
# create folder ../../results/Demanda/xgboost/c_model_v3/fold_1/shift_2
# [02:46:50] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01547	validation_1-rmse:5.93908
# [20]	validation_0-rmse:5.69657	validation_1-rmse:5.62452
# [40]	validation_0-rmse:4.92904	validation_1-rmse:4.88115
# [60]	validation_0-rmse:4.20969	validation_1-rmse:4.21823
# [80]	validation_0-rmse:3.68619	validation_1-rmse:3.76211
# [100]	validation_0-rmse:3.33243	validation_1-rmse:3.47772
# [120]	validation_0-rmse:3.10613	validation_1-rmse:3.31184
# [140]	validation_0-rmse:2.96478	validation_1-rmse:3.21972
# [160]	validation_0-rmse:2.87594	validation_1-rmse:3.16912
# [180]	validation_0-rmse:2.81705	validation_1-rmse:3.14174
# [200]	validation_0-rmse:2.77688	validation_1-rmse:3.12881
# [220]	validation_0-rmse:2.74769	validation_1-rmse:3.12080
# [240]	validation_0-rmse:2.72561	validation_1-rmse:3.11783
# [260]	validation_0-rmse:2.71212	validation_1-rmse:3.11768
# [280]	validation_0-rmse:2.70204	validation_1-rmse:3.11822
# [300]	validation_0-rmse:2.69536	validation_1-rmse:3.11851
# [304]	validation_0-rmse:2.69436	validation_1-rmse:3.11870
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3
# [280]	validation_0-rmse:2.64161	validation_1-rmse:3.24881
# [300]	validation_0-rmse:2.63503	validation_1-rmse:3.24575
# [320]	validation_0-rmse:2.62989	validation_1-rmse:3.24405
# [340]	validation_0-rmse:2.62618	validation_1-rmse:3.24336
# [360]	validation_0-rmse:2.61708	validation_1-rmse:3.24314
# [380]	validation_0-rmse:2.61103	validation_1-rmse:3.24270
# [400]	validation_0-rmse:2.60622	validation_1-rmse:3.24283
# [420]	validation_0-rmse:2.60024	validation_1-rmse:3.24297
# [440]	validation_0-rmse:2.59274	validation_1-rmse:3.24443
# [454]	validation_0-rmse:2.58759	validation_1-rmse:3.24583
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.2423529337857886
# Score test : 2.8821457809663396
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_2/rmse_val_3.2424_test_2.8821_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_2/rmse_val_3.2424_test_2.8821_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_2/rmse_val_3.2424_test_2.8821_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_2/rmse_val_3.2424_test_2.8821_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8154646511236403
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.3802561938174185
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.164882592287077
# Saving analysis by week ..
# Predict submission
# CV score: 3.13021
# cv_train_rmse :  3.130212415255939
# cv_test_rmse  :  2.7725492018266533
# create folder ../../results/Demanda/xgboost/c_model_v3/shift_2
# (471730, 1111)
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v3/shift_2/rmse_cv_train_3.1302_rmse_cv_test_2.7725_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v3/shift_2/rmse_cv_train_3.1302_rmse_cv_test_2.7725_prediction_test.png
# saving submission .. ../../results/Demanda/xgboost/c_model_v3/shift_2/rmse_cv_train_3.1302_rmse_cv_test_2.7725_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.796166095596082
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.3457353942211625
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1543958630386757
# Saving analysis by week ..
# ********************
# ********************
# WEEK =  3
# ********************
# ********************
# len base features =  314
# example base features = ['Demanda_lag_shift_4', 'enc_Z_MODELO_Z_GAMA_max', 'shift_5_roll_2_mean_Z_MODELO_Z_DEPARTAMENTO', 'enc_Z_MODELO_max', 'shift_3_roll_4_mean_Z_MODELO_Z_PUNTO_VENTA']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 314)
# X_test           (377384, 314)
# X_submission     (471730, 314)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_3
# create folder ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_3
# [02:48:29] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01556	validation_1-rmse:5.93918
# [20]	validation_0-rmse:5.70750	validation_1-rmse:5.63949
# [40]	validation_0-rmse:4.95417	validation_1-rmse:4.95010
# [60]	validation_0-rmse:4.23318	validation_1-rmse:4.32850
# [80]	validation_0-rmse:3.69664	validation_1-rmse:3.89485
# [100]	validation_0-rmse:3.31503	validation_1-rmse:3.61143
# [120]	validation_0-rmse:3.06467	validation_1-rmse:3.44595
# [140]	validation_0-rmse:2.90285	validation_1-rmse:3.34526
# [160]	validation_0-rmse:2.78746	validation_1-rmse:3.28794
# [180]	validation_0-rmse:2.71084	validation_1-rmse:3.25100
# [200]	validation_0-rmse:2.65992	validation_1-rmse:3.23086
# [220]	validation_0-rmse:2.62398	validation_1-rmse:3.21494
# [240]	validation_0-rmse:2.59676	validation_1-rmse:3.20563
# [260]	validation_0-rmse:2.57858	validation_1-rmse:3.19859
# [280]	validation_0-rmse:2.56534	validation_1-rmse:3.19544
# [300]	validation_0-rmse:2.54491	validation_1-rmse:3.18992
# [320]	validation_0-rmse:2.51791	validation_1-rmse:3.17982
# [340]	validation_0-rmse:2.50334	validation_1-rmse:3.17372
# [360]	validation_0-rmse:2.48376	validation_1-rmse:3.16785
# [380]	validation_0-rmse:2.45782	validation_1-rmse:3.16463
# [400]	validation_0-rmse:2.43991	validation_1-rmse:3.16100
# [420]	validation_0-rmse:2.42146	validation_1-rmse:3.15671
# [440]	validation_0-rmse:2.40955	validation_1-rmse:3.15323
# [460]	validation_0-rmse:2.39477	validation_1-rmse:3.14928
# [480]	validation_0-rmse:2.37763	validation_1-rmse:3.14460
# [500]	validation_0-rmse:2.36229	validation_1-rmse:3.14366
# [520]	validation_0-rmse:2.33923	validation_1-rmse:3.13929
# [540]	validation_0-rmse:2.32257	validation_1-rmse:3.13598
# [560]	validation_0-rmse:2.30459	validation_1-rmse:3.13304
# [580]	validation_0-rmse:2.29436	validation_1-rmse:3.13069
# [600]	validation_0-rmse:2.27584	validation_1-rmse:3.12992
# [620]	validation_0-rmse:2.25910	validation_1-rmse:3.12682
# [640]	validation_0-rmse:2.24233	validation_1-rmse:3.12423
# [660]	validation_0-rmse:2.22386	validation_1-rmse:3.12227
# [680]	validation_0-rmse:2.21109	validation_1-rmse:3.11760
# [700]	validation_0-rmse:2.19877	validation_1-rmse:3.11528
# [720]	validation_0-rmse:2.18752	validation_1-rmse:3.11474
# [740]	validation_0-rmse:2.17437	validation_1-rmse:3.11354
# [760]	validation_0-rmse:2.15751	validation_1-rmse:3.11369
# [780]	validation_0-rmse:2.14720	validation_1-rmse:3.11412
# [784]	validation_0-rmse:2.14554	validation_1-rmse:3.11365
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.1124868567250963
# Score test : 3.798878496184611
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_3/rmse_val_3.1125_test_3.7989_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_3/rmse_val_3.1125_test_3.7989_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_3/rmse_val_3.1125_test_3.7989_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v2/fold_1/shift_3/rmse_val_3.1125_test_3.7989_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8739130275368978
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.7514837259984306
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9888199584446198
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_3
# create folder ../../results/Demanda/xgboost/c_model_v2/fold_2/shift_3
# [02:49:54] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10029	validation_1-rmse:5.76376
# [20]	validation_0-rmse:5.78942	validation_1-rmse:5.47059
# [40]	validation_0-rmse:5.02222	validation_1-rmse:4.81825
# [60]	validation_0-rmse:4.29150	validation_1-rmse:4.23705
# ...
# [60]	validation_0-rmse:4.47587	validation_1-rmse:4.51147
# [80]	validation_0-rmse:4.02571	validation_1-rmse:4.13037
# [100]	validation_0-rmse:3.72174	validation_1-rmse:3.88398
# [120]	validation_0-rmse:3.51700	validation_1-rmse:3.72523
# [140]	validation_0-rmse:3.37752	validation_1-rmse:3.62424
# [160]	validation_0-rmse:3.29002	validation_1-rmse:3.56054
# [180]	validation_0-rmse:3.22083	validation_1-rmse:3.52021
# [200]	validation_0-rmse:3.17561	validation_1-rmse:3.49556
# [220]	validation_0-rmse:3.13784	validation_1-rmse:3.47768
# [240]	validation_0-rmse:3.10157	validation_1-rmse:3.46516
# [260]	validation_0-rmse:3.07363	validation_1-rmse:3.45511
# [280]	validation_0-rmse:3.05448	validation_1-rmse:3.44446
# [300]	validation_0-rmse:3.03758	validation_1-rmse:3.43700
# [320]	validation_0-rmse:3.02626	validation_1-rmse:3.43219
feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v3/fold_2/shift_8/rmse_val_3.1926_test_3.7036_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v3/fold_2/shift_8/rmse_val_3.1926_test_3.7036_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v3/fold_2/shift_8/rmse_val_3.1926_test_3.7036_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.2116529790555175
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.217620393848564
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.205669419545284
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_8
# create folder ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_8
# [03:26:51] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85234	validation_1-rmse:6.25750
# [20]	validation_0-rmse:5.58107	validation_1-rmse:5.98639
# [40]	validation_0-rmse:4.95559	validation_1-rmse:5.38003
# [60]	validation_0-rmse:4.36028	validation_1-rmse:4.83863
# [80]	validation_0-rmse:3.92958	validation_1-rmse:4.44650
# [100]	validation_0-rmse:3.63321	validation_1-rmse:4.18052
# [120]	validation_0-rmse:3.44137	validation_1-rmse:4.00551
# [140]	validation_0-rmse:3.31212	validation_1-rmse:3.88737
# [160]	validation_0-rmse:3.21986	validation_1-rmse:3.79857
# [180]	validation_0-rmse:3.15532	validation_1-rmse:3.73717
# [200]	validation_0-rmse:3.11440	validation_1-rmse:3.69829
# [220]	validation_0-rmse:3.07936	validation_1-rmse:3.66503
# [240]	validation_0-rmse:3.04954	validation_1-rmse:3.63760
# [260]	validation_0-rmse:3.02396	validation_1-rmse:3.61407
# [280]	validation_0-rmse:3.00268	validation_1-rmse:3.59509
# [300]	validation_0-rmse:2.98915	validation_1-rmse:3.58255
# [320]	validation_0-rmse:2.97677	validation_1-rmse:3.57200
# [340]	validation_0-rmse:2.95681	validation_1-rmse:3.55774
# [360]	validation_0-rmse:2.93572	validation_1-rmse:3.54429
# [380]	validation_0-rmse:2.91206	validation_1-rmse:3.53493
# [400]	validation_0-rmse:2.88590	validation_1-rmse:3.52072
# [420]	validation_0-rmse:2.86273	validation_1-rmse:3.50907
# [440]	validation_0-rmse:2.83448	validation_1-rmse:3.49460
# [460]	validation_0-rmse:2.81834	validation_1-rmse:3.48588
# [480]	validation_0-rmse:2.80695	validation_1-rmse:3.47913
# [500]	validation_0-rmse:2.79169	validation_1-rmse:3.47491
# [520]	validation_0-rmse:2.77393	validation_1-rmse:3.47007
# [540]	validation_0-rmse:2.76489	validation_1-rmse:3.46415
# [560]	validation_0-rmse:2.75548	validation_1-rmse:3.45602
# [580]	validation_0-rmse:2.74551	validation_1-rmse:3.44806
# [600]	validation_0-rmse:2.73070	validation_1-rmse:3.44330
# [620]	validation_0-rmse:2.72272	validation_1-rmse:3.43828
# [640]	validation_0-rmse:2.71287	validation_1-rmse:3.43493
# [660]	validation_0-rmse:2.69936	validation_1-rmse:3.42967
# [680]	validation_0-rmse:2.68570	validation_1-rmse:3.42405
# [700]	validation_0-rmse:2.67497	validation_1-rmse:3.42290
# [720]	validation_0-rmse:2.65786	validation_1-rmse:3.42052
# [740]	validation_0-rmse:2.64183	validation_1-rmse:3.41755
# [760]	validation_0-rmse:2.61801	validation_1-rmse:3.40725
# [780]	validation_0-rmse:2.60176	validation_1-rmse:3.40357
# [800]	validation_0-rmse:2.58712	validation_1-rmse:3.40219
# [820]	validation_0-rmse:2.56759	validation_1-rmse:3.39716
# [840]	validation_0-rmse:2.55961	validation_1-rmse:3.39581
# [860]	validation_0-rmse:2.54930	validation_1-rmse:3.39329
# [880]	validation_0-rmse:2.53934	validation_1-rmse:3.39022
# [900]	validation_0-rmse:2.52652	validation_1-rmse:3.38652
# [920]	validation_0-rmse:2.51663	validation_1-rmse:3.38530
# [940]	validation_0-rmse:2.50898	validation_1-rmse:3.38223
# [960]	validation_0-rmse:2.50073	validation_1-rmse:3.37877
# [980]	validation_0-rmse:2.49155	validation_1-rmse:3.37739
# [1000]	validation_0-rmse:2.47989	validation_1-rmse:3.37334
# [1020]	validation_0-rmse:2.47138	validation_1-rmse:3.37339
# [1040]	validation_0-rmse:2.45735	validation_1-rmse:3.36993
# [1060]	validation_0-rmse:2.44280	validation_1-rmse:3.36265
# [1080]	validation_0-rmse:2.42714	validation_1-rmse:3.35922
# [1100]	validation_0-rmse:2.41327	validation_1-rmse:3.35719
# [1120]	validation_0-rmse:2.39775	validation_1-rmse:3.35462
# [1140]	validation_0-rmse:2.38653	validation_1-rmse:3.35350
# [1160]	validation_0-rmse:2.37485	validation_1-rmse:3.35202
# [1180]	validation_0-rmse:2.36721	validation_1-rmse:3.34945
# [1200]	validation_0-rmse:2.36097	validation_1-rmse:3.34723
# [1220]	validation_0-rmse:2.35525	validation_1-rmse:3.34652
# [1240]	validation_0-rmse:2.34449	validation_1-rmse:3.34507
# [1260]	validation_0-rmse:2.32306	validation_1-rmse:3.34038
# [1280]	validation_0-rmse:2.31837	validation_1-rmse:3.33842
# [1300]	validation_0-rmse:2.31098	validation_1-rmse:3.33866
# [1320]	validation_0-rmse:2.30347	validation_1-rmse:3.33880
# [1328]	validation_0-rmse:2.30125	validation_1-rmse:3.33794
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 3.337305178798715
# Score test : 3.682252683846296
# end !
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_8/rmse_val_3.3373_test_3.6823_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_8/rmse_val_3.3373_test_3.6823_prediction_test.png
# saving model.. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_8/rmse_val_3.3373_test_3.6823_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda/xgboost/c_model_v3/fold_3/shift_8/rmse_val_3.3373_test_3.6823_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.4460772809042997
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.345455942539333
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.5427199118108303
# Saving analysis by week ..
# Predict submission
# CV score: 3.28883
# cv_train_rmse :  3.288828130943081
# cv_test_rmse  :  3.7328682935954562
# create folder ../../results/Demanda/xgboost/c_model_v3/shift_8
# (471730, 1111)
# saving feature importance .. ../../results/Demanda/xgboost/c_model_v3/shift_8/rmse_cv_train_3.2888_rmse_cv_test_3.7329_feature_importance.png
# saving test prediction .. ../../results/Demanda/xgboost/c_model_v3/shift_8/rmse_cv_train_3.2888_rmse_cv_test_3.7329_prediction_test.png
# saving submission .. ../../results/Demanda/xgboost/c_model_v3/shift_8/rmse_cv_train_3.2888_rmse_cv_test_3.7329_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.54920932309177
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.634102530128343
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.461389893261012
# Saving analysis by week ..
# ********************
# ********************
# WEEK =  9
# ********************
# ********************
# len base features =  314
# example base features = ['enc_Z_MODELO_Z_GAMA_max', 'enc_Z_MODELO_max', 'enc_Z_MODELO_Z_GAMA_std', 'shift_11_roll_2_mean_Z_MODELO', 'enc_Z_GAMA_Z_MARCA_mean']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 314)
# X_test           (377384, 314)
# X_submission     (471730, 314)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
