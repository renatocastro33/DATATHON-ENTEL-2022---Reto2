# %%
import sys
sys.path.insert(1, '../../Src')
from utils.preprocessing import *
import training


import numpy as np
import pandas as pd
from math import ceil
import warnings
import os

SEED = 42
seed_everything(SEED)
PATH_DATASET = '../../dataset/'
PATH_RESULTS = '../../results/Demanda/'
FILL = False
TARGET = 'Demanda'
N_FOLDS = 3
N_FEATURE_IMPORTANCE = 15



plt.rcParams['axes.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)
# %load_ext autoreload
# %autoreload 2

# %%
submission_top_reference = 'submission_weeks2_repz12_rmse_kaggle_0.686.csv'
print('reading .. ',os.path.join('../../results/',submission_top_reference))
result = pd.read_csv(os.path.join('../../results/',submission_top_reference))
# Out:
# reading ..  ../../results/submission_weeks2_repz12_rmse_kaggle_0.686.csv

# %%
descriptive_columns = ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']
reverse_mapping_file = '../../utils/reverse_dict_mapping_list.txt'

result[['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']] = result['ID'].str.split('|',expand=True)

with open(reverse_mapping_file, 'rb') as f:
    reverse_mapping = pickle.load( f)
    
descriptive_columns = ['Z_MARCA', 'Z_GAMA', 'Z_MODELO',
                       'Z_DEPARTAMENTO', 'Z_PUNTO_VENTA']
i=0
for column in descriptive_columns:
    if column in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA','Z_WEEK']:
        inv_reverse_mapping = {v: k for k, v in reverse_mapping[i].items()}

        result[column] = result[column].map(inv_reverse_mapping)
    i+=1
    
result = result.rename(columns = {TARGET: TARGET+'_real'})

# %%
result.head(1)
# Out:
#                                                   ID  Demanda_real Z_MODELO  \
# 0  009e0874cc07b2180b2b2b1039321041a1f42e66693c49...      0.010752  MOD_170
#
#   Z_PUNTO_VENTA Z_GAMA     Z_WEEK
# 0     PVENT_259  GAM_2  SEMANA_51

# %%
print('Reading dataset')
SHIFT=1
df_train  = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_train_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))
df_test   = pd.read_pickle(os.path.join(PATH_RESULTS,'dataset','df_test_fe_FILL_'+str(FILL)+'_SHIFT_'+str(SHIFT)+'.pkl'))

gc.collect()
print('df_train size :',df_train.shape)
print('df_test size  :',df_test.shape)
# Out:
# Reading dataset
# df_train size : (2358650, 1111)
# df_test size  : (471730, 1111)

# %%
features_names = set(df_train.columns)-set([TARGET,'date_block_num',TARGET+'_clipped','release','item_id',
                                            'Z_WEEK_DATE', 'Z_WEEK','date_block_num','year',
                                            'month', 'is_month_end', 'tm_m_end','is_month_start','tm_wm', 'tm_w_end','is_quarter_start','is_year_start',
                                             'day_of_week',
                                            'day_of_year', 'day',
                                            #'Z_MODELO','Z_PUNTO_VENTA','Z_DEPARTAMENTO',
                                            #'Z_GAMA','Z_MARCA', 
                                           ]) 
print(len(features_names))
features_names = list(features_names)
# Out:
# 1093

# %% [raw]
# print(len(features_names))
# features_names = [e for e in features_names if not any(prefix in e for prefix in ['enc_'])]
# print(len(features_names))

# %%
for columns in features_names:
    if columns in ['Z_MODELO','Z_PUNTO_VENTA','Z_GAMA']:
        print(columns)
# Out:
# Z_PUNTO_VENTA
# Z_MODELO
# Z_GAMA

# %%
df_train['week_of_month'] = df_train['week_of_month'].astype('category')
df_test['week_of_month']  = df_test['week_of_month'].astype('category')

# %%
total_features_names = features_names.copy()

# %%
def get_feature_names_shift(shift,total_features_names):
    features_names = []

    for column in total_features_names:
        if 'shift' in column:
            number = column.split('shift_')[1]
            number = int(number.split('_')[0])
            if (number>=shift and number<=(shift+2))or(number>=(shift+6) and number<=(shift+8)):
                features_names.append(column)
        else:
            features_names.append(column)
    return features_names

# %%
TRAIN_START = '2021-08-01'
TEST_START = '2022-03-01'
TEST_END   = '2022-05-01'
print(df_train.shape)
df_train = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)]
print(df_train.shape)
# Out:
# (2358650, 1111)
# (1839747, 1111)

# %%
PATH_RESULTS = '../../results/Demanda_ventana_custom/'
training.PATH_RESULTS = PATH_RESULTS
training.submission_analysis.TARGET  = TARGET


for SHIFT in range(1,11):
    print('*'*20)
    print('*'*20)
    print('WEEK = ',SHIFT)
    print('*'*20)
    print('*'*20)

    features_names = get_feature_names_shift(SHIFT,total_features_names)
    print('len base features = ',len(features_names))
    print('example base features =',features_names[:5])
    
    ################### CV MODEL RANDOM SPLIT ###############

    gc.collect()
    
    for idx,model_type in enumerate(['xgboost']):

    
        X_train      = df_train[((df_train['Z_WEEK_DATE'] >= TRAIN_START) &(df_train['Z_WEEK_DATE'] < TEST_START))&
                               (df_train['Z_WEEK_DATE'] != '2022-04-11')].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT model_type = ',model_type,'c_model_v2')
        print('*'*20)

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]
        X_train = X_train[features_names]
        X_test  = X_test[features_names]
        X_submission = df_test[features_names]        
        


        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        model_version = 'c_model_v2'
        training.TARGET = TARGET
        training.SHIFT = SHIFT

        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                            X_test,y_test,X_submission,df_test,result,N_FOLDS)

    
        gc.collect()
        
        #'''
        if idx ==0 :
            features_names = list(df_feature_importance['feature'][:30].values)
            
        ################### CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE ###############
        important_features = list(df_feature_importance[:N_FEATURE_IMPORTANCE]['feature'])
        
        X_train      = df_train[(df_train['Z_WEEK_DATE'] >= TRAIN_START)&(df_train['Z_WEEK_DATE'] < TEST_START)].copy() 
        X_test       = df_train[(df_train['Z_WEEK_DATE'] >= TEST_START) & (df_train['Z_WEEK_DATE'] < TEST_END)].copy() 

        y_train = X_train[TARGET]
        y_test =  X_test[TARGET]
        y_submission = df_test[TARGET]

        X_train = X_train[important_features]
        X_test  = X_test[important_features]
        X_submission = df_test[important_features]

        print('X_train total cv',X_train.shape)
        print('X_test          ',X_test.shape)
        print('X_submission    ',X_submission.shape)

        print('*'*20)
        print('MODEL = ',model_type)
        print('CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type = ',model_type,'c_model_v3')
        print('*'*20)
        
        model_version = 'c_model_v3'
        training.TARGET = TARGET
        training.SHIFT = SHIFT


        df_submission,df_feature_importance = training.training_model_cv(model_type,model_version,X_train,y_train,
                                                               X_test,y_test,X_submission,df_test,result,N_FOLDS)
        #'''
        gc.collect()
# Out:
# ********************
# ********************
# WEEK =  1
# ********************
# ********************
# len base features =  444
# example base features = ['shift_3_roll_2_mean_Z_MODELO', 'shift_2_roll_2_std_Z_GAMA_Z_MARCA', 'shift_2_roll_2_std_Z_MODELO_Z_PUNTO_VENTA', 'shift_8_roll_2_mean_Z_MODELO_Z_MARCA', 'shift_1_roll_2_std_Z_GAMA']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 444)
# X_test           (377384, 444)
# X_submission     (471730, 444)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1
# [17:42:29] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01533	validation_1-rmse:5.93895
# [20]	validation_0-rmse:5.67463	validation_1-rmse:5.60583
# [40]	validation_0-rmse:4.80061	validation_1-rmse:4.79564
# [60]	validation_0-rmse:3.93479	validation_1-rmse:4.04112
# [80]	validation_0-rmse:3.27241	validation_1-rmse:3.50122
# [100]	validation_0-rmse:2.79883	validation_1-rmse:3.14240
# [120]	validation_0-rmse:2.47330	validation_1-rmse:2.91770
# [140]	validation_0-rmse:2.25941	validation_1-rmse:2.78541
# [160]	validation_0-rmse:2.12613	validation_1-rmse:2.70596
# [180]	validation_0-rmse:2.04493	validation_1-rmse:2.66158
# [200]	validation_0-rmse:1.99007	validation_1-rmse:2.63359
# [220]	validation_0-rmse:1.95462	validation_1-rmse:2.61605
# [240]	validation_0-rmse:1.93056	validation_1-rmse:2.60563
# [260]	validation_0-rmse:1.91288	validation_1-rmse:2.59876
# [280]	validation_0-rmse:1.89988	validation_1-rmse:2.59310
# [300]	validation_0-rmse:1.89028	validation_1-rmse:2.58964
# [320]	validation_0-rmse:1.88386	validation_1-rmse:2.58789
# [340]	validation_0-rmse:1.87640	validation_1-rmse:2.58592
# [360]	validation_0-rmse:1.86848	validation_1-rmse:2.58429
# [380]	validation_0-rmse:1.86111	validation_1-rmse:2.58155
# [400]	validation_0-rmse:1.85344	validation_1-rmse:2.57805
# [420]	validation_0-rmse:1.83864	validation_1-rmse:2.57322
# [440]	validation_0-rmse:1.82686	validation_1-rmse:2.56900
# [460]	validation_0-rmse:1.81090	validation_1-rmse:2.56534
# [480]	validation_0-rmse:1.80233	validation_1-rmse:2.56494
# [500]	validation_0-rmse:1.78643	validation_1-rmse:2.56047
# [520]	validation_0-rmse:1.77898	validation_1-rmse:2.55969
# [540]	validation_0-rmse:1.77049	validation_1-rmse:2.55801
# [560]	validation_0-rmse:1.76338	validation_1-rmse:2.55668
# [580]	validation_0-rmse:1.75546	validation_1-rmse:2.55694
# [600]	validation_0-rmse:1.73519	validation_1-rmse:2.55448
# [620]	validation_0-rmse:1.72139	validation_1-rmse:2.55232
# [640]	validation_0-rmse:1.71176	validation_1-rmse:2.55037
# [660]	validation_0-rmse:1.69965	validation_1-rmse:2.54797
# [680]	validation_0-rmse:1.68508	validation_1-rmse:2.54671
# [700]	validation_0-rmse:1.67131	validation_1-rmse:2.54894
# [713]	validation_0-rmse:1.66702	validation_1-rmse:2.54778
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.5461713892192854
# Score test : 2.5023898459670684
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5462_test_2.5024_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5462_test_2.5024_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5462_test_2.5024_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_1/rmse_val_2.5462_test_2.5024_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9547479678836839
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8446859201151962
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0589349411818567
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_1
# [17:48:44] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10006	validation_1-rmse:5.76349
# [20]	validation_0-rmse:5.75692	validation_1-rmse:5.43228
# [40]	validation_0-rmse:4.86760	validation_1-rmse:4.66083
# [60]	validation_0-rmse:3.98470	validation_1-rmse:3.95361
# [80]	validation_0-rmse:3.30146	validation_1-rmse:3.44297
# [100]	validation_0-rmse:2.81703	validation_1-rmse:3.10637
# [120]	validation_0-rmse:2.48490	validation_1-rmse:2.89313
# [140]	validation_0-rmse:2.26315	validation_1-rmse:2.76016
# [160]	validation_0-rmse:2.12395	validation_1-rmse:2.68168
# [180]	validation_0-rmse:2.03182	validation_1-rmse:2.63135
# [200]	validation_0-rmse:1.97325	validation_1-rmse:2.60245
# [220]	validation_0-rmse:1.93299	validation_1-rmse:2.58179
# [220]	validation_0-rmse:2.25424	validation_1-rmse:2.72829
# [240]	validation_0-rmse:2.23828	validation_1-rmse:2.72105
# [260]	validation_0-rmse:2.22697	validation_1-rmse:2.71564
# [280]	validation_0-rmse:2.21959	validation_1-rmse:2.71345
# [300]	validation_0-rmse:2.21373	validation_1-rmse:2.71132
# [320]	validation_0-rmse:2.20930	validation_1-rmse:2.70775
# [340]	validation_0-rmse:2.20544	validation_1-rmse:2.70551
# [360]	validation_0-rmse:2.20086	validation_1-rmse:2.70463
# [380]	validation_0-rmse:2.19585	validation_1-rmse:2.70559
# [400]	validation_0-rmse:2.18992	validation_1-rmse:2.70942
# [412]	validation_0-rmse:2.18541	validation_1-rmse:2.71517
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.704154104257326
# Score test : 2.1908147295768585
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7042_test_2.1908_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7042_test_2.1908_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7042_test_2.1908_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_1/rmse_val_2.7042_test_2.1908_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.020114027646858
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8521947020417735
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1751083088250116
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1
# [18:02:51] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10006	validation_1-rmse:5.76349
# [20]	validation_0-rmse:5.75763	validation_1-rmse:5.43277
# [40]	validation_0-rmse:4.87946	validation_1-rmse:4.66108
# [60]	validation_0-rmse:4.02387	validation_1-rmse:3.95546
# [80]	validation_0-rmse:3.37683	validation_1-rmse:3.45228
# [100]	validation_0-rmse:2.92973	validation_1-rmse:3.12691
# [120]	validation_0-rmse:2.63442	validation_1-rmse:2.92902
# [140]	validation_0-rmse:2.44346	validation_1-rmse:2.81443
# [160]	validation_0-rmse:2.32312	validation_1-rmse:2.74823
# [180]	validation_0-rmse:2.25159	validation_1-rmse:2.71073
# [200]	validation_0-rmse:2.20830	validation_1-rmse:2.68967
# [220]	validation_0-rmse:2.17885	validation_1-rmse:2.67666
# [240]	validation_0-rmse:2.15986	validation_1-rmse:2.66851
# [260]	validation_0-rmse:2.14757	validation_1-rmse:2.66364
# [280]	validation_0-rmse:2.13827	validation_1-rmse:2.66064
# [300]	validation_0-rmse:2.13072	validation_1-rmse:2.65776
# [320]	validation_0-rmse:2.12494	validation_1-rmse:2.65548
# [340]	validation_0-rmse:2.11911	validation_1-rmse:2.65303
# [360]	validation_0-rmse:2.11522	validation_1-rmse:2.65234
# [380]	validation_0-rmse:2.11151	validation_1-rmse:2.65157
# [400]	validation_0-rmse:2.10822	validation_1-rmse:2.65062
# [420]	validation_0-rmse:2.10475	validation_1-rmse:2.65028
# [440]	validation_0-rmse:2.10106	validation_1-rmse:2.64862
# [460]	validation_0-rmse:2.09812	validation_1-rmse:2.64828
# [480]	validation_0-rmse:2.09231	validation_1-rmse:2.64683
# [500]	validation_0-rmse:2.08561	validation_1-rmse:2.64459
# [520]	validation_0-rmse:2.07855	validation_1-rmse:2.64395
# [540]	validation_0-rmse:2.07208	validation_1-rmse:2.64393
# [560]	validation_0-rmse:2.06635	validation_1-rmse:2.64353
# [580]	validation_0-rmse:2.06232	validation_1-rmse:2.64321
# [591]	validation_0-rmse:2.06013	validation_1-rmse:2.64356
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.6428668825916963
# Score test : 2.206028034238118
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6429_test_2.206_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6429_test_2.206_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6429_test_2.206_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_1/rmse_val_2.6429_test_2.206_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0146864491505294
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8434462603180115
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1724706815285386
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1
# [18:03:37] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85187	validation_1-rmse:6.25704
# [20]	validation_0-rmse:5.51651	validation_1-rmse:5.91930
# [40]	validation_0-rmse:4.68958	validation_1-rmse:5.07109
# [60]	validation_0-rmse:3.89157	validation_1-rmse:4.26511
# [80]	validation_0-rmse:3.29365	validation_1-rmse:3.66932
# [100]	validation_0-rmse:2.88417	validation_1-rmse:3.26966
# [120]	validation_0-rmse:2.61589	validation_1-rmse:3.00950
# [140]	validation_0-rmse:2.44496	validation_1-rmse:2.84610
# [160]	validation_0-rmse:2.33741	validation_1-rmse:2.74586
# [180]	validation_0-rmse:2.27235	validation_1-rmse:2.68321
# [200]	validation_0-rmse:2.23220	validation_1-rmse:2.64396
# [220]	validation_0-rmse:2.20593	validation_1-rmse:2.61916
# [240]	validation_0-rmse:2.18956	validation_1-rmse:2.60391
# [260]	validation_0-rmse:2.17816	validation_1-rmse:2.59192
# [280]	validation_0-rmse:2.16993	validation_1-rmse:2.58524
# [300]	validation_0-rmse:2.16361	validation_1-rmse:2.57864
# [320]	validation_0-rmse:2.15767	validation_1-rmse:2.57302
# [340]	validation_0-rmse:2.15318	validation_1-rmse:2.56879
# [360]	validation_0-rmse:2.15029	validation_1-rmse:2.56611
# [380]	validation_0-rmse:2.14746	validation_1-rmse:2.56378
# [400]	validation_0-rmse:2.14306	validation_1-rmse:2.56158
# [420]	validation_0-rmse:2.13922	validation_1-rmse:2.55976
# [440]	validation_0-rmse:2.13578	validation_1-rmse:2.55732
# [460]	validation_0-rmse:2.13212	validation_1-rmse:2.55567
# [480]	validation_0-rmse:2.12403	validation_1-rmse:2.55073
# [500]	validation_0-rmse:2.11907	validation_1-rmse:2.54963
# [520]	validation_0-rmse:2.11139	validation_1-rmse:2.54582
# [540]	validation_0-rmse:2.10340	validation_1-rmse:2.54306
# [560]	validation_0-rmse:2.09627	validation_1-rmse:2.54059
# [580]	validation_0-rmse:2.08705	validation_1-rmse:2.53930
# [600]	validation_0-rmse:2.08079	validation_1-rmse:2.53775
# [620]	validation_0-rmse:2.07373	validation_1-rmse:2.53541
# [640]	validation_0-rmse:2.06537	validation_1-rmse:2.53051
# [660]	validation_0-rmse:2.05989	validation_1-rmse:2.52773
# [680]	validation_0-rmse:2.05367	validation_1-rmse:2.52477
# [700]	validation_0-rmse:2.04624	validation_1-rmse:2.52197
# [720]	validation_0-rmse:2.04199	validation_1-rmse:2.51935
# [740]	validation_0-rmse:2.03140	validation_1-rmse:2.52100
# [760]	validation_0-rmse:2.02192	validation_1-rmse:2.52079
# [769]	validation_0-rmse:2.01943	validation_1-rmse:2.52048
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.519066760066325
# Score test : 2.3277690697219042
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.5191_test_2.3278_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.5191_test_2.3278_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.5191_test_2.3278_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_1/rmse_val_2.5191_test_2.3278_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0427334720642603
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9033103602474284
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1732302566360104
# Saving analysis by week ..
# Predict submission
# CV score: 2.62316
# cv_train_rmse :  2.62315922794912
# cv_test_rmse  :  2.208824126830935
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1/rmse_cv_train_2.6232_rmse_cv_test_2.2088_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1/rmse_cv_train_2.6232_rmse_cv_test_2.2088_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_1/rmse_cv_train_2.6232_rmse_cv_test_2.2088_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0223915195606397
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.860050390706139
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1726360626703047
# Saving analysis by week ..
# ********************
# ********************
# WEEK =  2
# ********************
# ********************
# len base features =  444
# example base features = ['shift_3_roll_2_mean_Z_MODELO', 'shift_2_roll_2_std_Z_GAMA_Z_MARCA', 'shift_2_roll_2_std_Z_MODELO_Z_PUNTO_VENTA', 'shift_8_roll_2_mean_Z_MODELO_Z_MARCA', 'shift_4_roll_2_std_Z_MARCA_Z_DEPARTAMENTO']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 444)
# X_test           (377384, 444)
# X_submission     (471730, 444)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_2
# [18:05:20] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01545	validation_1-rmse:5.93908
# [20]	validation_0-rmse:5.69312	validation_1-rmse:5.62572
# [40]	validation_0-rmse:4.88754	validation_1-rmse:4.88234
# [60]	validation_0-rmse:4.10303	validation_1-rmse:4.20753
# [80]	validation_0-rmse:3.50219	validation_1-rmse:3.72148
# [100]	validation_0-rmse:3.07405	validation_1-rmse:3.40051
# [120]	validation_0-rmse:2.78711	validation_1-rmse:3.20085
# [140]	validation_0-rmse:2.60197	validation_1-rmse:3.07818
# [160]	validation_0-rmse:2.48219	validation_1-rmse:3.00485
# [180]	validation_0-rmse:2.40153	validation_1-rmse:2.95918
# [200]	validation_0-rmse:2.34672	validation_1-rmse:2.93161
# [220]	validation_0-rmse:2.30763	validation_1-rmse:2.91429
# [240]	validation_0-rmse:2.27788	validation_1-rmse:2.90057
# [260]	validation_0-rmse:2.25870	validation_1-rmse:2.89272
# [280]	validation_0-rmse:2.24567	validation_1-rmse:2.88920
# [300]	validation_0-rmse:2.23467	validation_1-rmse:2.88606
# [320]	validation_0-rmse:2.22007	validation_1-rmse:2.88268
# [340]	validation_0-rmse:2.20755	validation_1-rmse:2.87992
# [360]	validation_0-rmse:2.19412	validation_1-rmse:2.87697
# [380]	validation_0-rmse:2.18093	validation_1-rmse:2.87537
# [400]	validation_0-rmse:2.16078	validation_1-rmse:2.87163
# [420]	validation_0-rmse:2.14579	validation_1-rmse:2.86802
# [440]	validation_0-rmse:2.12708	validation_1-rmse:2.86352
# [460]	validation_0-rmse:2.10418	validation_1-rmse:2.85795
# [480]	validation_0-rmse:2.08761	validation_1-rmse:2.85334
# [500]	validation_0-rmse:2.07630	validation_1-rmse:2.85167
# [520]	validation_0-rmse:2.06020	validation_1-rmse:2.85065
# [540]	validation_0-rmse:2.04863	validation_1-rmse:2.84912
# [560]	validation_0-rmse:2.03283	validation_1-rmse:2.84539
# [580]	validation_0-rmse:2.01467	validation_1-rmse:2.84389
# [600]	validation_0-rmse:2.00352	validation_1-rmse:2.84229
WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10018	validation_1-rmse:5.76363
# [20]	validation_0-rmse:5.77549	validation_1-rmse:5.45455
# [40]	validation_0-rmse:4.95033	validation_1-rmse:4.76230
# [60]	validation_0-rmse:4.13905	validation_1-rmse:4.12465
# [80]	validation_0-rmse:3.51737	validation_1-rmse:3.66319
# [100]	validation_0-rmse:3.08218	validation_1-rmse:3.35660
# [120]	validation_0-rmse:2.78759	validation_1-rmse:3.16200
# [140]	validation_0-rmse:2.59812	validation_1-rmse:3.04259
# [160]	validation_0-rmse:2.46502	validation_1-rmse:2.96703
# [180]	validation_0-rmse:2.37090	validation_1-rmse:2.91900
# [200]	validation_0-rmse:2.30893	validation_1-rmse:2.88455
# [220]	validation_0-rmse:2.27162	validation_1-rmse:2.86433
# [240]	validation_0-rmse:2.24460	validation_1-rmse:2.84961
# [260]	validation_0-rmse:2.22546	validation_1-rmse:2.83824
# [280]	validation_0-rmse:2.20967	validation_1-rmse:2.82977
# [300]	validation_0-rmse:2.19549	validation_1-rmse:2.82340
# [320]	validation_0-rmse:2.18530	validation_1-rmse:2.81800
# [340]	validation_0-rmse:2.17198	validation_1-rmse:2.81310
# [360]	validation_0-rmse:2.15698	validation_1-rmse:2.80999
# [380]	validation_0-rmse:2.14122	validation_1-rmse:2.80623
# [400]	validation_0-rmse:2.11875	validation_1-rmse:2.80710
# [420]	validation_0-rmse:2.09893	validation_1-rmse:2.80853
# [435]	validation_0-rmse:2.08303	validation_1-rmse:2.80918
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.8052030049699836
# Score test : 2.4567525790349065
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.8052_test_2.4568_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.8052_test_2.4568_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.8052_test_2.4568_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_2/rmse_val_2.8052_test_2.4568_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8003699976400185
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.4983139338880507
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0585722266467976
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2
# [18:20:22] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85200	validation_1-rmse:6.25717
# [20]	validation_0-rmse:5.53409	validation_1-rmse:5.94085
# [40]	validation_0-rmse:4.75198	validation_1-rmse:5.18408
# [60]	validation_0-rmse:3.99057	validation_1-rmse:4.48777
# [80]	validation_0-rmse:3.40505	validation_1-rmse:3.98113
# [100]	validation_0-rmse:3.00277	validation_1-rmse:3.64105
# [120]	validation_0-rmse:2.72633	validation_1-rmse:3.42025
# [140]	validation_0-rmse:2.55359	validation_1-rmse:3.28345
# [160]	validation_0-rmse:2.43751	validation_1-rmse:3.19227
# [180]	validation_0-rmse:2.36056	validation_1-rmse:3.13458
# [200]	validation_0-rmse:2.30951	validation_1-rmse:3.09488
# [220]	validation_0-rmse:2.27068	validation_1-rmse:3.06526
# [240]	validation_0-rmse:2.24404	validation_1-rmse:3.04461
# [260]	validation_0-rmse:2.22368	validation_1-rmse:3.02701
# [280]	validation_0-rmse:2.21095	validation_1-rmse:3.01656
# [300]	validation_0-rmse:2.20135	validation_1-rmse:3.00887
# [320]	validation_0-rmse:2.19247	validation_1-rmse:3.00302
# [340]	validation_0-rmse:2.18499	validation_1-rmse:2.99730
# [360]	validation_0-rmse:2.17548	validation_1-rmse:2.99030
# [380]	validation_0-rmse:2.16568	validation_1-rmse:2.98158
# [400]	validation_0-rmse:2.14222	validation_1-rmse:2.96996
# [420]	validation_0-rmse:2.12648	validation_1-rmse:2.96222
# [440]	validation_0-rmse:2.11571	validation_1-rmse:2.95909
# [460]	validation_0-rmse:2.10485	validation_1-rmse:2.95674
# [480]	validation_0-rmse:2.09550	validation_1-rmse:2.95282
# [500]	validation_0-rmse:2.08276	validation_1-rmse:2.95084
# [520]	validation_0-rmse:2.06825	validation_1-rmse:2.95084
# [540]	validation_0-rmse:2.05338	validation_1-rmse:2.95113
# [550]	validation_0-rmse:2.04829	validation_1-rmse:2.95027
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.948922650110847
# Score test : 2.53123625706322
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2/rmse_val_2.9489_test_2.5312_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2/rmse_val_2.9489_test_2.5312_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2/rmse_val_2.9489_test_2.5312_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_2/rmse_val_2.9489_test_2.5312_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.814715558000616
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.6352337441147233
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.97797768314193
# Saving analysis by week ..
# Predict submission
# CV score: 2.84818
# cv_train_rmse :  2.848183763862868
# cv_test_rmse  :  2.4645728019684103
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_2
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_2/rmse_cv_train_2.8482_rmse_cv_test_2.4646_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_2/rmse_cv_train_2.8482_rmse_cv_test_2.4646_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/shift_2/rmse_cv_train_2.8482_rmse_cv_test_2.4646_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8011723970281512
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.5760101237817357
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.001158688702561
# Saving analysis by week ..
# X_train total cv (1462363, 15)
# X_test           (377384, 15)
# X_submission     (471730, 15)
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT + FEATURE IMPORTANCE model_type =  xgboost c_model_v3
# ********************
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2
# [18:25:40] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01546	validation_1-rmse:5.93908
# [20]	validation_0-rmse:5.69553	validation_1-rmse:5.62367
# [40]	validation_0-rmse:4.91516	validation_1-rmse:4.87276
# [60]	validation_0-rmse:4.17227	validation_1-rmse:4.18775
# [80]	validation_0-rmse:3.62261	validation_1-rmse:3.71065
# [100]	validation_0-rmse:3.24802	validation_1-rmse:3.40540
# [120]	validation_0-rmse:3.00284	validation_1-rmse:3.21812
# [140]	validation_0-rmse:2.84943	validation_1-rmse:3.11319
# [160]	validation_0-rmse:2.75136	validation_1-rmse:3.05496
# [180]	validation_0-rmse:2.68896	validation_1-rmse:3.02461
# [200]	validation_0-rmse:2.64803	validation_1-rmse:3.00791
# [220]	validation_0-rmse:2.62070	validation_1-rmse:2.99695
# [240]	validation_0-rmse:2.59680	validation_1-rmse:2.99273
# [260]	validation_0-rmse:2.57764	validation_1-rmse:2.99344
# [280]	validation_0-rmse:2.56842	validation_1-rmse:2.99225
# [300]	validation_0-rmse:2.56055	validation_1-rmse:2.99112
# [320]	validation_0-rmse:2.55206	validation_1-rmse:2.99074
# [340]	validation_0-rmse:2.54429	validation_1-rmse:2.99062
# [360]	validation_0-rmse:2.53330	validation_1-rmse:2.98872
# [380]	validation_0-rmse:2.52635	validation_1-rmse:2.98882
# [400]	validation_0-rmse:2.51968	validation_1-rmse:2.98819
# [420]	validation_0-rmse:2.51182	validation_1-rmse:2.98744
# [440]	validation_0-rmse:2.50024	validation_1-rmse:2.98541
# [460]	validation_0-rmse:2.48127	validation_1-rmse:2.98403
# [480]	validation_0-rmse:2.46610	validation_1-rmse:2.98145
# [500]	validation_0-rmse:2.45302	validation_1-rmse:2.98068
# [520]	validation_0-rmse:2.44525	validation_1-rmse:2.98066
# [540]	validation_0-rmse:2.43419	validation_1-rmse:2.97917
# [560]	validation_0-rmse:2.42217	validation_1-rmse:2.97923
# [580]	validation_0-rmse:2.41391	validation_1-rmse:2.97905
# [583]	validation_0-rmse:2.41337	validation_1-rmse:2.97885
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.9784596351939387
# Score test : 2.7108769200716663
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2/rmse_val_2.9785_test_2.7109_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2/rmse_val_2.9785_test_2.7109_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2/rmse_val_2.9785_test_2.7109_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_1/shift_2/rmse_val_2.9785_test_2.7109_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8242222355070985
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.4209656008654377
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1532371653383096
# Saving analysis by week ..
# Predict submission
# ********************  fold n°1
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_2
# [18:26:25] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.10019	validation_1-rmse:5.76363
# [20]	validation_0-rmse:5.77798	validation_1-rmse:5.45500
# [40]	validation_0-rmse:4.98148	validation_1-rmse:4.76673
# [60]	validation_0-rmse:4.22136	validation_1-rmse:4.14244
# [80]	validation_0-rmse:3.66051	validation_1-rmse:3.70053
# [100]	validation_0-rmse:3.27889	validation_1-rmse:3.41026
# [120]	validation_0-rmse:3.02878	validation_1-rmse:3.22747
# [140]	validation_0-rmse:2.86841	validation_1-rmse:3.11502
# [160]	validation_0-rmse:2.77024	validation_1-rmse:3.04699
# [180]	validation_0-rmse:2.70971	validation_1-rmse:3.00693
# [200]	validation_0-rmse:2.66818	validation_1-rmse:2.98250
# [220]	validation_0-rmse:2.63580	validation_1-rmse:2.96690
# [240]	validation_0-rmse:2.60701	validation_1-rmse:2.95558
# [260]	validation_0-rmse:2.59129	validation_1-rmse:2.94806
# [280]	validation_0-rmse:2.58207	validation_1-rmse:2.94286
# [300]	validation_0-rmse:2.57439	validation_1-rmse:2.93818
# [320]	validation_0-rmse:2.56902	validation_1-rmse:2.93505
# [340]	validation_0-rmse:2.56282	validation_1-rmse:2.93177
# [360]	validation_0-rmse:2.55700	validation_1-rmse:2.92926
# [380]	validation_0-rmse:2.55134	validation_1-rmse:2.92671
# [400]	validation_0-rmse:2.54678	validation_1-rmse:2.92447
# [420]	validation_0-rmse:2.54210	validation_1-rmse:2.92242
# [440]	validation_0-rmse:2.53206	validation_1-rmse:2.92118
# [460]	validation_0-rmse:2.51982	validation_1-rmse:2.92120
# [480]	validation_0-rmse:2.50752	validation_1-rmse:2.92284
# [498]	validation_0-rmse:2.50128	validation_1-rmse:2.92346
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.9202796339260817
# Score test : 2.648650698346604
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_2/rmse_val_2.9203_test_2.6487_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_2/rmse_val_2.9203_test_2.6487_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_2/rmse_val_2.9203_test_2.6487_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_2/shift_2/rmse_val_2.9203_test_2.6487_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8067064998088558
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.3915602015013648
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.1428805282844445
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_2
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_2
# [18:27:06] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85201	validation_1-rmse:6.25717
# [20]	validation_0-rmse:5.53595	validation_1-rmse:5.94057
# ...
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_4/rmse_val_3.5177_test_3.1556_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/fold_3/shift_4/rmse_val_3.5177_test_3.1556_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.9062513222573627
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.7756306498418322
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.028478247987432
# Saving analysis by week ..
# Predict submission
# CV score: 3.34623
# cv_train_rmse :  3.3462281916108103
# cv_test_rmse  :  3.237537082887293
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_4
# (471730, 1111)
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_4/rmse_cv_train_3.3462_rmse_cv_test_3.2375_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_4/rmse_cv_train_3.3462_rmse_cv_test_3.2375_prediction_test.png
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v3/shift_4/rmse_cv_train_3.3462_rmse_cv_test_3.2375_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.8343249635164882
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 1.6362460785427781
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.013006436654615
# Saving analysis by week ..
# ********************
# ********************
# WEEK =  5
# ********************
# ********************
# len base features =  444
# example base features = ['shift_6_roll_4_std_Z_MODELO_Z_GAMA', 'shift_6_roll_2_mean_Z_GAMA', 'shift_12_roll_4_mean_Z_PUNTO_VENTA_Z_DEPARTAMENTO', 'shift_5_roll_2_mean_item_id', 'shift_6_roll_2_mean_Z_MODELO_Z_GAMA']
# ********************
# MODEL =  xgboost
# CV MODEL RANDOM SPLIT model_type =  xgboost c_model_v2
# ********************
# X_train total cv (1462363, 444)
# X_test           (377384, 444)
# X_submission     (471730, 444)
# KFold(n_splits=3, random_state=100, shuffle=True)
# ********************  fold n°0
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_5
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_1/shift_5
# [19:18:02] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.01565	validation_1-rmse:5.93929
# [20]	validation_0-rmse:5.71827	validation_1-rmse:5.65573
# [40]	validation_0-rmse:4.99520	validation_1-rmse:5.00634
# [60]	validation_0-rmse:4.29702	validation_1-rmse:4.41917
# [80]	validation_0-rmse:3.76963	validation_1-rmse:4.00358
# [100]	validation_0-rmse:3.40196	validation_1-rmse:3.73450
# [120]	validation_0-rmse:3.16561	validation_1-rmse:3.56900
# [140]	validation_0-rmse:2.99900	validation_1-rmse:3.46214
# [160]	validation_0-rmse:2.89205	validation_1-rmse:3.39290
# [180]	validation_0-rmse:2.82195	validation_1-rmse:3.34782
# [200]	validation_0-rmse:2.77177	validation_1-rmse:3.31807
# [220]	validation_0-rmse:2.72467	validation_1-rmse:3.29743
# [240]	validation_0-rmse:2.69012	validation_1-rmse:3.28119
# [260]	validation_0-rmse:2.66104	validation_1-rmse:3.26968
# [280]	validation_0-rmse:2.64272	validation_1-rmse:3.26103
# [300]	validation_0-rmse:2.62357	validation_1-rmse:3.25169
# [320]	validation_0-rmse:2.60584	validation_1-rmse:3.24611
# [340]	validation_0-rmse:2.59057	validation_1-rmse:3.24156
# [360]	validation_0-rmse:2.57168	validation_1-rmse:3.23667
# [380]	validation_0-rmse:2.53121	validation_1-rmse:3.22611
# [400]	validation_0-rmse:2.49306	validation_1-rmse:3.21985
# [420]	validation_0-rmse:2.46398	validation_1-rmse:3.21348
# [440]	validation_0-rmse:2.44252	validation_1-rmse:3.20945
# [460]	validation_0-rmse:2.41976	validation_1-rmse:3.20620
# [480]	validation_0-rmse:2.39838	validation_1-rmse:3.20176
# [500]	validation_0-rmse:2.37754	validation_1-rmse:3.19554
# [520]	validation_0-rmse:2.34535	validation_1-rmse:3.19259
# [540]	validation_0-rmse:2.33169	validation_1-rmse:3.19141
# [560]	validation_0-rmse:2.31773	validation_1-rmse:3.18775
# [580]	validation_0-rmse:2.29275	validation_1-rmse:3.17855
# [600]	validation_0-rmse:2.27011	validation_1-rmse:3.17356
# [620]	validation_0-rmse:2.24943	validation_1-rmse:3.17160
# [640]	validation_0-rmse:2.22798	validation_1-rmse:3.17161
# [660]	validation_0-rmse:2.20573	validation_1-rmse:3.16829
# [680]	validation_0-rmse:2.19491	validation_1-rmse:3.16568
# [700]	validation_0-rmse:2.18092	validation_1-rmse:3.16436
# [720]	validation_0-rmse:2.16753	validation_1-rmse:3.16318
# [160]	validation_0-rmse:2.88289	validation_1-rmse:3.28137
# [180]	validation_0-rmse:2.80051	validation_1-rmse:3.22711
# [200]	validation_0-rmse:2.74185	validation_1-rmse:3.19030
# [220]	validation_0-rmse:2.69886	validation_1-rmse:3.16373
# [240]	validation_0-rmse:2.65524	validation_1-rmse:3.14326
# [260]	validation_0-rmse:2.61980	validation_1-rmse:3.12874
# [280]	validation_0-rmse:2.59158	validation_1-rmse:3.11272
# [300]	validation_0-rmse:2.56058	validation_1-rmse:3.10090
# [320]	validation_0-rmse:2.53298	validation_1-rmse:3.09090
# [340]	validation_0-rmse:2.50856	validation_1-rmse:3.08383
# [360]	validation_0-rmse:2.48462	validation_1-rmse:3.07512
# [380]	validation_0-rmse:2.44720	validation_1-rmse:3.06889
# [400]	validation_0-rmse:2.42412	validation_1-rmse:3.06353
# [420]	validation_0-rmse:2.39757	validation_1-rmse:3.05921
# [440]	validation_0-rmse:2.37241	validation_1-rmse:3.05965
# [460]	validation_0-rmse:2.35273	validation_1-rmse:3.05633
# [480]	validation_0-rmse:2.33385	validation_1-rmse:3.05391
# [500]	validation_0-rmse:2.31270	validation_1-rmse:3.04753
# [520]	validation_0-rmse:2.29300	validation_1-rmse:3.04275
# [540]	validation_0-rmse:2.27523	validation_1-rmse:3.03796
# [560]	validation_0-rmse:2.25473	validation_1-rmse:3.03007
# [580]	validation_0-rmse:2.23430	validation_1-rmse:3.02017
# [600]	validation_0-rmse:2.21511	validation_1-rmse:3.01058
# [620]	validation_0-rmse:2.20319	validation_1-rmse:3.00325
# [640]	validation_0-rmse:2.18689	validation_1-rmse:2.99435
# [660]	validation_0-rmse:2.17257	validation_1-rmse:2.99113
# [680]	validation_0-rmse:2.15880	validation_1-rmse:2.98898
# [700]	validation_0-rmse:2.14874	validation_1-rmse:2.98688
# [720]	validation_0-rmse:2.12860	validation_1-rmse:2.98505
# [740]	validation_0-rmse:2.11228	validation_1-rmse:2.98429
# [760]	validation_0-rmse:2.09650	validation_1-rmse:2.98253
# [780]	validation_0-rmse:2.08491	validation_1-rmse:2.97984
# [800]	validation_0-rmse:2.07268	validation_1-rmse:2.97808
# [820]	validation_0-rmse:2.06269	validation_1-rmse:2.97433
# [840]	validation_0-rmse:2.05311	validation_1-rmse:2.97110
# [860]	validation_0-rmse:2.03967	validation_1-rmse:2.96744
# [880]	validation_0-rmse:2.03070	validation_1-rmse:2.96722
# [900]	validation_0-rmse:2.02058	validation_1-rmse:2.96684
# [920]	validation_0-rmse:2.01059	validation_1-rmse:2.96515
# [940]	validation_0-rmse:1.99940	validation_1-rmse:2.96491
# [960]	validation_0-rmse:1.99372	validation_1-rmse:2.96439
# [971]	validation_0-rmse:1.98780	validation_1-rmse:2.96468
# Doing predictions...
# Doing metrics ...
# Final score mean_squared_error
# Score val  : 2.9641001680659125
# Score test : 3.4552014229713097
# end !
# saving feature importance .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_5/rmse_val_2.9641_test_3.4552_feature_importance.png
# saving test prediction .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_5/rmse_val_2.9641_test_3.4552_prediction_test.png
# saving model.. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_5/rmse_val_2.9641_test_3.4552_model.pkl
# (471730, 1111)
# saving submission .. ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_2/shift_5/rmse_val_2.9641_test_3.4552_submission.csv
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.026304596976958
# saving ..
# saved !
# Saving Prediction first 5 and last 5 weeks ...
# **********
# ['date_block_num']<55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0136417452764963
# **********
# ['date_block_num']>=55
# **********
# Final score referencial mean_squared_error
# RMSE Score referencial TARGET: 2.0388888054868843
# Saving analysis by week ..
# Predict submission
# ********************  fold n°2
# Training ...
# directory_model =  ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_5
# create folder ../../results/Demanda_ventana_custom/xgboost/c_model_v2/fold_3/shift_5
# [19:37:08] WARNING: ../src/learner.cc:627:
# Parameters: { "scale_pos_weight", "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:5.85220	validation_1-rmse:6.25736
# [20]	validation_0-rmse:5.56077	validation_1-rmse:5.96636
# [40]	validation_0-rmse:4.86914	validation_1-rmse:5.29061
# [60]	validation_0-rmse:4.20223	validation_1-rmse:4.66707
# [80]	validation_0-rmse:3.70057	validation_1-rmse:4.20104
# [100]	validation_0-rmse:3.35540	validation_1-rmse:3.89205
# [120]	validation_0-rmse:3.13223	validation_1-rmse:3.69189
# [140]	validation_0-rmse:2.98504	validation_1-rmse:3.56025
# [160]	validation_0-rmse:2.88845	validation_1-rmse:3.47418
# [180]	validation_0-rmse:2.82581	validation_1-rmse:3.41881
# [200]	validation_0-rmse:2.77853	validation_1-rmse:3.37698
# [220]	validation_0-rmse:2.73907	validation_1-rmse:3.34564
# [240]	validation_0-rmse:2.70761	validation_1-rmse:3.32276
# [260]	validation_0-rmse:2.67545	validation_1-rmse:3.30027
# [280]	validation_0-rmse:2.64953	validation_1-rmse:3.28283
# [300]	validation_0-rmse:2.63447	validation_1-rmse:3.27019
# [320]	validation_0-rmse:2.61383	validation_1-rmse:3.25450
# [340]	validation_0-rmse:2.59583	validation_1-rmse:3.24236
# [360]	validation_0-rmse:2.57490	validation_1-rmse:3.22966
# [380]	validation_0-rmse:2.54263	validation_1-rmse:3.21564
# [400]	validation_0-rmse:2.52193	validation_1-rmse:3.20646
# [420]	validation_0-rmse:2.50411	validation_1-rmse:3.19550
# [440]	validation_0-rmse:2.48053	validation_1-rmse:3.18998
# [460]	validation_0-rmse:2.46002	validation_1-rmse:3.17950
# [480]	validation_0-rmse:2.43641	validation_1-rmse:3.17518
# [500]	validation_0-rmse:2.42128	validation_1-rmse:3.16908
# [520]	validation_0-rmse:2.39515	validation_1-rmse:3.16413
# [540]	validation_0-rmse:2.36936	validation_1-rmse:3.15635
# [560]	validation_0-rmse:2.34743	validation_1-rmse:3.15213
# [580]	validation_0-rmse:2.32179	validation_1-rmse:3.14840
# [600]	validation_0-rmse:2.29602	validation_1-rmse:3.13974
# [620]	validation_0-rmse:2.27701	validation_1-rmse:3.13341
# [640]	validation_0-rmse:2.25509	validation_1-rmse:3.12977
# [660]	validation_0-rmse:2.23710	validation_1-rmse:3.12277
# [680]	validation_0-rmse:2.22050	validation_1-rmse:3.11592
# [700]	validation_0-rmse:2.20038	validation_1-rmse:3.10880
# [720]	validation_0-rmse:2.18662	validation_1-rmse:3.10445
# [740]	validation_0-rmse:2.16664	validation_1-rmse:3.10047
# [760]	validation_0-rmse:2.15064	validation_1-rmse:3.09425
# [780]	validation_0-rmse:2.13712	validation_1-rmse:3.09126
# [800]	validation_0-rmse:2.12361	validation_1-rmse:3.08679
