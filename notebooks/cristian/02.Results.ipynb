# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_baseline = pd.read_csv('../../results/Submission_01.csv')
import matplotlib.pyplot as plt

aux = df_baseline['Demanda']

fig = plt.figure(figsize=(20,5))
plt.plot(aux,'o')
plt.show()
